# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
 
os.environ["CUDA_VISIBLE_DEVICES"]="3";

# %%
from flair.data import Corpus
from flair.datasets import ColumnCorpus
from flair.embeddings import TokenEmbeddings, FlairEmbeddings, StackedEmbeddings
from typing import List

# %%
import torch
torch.__version__
# Out:
# '1.5.0'

# %% [markdown]
# #### train with a costume training file

# %% [markdown]
# # Data 1

# %%
TRAIN_FILE = 'train.tsv'
DOC = 'data/data1'
# exemple du format pour ner ou pos
#Il       PRO:PER   O
#assure   VER:pres  O
#à        VER:pper  O
#la       DET:ART   O
#suite    NOM       O
#de       PRP       I-PER
#Saussure NAM       I-PER
#le       DET:ART   O
corpus = ColumnCorpus(DOC,column_format={0: 'text', 1: 'ner'},train_file=TRAIN_FILE)
tag_type = 'ner'
# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary)
# 4. initialize embeddings
embedding_types: List[TokenEmbeddings] = [
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)
    
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# 7. start training
trainer.train(DOC+'/flair-ner',
              learning_rate=0.1,
              mini_batch_size=32,
              max_epochs=200)
# Out:
# 2020-05-15 13:37:10,054 Reading data from data/data1
# 2020-05-15 13:37:10,055 Train: data/data1/train.tsv
# 2020-05-15 13:37:10,055 Dev: None
# 2020-05-15 13:37:10,056 Test: None
# Dictionary with 8 tags: <unk>, O, S-Disease, B-Disease, I-Disease, E-Disease, <START>, <STOP>
# 2020-05-15 13:37:13,074 ----------------------------------------------------------------------------------------------------
# 2020-05-15 13:37:13,075 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
# ...

# %% [markdown]
# # BC5CDR

# %%
TRAIN_FILE = 'train.tsv'
DOC = 'data/BC5CDR'
# exemple du format pour ner ou pos
#Il       PRO:PER   O
#assure   VER:pres  O
#à        VER:pper  O
#la       DET:ART   O
#suite    NOM       O
#de       PRP       I-PER
#Saussure NAM       I-PER
#le       DET:ART   O
corpus = ColumnCorpus(DOC,column_format={0: 'text', 1: 'ner'},train_file=TRAIN_FILE)
tag_type = 'ner'
# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary)
# 4. initialize embeddings
embedding_types: List[TokenEmbeddings] = [
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)
    
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# 7. start training
trainer.train('flair-ner-BC5CDR',
              learning_rate=0.1,
              mini_batch_size=32,
              max_epochs=200)
# Out:
# 2020-05-15 14:07:37,028 Reading data from data/BC5CDR
# 2020-05-15 14:07:37,029 Train: data/BC5CDR/train.tsv
# 2020-05-15 14:07:37,029 Dev: None
# 2020-05-15 14:07:37,030 Test: None
# Dictionary with 8 tags: <unk>, O, B-Chemical, B-Disease, I-Disease, I-Chemical, <START>, <STOP>
# 2020-05-15 14:07:39,312 ----------------------------------------------------------------------------------------------------
# 2020-05-15 14:07:39,313 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
# ...

# %% [markdown]
# # BC5CDR-chem

# %%
TRAIN_FILE = 'train.tsv'
DOC = 'data/BC5CDR-chem'
# exemple du format pour ner ou pos
#Il       PRO:PER   O
#assure   VER:pres  O
#à        VER:pper  O
#la       DET:ART   O
#suite    NOM       O
#de       PRP       I-PER
#Saussure NAM       I-PER
#le       DET:ART   O
corpus = ColumnCorpus(DOC,column_format={0: 'text', 1: 'ner'},train_file=TRAIN_FILE)
tag_type = 'ner'
# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary)
# 4. initialize embeddings
embedding_types: List[TokenEmbeddings] = [
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)
    
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# 7. start training
trainer.train('flair-ner-BC5CDR-chem',
              learning_rate=0.1,
              mini_batch_size=32,
              max_epochs=200)
# Out:
# 2020-05-15 14:44:30,265 Reading data from data/BC5CDR-chem
# 2020-05-15 14:44:30,267 Train: data/BC5CDR-chem/train.tsv
# 2020-05-15 14:44:30,267 Dev: None
# 2020-05-15 14:44:30,267 Test: None
# Dictionary with 8 tags: <unk>, O, S-Chemical, B-Chemical, I-Chemical, E-Chemical, <START>, <STOP>
# 2020-05-15 14:44:32,432 ----------------------------------------------------------------------------------------------------
# 2020-05-15 14:44:32,433 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
# ...

# %% [markdown]
# # JNLPBA

# %%
TRAIN_FILE = 'train.tsv'
DOC = 'data/JNLPBA'
# exemple du format pour ner ou pos
#Il       PRO:PER   O
#assure   VER:pres  O
#à        VER:pper  O
#la       DET:ART   O
#suite    NOM       O
#de       PRP       I-PER
#Saussure NAM       I-PER
#le       DET:ART   O
corpus = ColumnCorpus(DOC,column_format={0: 'text', 1: 'ner'},train_file=TRAIN_FILE)
tag_type = 'ner'
# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary)
# 4. initialize embeddings
embedding_types: List[TokenEmbeddings] = [
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)
    
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# 7. start training
trainer.train('flair-ner-JNLPBA',
              learning_rate=0.1,
              mini_batch_size=32,
              max_epochs=200)
# Out:
# 2020-05-17 17:16:12,011 Reading data from data/JNLPBA
# 2020-05-17 17:16:12,012 Train: data/JNLPBA/train.tsv
# 2020-05-17 17:16:12,013 Dev: None
# 2020-05-17 17:16:12,013 Test: None
# Dictionary with 24 tags: <unk>, O, B-DNA, I-DNA, E-DNA, B-cell_line, E-cell_line, I-cell_line, B-cell_type, E-cell_type, S-DNA, B-protein, I-protein, E-protein, S-protein, S-cell_line, I-cell_type, S-cell_type, B-RNA, E-RNA, I-RNA, S-RNA, <START>, <STOP>
# 2020-05-17 17:16:20,151 ----------------------------------------------------------------------------------------------------
# 2020-05-17 17:16:20,152 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_1): FlairEmbeddings(
# ...

# %% [markdown]
# #### train with default dataset

# %%
from flair.data import Sentence

s = Sentence("Clustering of missense mutations in the ataxia-telangiectasia gene in a sporadic T-cell leukaemia. Ataxia-telangiectasia ( A-T ) is a recessive multi-system disorder caused by mutations in the ATM gene at 11q22-q23 ( ref . 3 ) . The risk of cancer , especially lymphoid neoplasias , is substantially elevated in A-T patients and has long been associated with chromosomal instability . By analysing tumour DNA from patients with sporadic T-cell prolymphocytic leukaemia ( T-PLL ) , a rare clonal malignancy with similarities to a mature T-cell leukaemia seen in A-T , we demonstrate a high frequency of ATM mutations in T-PLL . In marked contrast to the ATM mutation pattern in A-T , the most frequent nucleotide changes in this leukaemia were missense mutations . These clustered in the region corresponding to the kinase domain , which is highly conserved in ATM-related proteins in mouse , yeast and Drosophila . The resulting amino-acid substitutions are predicted to interfere with ATP binding or substrate recognition . Two of seventeen mutated T-PLL samples had a previously reported A-T allele . In contrast , no mutations were detected in the p53 gene , suggesting that this tumour suppressor is not frequently altered in this leukaemia. Occasional missense mutations in ATM were also found in tumour DNA from patients")

tagger.predict(s)

print(s.to_tagged_string())
# Out:
# Clustering of missense mutations in the ataxia-telangiectasia <B-DNA> gene <E-DNA> in a sporadic T-cell leukaemia. Ataxia-telangiectasia ( A-T ) is a recessive multi-system disorder caused by mutations in the ATM <B-DNA> gene <E-DNA> at 11q22-q23 <S-DNA> ( ref . 3 ) . The risk of cancer , especially lymphoid neoplasias , is substantially elevated in A-T patients and has long been associated with chromosomal instability . By analysing tumour <B-DNA> DNA <E-DNA> from patients with sporadic T-cell prolymphocytic leukaemia ( T-PLL ) , a rare clonal malignancy with similarities to a mature T-cell leukaemia seen in A-T , we demonstrate a high frequency of ATM mutations in T-PLL . In marked contrast to the ATM mutation pattern in A-T , the most frequent nucleotide changes in this leukaemia were missense mutations . These clustered in the region corresponding to the kinase <B-protein> domain <E-protein> , which is highly conserved in ATM-related <B-protein> proteins <E-protein> in mouse , ye
# ...

# %% [markdown]
# ## General dataset

# %%
TRAIN_FILE = 'general-train.tsv'
DOC = 'data'
# exemple du format pour ner ou pos
#Il       PRO:PER   O
#assure   VER:pres  O
#à        VER:pper  O
#la       DET:ART   O
#suite    NOM       O
#de       PRP       I-PER
#Saussure NAM       I-PER
#le       DET:ART   O
corpus = ColumnCorpus(DOC,column_format={0: 'text', 1: 'ner'},train_file=TRAIN_FILE)
tag_type = 'ner'
# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary)
# 4. initialize embeddings
embedding_types: List[TokenEmbeddings] = [
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)
    
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# 7. start training
trainer.train('flair-ner-Global',
              learning_rate=0.1,
              mini_batch_size=48,
              max_epochs=100)
# Out:
# 2020-05-17 14:51:27,535 Reading data from data
# 2020-05-17 14:51:27,536 Train: data/general-train.tsv
# 2020-05-17 14:51:27,536 Dev: None
# 2020-05-17 14:51:27,536 Test: None
# Dictionary with 30 tags: <unk>, O, B-Disease, I-Disease, B-Chemical, I-Chemical, B-DNA, E-DNA, I-DNA, S-protein, B-protein, I-protein, E-protein, S-Chemical, E-Chemical, B-cell_type, I-cell_type, E-cell_type, B-RNA, E-RNA, B-cell_line, I-cell_line, E-cell_line, S-DNA, S-cell_type, I-RNA, S-cell_line, S-RNA, <START>, <STOP>
# 2020-05-17 14:51:39,925 ----------------------------------------------------------------------------------------------------
# 2020-05-17 14:51:39,926 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
# ...
