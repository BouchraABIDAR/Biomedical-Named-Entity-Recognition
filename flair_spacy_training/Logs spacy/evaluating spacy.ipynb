# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv('lossJNLPBA.csv',header=None)
df2 = pd.read_csv('loss-BC5CDR-chem.csv',header=None)
df3 = pd.read_csv('loss-BC5CDR.csv',header=None)

df1.columns = ['lossJNLPBA']
df2.columns = ['loss_BC5CDR_chem']
df3.columns = ['loss_BC5CDR']

df = pd.DataFrame({'{lossJNLPBA' : df1.lossJNLPBA,
                  'loss_BC5CDR_chem' : df2.loss_BC5CDR_chem,
                  'loss_BC5CDR': df3.loss_BC5CDR })

# %%
df.plot()
