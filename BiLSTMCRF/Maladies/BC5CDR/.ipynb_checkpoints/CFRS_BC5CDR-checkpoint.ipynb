# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import sys  
sys.path.insert(0, '/home/user/PPD_project/')
from CFRs_functions import *

# %%
import nltk
import csv
from nltk.tokenize import word_tokenize
from nltk import word_tokenize, pos_tag, pos_tag_sents
import nltk.tag
from sklearn.model_selection import learning_curve
from itertools import chain
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelBinarizer
import pycrfsuite
import io

# %%
import sklearn_crfsuite
import eli5
import scipy.stats

from sklearn.model_selection import train_test_split
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite.metrics import flat_classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
from sklearn_crfsuite.metrics import sequence_accuracy_score,flat_accuracy_score, flat_recall_score,flat_precision_score
# Out:
# Using TensorFlow backend.

# %%
# Pos_tag_corpus : fonction pour ajouter les POS au corpus

# %%
corpus_training_with_pos = Pos_tag_corpus("Corpus_BC5CDR/train.tsv")
corpus_testing_with_pos = Pos_tag_corpus("Corpus_BC5CDR/test.tsv")
corpus_devel_with_pos = Pos_tag_corpus("Corpus_BC5CDR/devel.tsv")

# %%
# Distrubition des tag

# %%
tag_distribution = corpus_training_with_pos.groupby("tag").size().reset_index(name='counts')
print(tag_distribution)
# Out:
#           tag  counts
# 0  B-Chemical    5202
# 1   B-Disease    4182
# 2  I-Chemical    1900
# 3   I-Disease    2918
# 4           O  103966

# %%
## Save les données avec POS et Class
corpus_training_with_pos.to_csv('POS_BC5CDR/train_pos.tsv',sep='\t',index=False, header=False)
corpus_testing_with_pos.to_csv('POS_BC5CDR/test_pos.tsv',sep='\t',index=False, header=False)
corpus_devel_with_pos.to_csv('POS_BC5CDR/dev_pos.tsv',sep='\t',index=False, header=False)

# %%
corpus_training = corpus_preprocessing("POS_BC5CDR/train_pos.tsv")
corpus_testing = corpus_preprocessing("POS_BC5CDR/test_pos.tsv")
corpus_devel = corpus_preprocessing("POS_BC5CDR/dev_pos.tsv")

# %%
X_dev = sent2features(corpus_devel)
X_dev = [[i] for i in X_dev]
y_dev = sent2labels(corpus_devel)
y_dev = [[i] for i in y_dev]

# %%
## split_data_train_test : fonction pour spliter les datas

# %%
X_train, y_train, X_test, y_test = split_data_train_test(corpus_training, corpus_testing)

# %% [markdown]
# ## Train a CRF model

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True,
)
crf.fit(X_train, y_train);

# %%
import eli5
eli5.show_weights(crf, show=['targets'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-Chemical
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-Chemical
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-Disease
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-Disease
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.512
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():saline
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.933
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():side
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.835
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():baseline
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.036
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():healthy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.80%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.755
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():dose
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.712
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():control
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.666
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():line
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.606
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():determine
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.538
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():urine
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.534
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():calcineurin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.515
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bias
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.465
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():prolactin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.453
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():endocrine
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.405
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():membrane
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.190
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():nine
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.107
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():examine
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.091
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():biopsy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.032
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-Disease', 'I-Disease', 'B-Chemical', 'I-Chemical']

# %%
## cross validation de model

# %%
pred = cross_val_predict(estimator=crf, X = X_train,y = y_train, cv=10)

# %%
report = flat_classification_report(y_pred=pred, y_true=y_train)
print(report)
f1 = flat_f1_score(y_train, pred, average='weighted', labels=labels)
print("F1 weighted avg: " + str(f1))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical       0.92      0.76      0.83      5202
#    B-Disease       0.84      0.66      0.74      4182
#   I-Chemical       0.81      0.48      0.60      1900
#    I-Disease       0.79      0.53      0.63      2918
#            O       0.96      0.99      0.97    103966
#
#     accuracy                           0.95    118168
#    macro avg       0.86      0.68      0.76    118168
# weighted avg       0.95      0.95      0.95    118168
#
# F1 weighted avg: 0.731643446535844

# %%
## On test sur les données test et dev

# %%
y_pred = crf.predict(X_test)
flat_f1_score(y_test, y_pred,average='weighted', labels=labels)
# Out:
# 0.7417211002326651

# %%
y_pred = crf.predict(X_dev)
flat_f1_score(y_dev, y_pred,average='weighted', labels=labels)
# Out:
# 0.7493551755929264

# %%
# group B and I results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(flat_classification_report(
    y_dev, y_pred, labels=sorted_labels, digits=3
))

accuracy = flat_accuracy_score(y_dev, y_pred)
print("Accuracy: " + str(accuracy))
f1 = flat_f1_score(y_dev, y_pred, average='weighted', labels=labels)
precision = flat_precision_score(y_dev, y_pred, average='weighted', labels=labels)
print("Precision : "  + str(precision))

recall =flat_recall_score(y_dev, y_pred, average='weighted', labels=labels)
print("Recall : " + str(recall))
print("F1 weighted avg: " + str(f1))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.923     0.780     0.846      5346
#   I-Chemical      0.765     0.477     0.588      1748
#    B-Disease      0.826     0.686     0.749      4246
#    I-Disease      0.773     0.583     0.664      2723
#
#    micro avg      0.849     0.676     0.753     14063
#    macro avg      0.822     0.631     0.712     14063
# weighted avg      0.845     0.676     0.749     14063
#
# Accuracy: 0.9519803834758028
# Precision : 0.8447846848149426
# Recall : 0.6758159709876982
# F1 weighted avg: 0.7493551755929264

# %% [markdown]
# ## Plot learning curves for the optimised model

# %% [markdown]
# La performance du modèle peut être évaluée à l'aide d'une courbe d'apprentissage, en traçant la précision des prédictions sur les ensembles de données de formation et de test au fur et à mesure que des données de formation supplémentaires sont introduites dans le modèle. Comme on peut s'y attendre, la précision des données de test augmente avec le nombre d'échantillons de formation.

# %%
# Produce the necessary data for a learning curve
train_sizes, train_scores, test_scores = learning_curve(estimator=crf,
                                                        X=X_train,
                                                        y=y_train,
                                                        train_sizes=np.linspace(0.1, 1.0, 10),
                                                        cv=3,
                                                        verbose=1,
                                                        n_jobs=-1)

# Find the means and standard deviations of the training and test datasets across the learning curve
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot the learning curve
plot_learning_curve(train_sizes, train_mean, train_std, test_mean, test_std)
# Out:
# [learning_curve] Training set sizes: [ 7877 15755 23633 31511 39389 47266 55144 63022 70900 78778]
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  1.9min finished

# %%
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(flat_f1_score,average='weighted', labels=labels)
# search
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=50,
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 15.5min finished
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=CRF(algorithm='lbfgs', all_possible_states=None,
#                                  all_possible_transitions=True, averaging=None,
#                                  c=None, c1=0.1, c2=0.1,
#                                  calibration_candidates=None,
#                                  calibration_eta=None,
#                                  calibration_max_trials=None,
#                                  calibration_rate=None,
#                                  calibration_samples=None, delta=None,
#                                  epsilon=None, error_sensitive=None, ga...
#                    param_distributions={'c1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fbcddb7f610>,
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fbcddb915d0>},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False,
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['B-Disease', 'I-Disease', 'B-Chemical', 'I-Chemical']),
#                    verbose=1)

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.20180759620162603, 'c2': 0.027333153003740326}
# best CV score: 0.7010011174186632
# model size: 0.73M

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_dev)
print(flat_classification_report(
    y_dev, y_pred, labels=sorted_labels, digits=3
))

accuracy = flat_accuracy_score(y_dev, y_pred)
print("accuracy :" + str(accuracy))
precision = flat_precision_score(y_dev, y_pred, average='weighted', labels=labels)
print("Precision : "  + str(precision))
recall = flat_recall_score(y_dev, y_pred, average='weighted', labels=labels)
print("Recall : " + str(recall))
f1 = flat_f1_score(y_dev, y_pred, average='weighted', labels=labels)
print("F1 weighted avg: " + str(f1))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.924     0.780     0.846      5346
#   I-Chemical      0.757     0.465     0.576      1748
#    B-Disease      0.822     0.699     0.756      4246
#    I-Disease      0.756     0.595     0.666      2723
#
#    micro avg      0.844     0.680     0.754     14063
#    macro avg      0.815     0.635     0.711     14063
# weighted avg      0.840     0.680     0.750     14063
#
# accuracy :0.9519974117086129
# Precision : 0.8402294849916769
# Recall : 0.6804380288700846
# F1 weighted avg: 0.750270541332069

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
_x = rs.cv_results_['param_c1'].tolist()
_y = rs.cv_results_['param_c2'].tolist()
_c = rs.cv_results_['mean_test_score'].tolist()

fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.gca()
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('C1')
ax.set_ylabel('C2')
ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(
    min(_c), max(_c)
))

ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])

print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))
# Out:
# Dark blue => 0.6329, dark red => 0.701

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_dev)
print(flat_classification_report(
    y_dev, y_pred, labels = sorted_labels, digits = 3
))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.924     0.780     0.846      5346
#   I-Chemical      0.757     0.465     0.576      1748
#    B-Disease      0.822     0.699     0.756      4246
#    I-Disease      0.756     0.595     0.666      2723
#
#    micro avg      0.844     0.680     0.754     14063
#    macro avg      0.815     0.635     0.711     14063
# weighted avg      0.840     0.680     0.750     14063

# %%
## tester avec les données  dev

# %%
# accuracy = flat_accuracy_score(y_dev, y_pred)
# print("accuracy :" + str(accuracy))
precision = flat_precision_score(y_dev, y_pred, average='weighted', labels=labels)
print("Precision : "  + str(precision))
recall = flat_recall_score(y_dev, y_pred, average='weighted', labels=labels)
print("Recall : " + str(recall))
f1 = flat_f1_score(y_dev, y_pred, average='weighted', labels=labels)
print("flat_f1_score: " + str(f1))
# Out:
# Precision : 0.8402294849916769
# Recall : 0.6804380288700846
# flat_f1_score: 0.750270541332069

# %%
## les données test
y_pred = crf.predict(X_test)

# %%
# accuracy = flat_accuracy_score(y_test, y_pred)
# print("accuracy :" + str(accuracy))
precision = flat_precision_score(y_test, y_pred, average='weighted', labels=labels)
print("Precision : "  + str(precision))
recall = flat_recall_score(y_test, y_pred, average='weighted', labels=labels)
print("Recall : " + str(recall))
f1 = flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
print("F1 flat_f1_score avg: " + str(f1))

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 7.680241 E-Disease word.lower():palate
# 7.079818 S-Disease word.lower():hypopigmentation
# 6.470474 E-Disease word.lower():tumors
# 6.393645 I-Disease -1:word.lower():hypersensitivity
# 6.381990 I-Disease +1:word.lower():epididymis
# 6.310929 S-Disease word.lower():tumors
# 6.015982 S-Disease word.lower():cataracts
# 5.995928 I-Disease +1:word.lower():ninth
# 5.956562 I-Disease +1:word.lower():syndrome
# 5.831147 S-Disease word.lower():cancers
# 5.795925 I-Disease -1:word.lower():gastric
# 5.771352 E-Disease word.lower():cancers
# 5.728105 S-Disease word.lower():aniridia
# 5.725559 S-Disease word.lower():neurodegeneration
# 5.723875 B-Disease word.lower():hypersensitivity
# 5.554444 B-Disease +1:word.lower():dystrophy
# 5.548867 I-Disease +1:word.lower():achilles
# 5.524757 B-Disease +1:word.lower():syndrome
# 5.447542 S-Disease word.lower():hypomyelination
# 5.387771 I-Disease -1:word.lower():breast
# 5.337615 I-Disease -1:word.lower():syndromic
# 5.318167 E-Disease -1:word.lower():hearing
# 5.303637 E-Disease word.lower():retardation
# 5.230713 S-Disease word[-3:]:ema
# 5.125849 S-Disease word.lower():obesity
# 5.117182 S-Disease word[-3:]:mia
# 5.109544 I-Disease +1:word.lower():fingers
# 5.003278 S-Disease word.lower():infertility
# 4.991152 S-Disease word.lower():hypopigmented
# 4.955015 E-Disease -1:word.lower():anchored
#
# Top negative:
# -3.263694 O        word.lower():prostate
# -3.299281 O        word.lower():component
# -3.307100 O        -1:word.lower():lindau
# -3.307698 O        +1:word.lower():elbows
# -3.329706 O        +1:word.lower():anomaly
# -3.379496 O        +1:word.lower():retarded
# -3.390473 O        -1:word.lower():disomy
# -3.395916 O        +1:word.lower():eyes
# -3.480501 O        +1:word.lower():cancers
# -3.516463 O        -1:word.lower():clefts
# -3.544651 O        +1:word.lower():ear
# -3.616265 O        +1:word.lower():meningitis
# -3.644431 B-Disease -1:word.lower():-
# -3.702291 O        word[-3:]:nia
# -3.733203 O        +1:word.lower():lcat
# -3.782113 O        -1:word.lower():pros1
# -3.832715 O        +1:word.lower():seventh
# -3.836716 O        word[-3:]:ias
# -3.921868 O        +1:word.lower():dysmyelinating
# -3.944708 S-Disease -1:word.lower():-
# -4.050200 O        +1:word.lower():49
# -4.053604 O        word[-3:]:mas
# -4.113030 O        word.lower():ovarian
# -4.210730 O        word[-3:]:sia
# -4.226802 O        word.lower():degeneration
# -4.345053 O        +1:word.lower():anemia
# -4.420756 O        word[-3:]:thy
# -4.724128 O        word[-3:]:tis
# -4.848861 O        word[-3:]:mia
# -5.458650 O        word[-3:]:oma

# %%
## pycrfsuite

# %%
trainer = pycrfsuite.Trainer(verbose=False)

for xseq, yseq in zip(X_train, y_train):
    trainer.append(xseq, yseq)

# %%
trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 100,  # epoches

    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

# %%
trainer.train('UG_NER_1203_1st.model')

# %%
tagger = pycrfsuite.Tagger()
tagger.open('UG_NER_1203_1st.model')

# %%
y_pred = [tagger.tag(xseq) for xseq in X_test]

# %%
X_test[0]
# Out:
# [{'bias': 1.0,
#   'word.lower()': 'of',
#   'word[-3:]': 'of',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   'postag': 'IN',
#   'postag[:2]': 'IN',
#   'BOS': True,
#   '+1:word.lower()': 'missense',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:postag': 'NN',
#   '+1:postag[:2]': 'NN'}]

# %%
# %%time
y_pred = [tagger.tag(xseq) for xseq in X_dev]
# Out:
# CPU times: user 369 ms, sys: 5 µs, total: 369 ms
# Wall time: 368 ms

# %%
print(bio_classification_report(y_dev, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    B-Disease       0.83      0.66      0.73       504
#    E-Disease       0.90      0.81      0.85       504
#    I-Disease       0.87      0.57      0.69       586
#    S-Disease       0.85      0.75      0.80       283
#
#    micro avg       0.86      0.69      0.76      1877
#    macro avg       0.86      0.70      0.77      1877
# weighted avg       0.86      0.69      0.76      1877
#  samples avg       0.05      0.05      0.05      1877
