# %%
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

# %%
import sklearn_crfsuite
import eli5
import scipy.stats

from sklearn.model_selection import train_test_split
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite.metrics import flat_classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV
# Out:
# Using TensorFlow backend.

# %%
import sys  
sys.path.insert(0, '/home/user/PPD_project/')
from CFRs_functions import *

# %%
corpus_training_with_pos = Pos_tag_corpus("Corpus_BC5CDR/train.tsv")
corpus_testing_with_pos = Pos_tag_corpus("Corpus_BC5CDR/test.tsv")
corpus_devel_with_pos = Pos_tag_corpus("Corpus_BC5CDR/devel.tsv")

# %%
corpus_training_with_pos.to_csv('POS_BC5CDR/train_pos.tsv',sep='\t',index=False, header=False)
corpus_testing_with_pos.to_csv('POS_BC5CDR/test_pos.tsv',sep='\t',index=False, header=False)
corpus_devel_with_pos.to_csv('POS_BC5CDR/dev_pos.tsv',sep='\t',index=False, header=False)

# %%
corpus_training = corpus_preprocessing("POS_BC5CDR/train_pos.tsv")
corpus_testing = corpus_preprocessing("POS_BC5CDR/test_pos.tsv")
corpus_devel = corpus_preprocessing("POS_BC5CDR/dev_pos.tsv")

# %%
X_train, y_train, X_test, y_test = split_data_train_test(corpus_training, corpus_testing)

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True,
)
crf.fit(X_train, y_train);

# %%
eli5.show_weights(crf,show=['targets'],top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-Chemical
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-Chemical
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
# ...

# %%
# Use the l1 regularization to sparsify the feature weights
crf_c1reg = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=200,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True,
)
crf_c1reg.fit(X_train, y_train);

# %%
# Consoder all TAG transitions
crf_allTrans = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.01,
    c2=0.02,
    max_iterations=100,
    all_possible_transitions=True,
)
crf_allTrans.fit(X_train, y_train);

# %%
eli5.show_weights(crf_allTrans, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-Chemical</th>
#
#                 <th>I-Chemical</th>
#
#                 <th>B-Disease</th>
#
#                 <th>I-Disease</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(0, 100.00%, nan%)" title="O &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, nan%)" title="O &rArr; B-Chemical">
#                             0.0
#                         </td>
#
# ...

# %%
eli5.show_weights(crf_c1reg,top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-Chemical</th>
#
#                 <th>I-Chemical</th>
#
#                 <th>B-Disease</th>
#
#                 <th>I-Disease</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(0, 100.00%, nan%)" title="O &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, nan%)" title="O &rArr; B-Chemical">
#                             0.0
#                         </td>
#
# ...

# %%
eli5.explain_weights(crf_allTrans, top=10)
# Out:
# Explanation(estimator="CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=True,\n    averaging=None, c=None, c1=0.01, c2=0.02, calibration_candidates=None,\n    calibration_eta=None, calibration_max_trials=None, calibration_rate=None,\n    calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,\n    gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,\n    max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,\n    pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)", description=None, error=None, method='CRF', is_regression=False, targets=[TargetExplanation(target='O', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='word.lower():saline', weight=8.882584, std=None, value=None), FeatureWeight(feature='word.lower():side', weight=8.234679, std=None, value=None), FeatureWeight(feature='word.lower():baseline', weight=7.669794, std=None, value=None), FeatureWeight(feature='word.
# ...

# %%
# Check if a feature function works as intended
eli5.show_weights(crf_allTrans, top=10, feature_re='^word\.is',horizontal_layout=False, show=['targets'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=O
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
# ...

# %%
eli5.show_weights(crf, top=10, feature_re='^word\.is',horizontal_layout=False, show=['targets'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=O
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
# ...

# %%
eli5.show_weights(crf_c1reg, top=10, feature_re='^word\.is',horizontal_layout=False, show=['targets'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=B-Chemical
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
# ...

# %%
expl = eli5.explain_weights(crf, top=5, targets=["B-Chemical","I-Chemical","B-Disease","I-Disease"])
print(eli5.format_as_text(expl))
# Out:
# Explained as: CRF
#
# Transition features:
#               B-Chemical    I-Chemical    B-Disease    I-Disease
# ----------  ------------  ------------  -----------  -----------
# B-Chemical         0.000         0.000        0.000        0.000
# I-Chemical         0.000         0.000        0.000        0.000
# B-Disease          0.000         0.000        0.000        0.000
# I-Disease          0.000         0.000        0.000        0.000
#
# y='B-Chemical' top features
#        … 1763 more positive …
#        … 179 more negative …
# Weight  Feature
# ------  ----------------------------
# +7.756  word.lower():antidepressant
# +7.359  word.lower():bupropion
# +6.889  word[-3:]:cin
# +6.273  word.lower():luminal
# +6.134  word.lower():antidepressants
#
# y='I-Chemical' top features
#     … 1219 more positive …
#      … 110 more negative …
# Weight  Feature
# ------  -----------------------
# +7.422  -1:word.lower():vitamin
# +5.328  -1:word.lower():cacl
# +4.935  word[-3:]:opa
# ...

# %%
# Evaluate without the O label
labels = list(crf.classes_)
labels.remove('O')
#labels.remove('I-Disease')
labels
# Out:
# ['B-Disease', 'I-Disease', 'B-Chemical', 'I-Chemical']

# %%
y_pred_crf= crf.predict(X_test)
y_pred_crf_c1reg = crf_c1reg.predict(X_test)
y_pred_crf_allTrans = crf_allTrans.predict(X_test)

# %%
print("crf",flat_f1_score(y_pred_crf, y_test, average='weighted'))
print("crf_c1reg",flat_f1_score(y_pred_crf_c1reg, y_test, average='weighted'))
print("crf_allTrans",flat_f1_score(y_pred_crf_allTrans, y_test, average='weighted'))
# Out:
# crf 0.9557667068282882
# crf_c1reg 0.9361317423855751
# crf_allTrans 0.9555236255887205

# %%
# Per class results
# --> groupe B- and I- results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(flat_classification_report(
    y_test, y_pred_crf, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.917     0.750     0.825      5378
#   I-Chemical      0.745     0.471     0.577      1628
#    B-Disease      0.828     0.672     0.742      4423
#    I-Disease      0.767     0.604     0.676      2737
#
#    micro avg      0.844     0.665     0.744     14166
#    macro avg      0.814     0.624     0.705     14166
# weighted avg      0.841     0.665     0.742     14166

# %%
# Per class results
# --> groupe B- and I- results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(flat_classification_report(
    y_test, y_pred_crf_c1reg, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.768     0.232     0.356      5378
#   I-Chemical      0.000     0.000     0.000      1628
#    B-Disease      0.000     0.000     0.000      4423
#    I-Disease      0.000     0.000     0.000      2737
#
#    micro avg      0.768     0.088     0.158     14166
#    macro avg      0.192     0.058     0.089     14166
# weighted avg      0.291     0.088     0.135     14166

# %%
# Per class results
# --> groupe B- and I- results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(flat_classification_report(
    y_test, y_pred_crf_allTrans, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.921     0.755     0.830      5378
#   I-Chemical      0.731     0.468     0.571      1628
#    B-Disease      0.813     0.696     0.750      4423
#    I-Disease      0.722     0.649     0.683      2737
#
#    micro avg      0.827     0.683     0.748     14166
#    macro avg      0.797     0.642     0.708     14166
# weighted avg      0.827     0.683     0.747     14166

# %%
# %%time
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    max_iterations=100,
    all_possible_transitions=True
)

# --> grid search
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(flat_f1_score,
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=50,
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 16.0min finished
# CPU times: user 16min 7s, sys: 254 ms, total: 16min 8s
# Wall time: 16min 8s
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=CRF(algorithm='lbfgs', all_possible_states=None,
#                                  all_possible_transitions=True, averaging=None,
#                                  c=None, c1=None, c2=None,
#                                  calibration_candidates=None,
#                                  calibration_eta=None,
#                                  calibration_max_trials=None,
#                                  calibration_rate=None,
#                                  calibration_samples=None, delta=None,
#                                  epsilon=None, error_sensitive=None,...
# ...

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
print(rs.cv_results_.keys())
rs.cv_results_['mean_test_score']
# Out:
# best params: {'c1': 0.10870150678515297, 'c2': 0.0054272062519354}
# best CV score: 0.7015230510694557
# model size: 0.75M
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_c1', 'param_c2', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])
# array([0.68328422, 0.69697603, 0.69683086, 0.64976438, 0.64412276,
#        0.69436233, 0.63975725, 0.68142135, 0.69916178, 0.70152305,
#        0.70079068, 0.683706  , 0.68960615, 0.69478902, 0.68167438,
#        0.70140052, 0.67178079, 0.69903385, 0.66950138, 0.70118847,
#        0.69961071, 0.697587  , 0.66842394, 0.69965489, 0.68162185,
#        0.70011029, 0.65755617, 0.68494775, 0.70141742, 0.62152104,
#        0.68482383, 0.69956073, 0.70008853, 0.65655686, 0.67874384,
#        0.70028519, 0.65800479, 0.67408375, 0.66843086, 0.69971398,
#        0.70007984, 0.67583327, 0.64877681, 0.6681793 , 0.6581538 ,
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
_x = rs.cv_results_['param_c1'].tolist()
_y = rs.cv_results_['param_c2'].tolist()
_c = rs.cv_results_['mean_test_score'].tolist()

fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.gca()
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('C1')
ax.set_ylabel('C2')
ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(
    min(_c), max(_c)
))

ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])

print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))
# Out:
# Dark blue => 0.6215, dark red => 0.7015

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(flat_classification_report(
    y_test, y_pred, labels = sorted_labels, digits = 3
))
# Out:
#               precision    recall  f1-score   support
#
#   B-Chemical      0.926     0.740     0.823      5378
#   I-Chemical      0.734     0.458     0.564      1628
#    B-Disease      0.816     0.699     0.753      4423
#    I-Disease      0.730     0.630     0.676      2737
#
#    micro avg      0.832     0.674     0.745     14166
#    macro avg      0.801     0.632     0.704     14166
# weighted avg      0.832     0.674     0.743     14166

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))
        
print("Top likely transitions:")
print_transitions(Counter(crf_c1reg.transition_features_).most_common(20))
print("\nTop unlikely transitions:")
print_transitions(Counter(crf_allTrans.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
#
# Top unlikely transitions:

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 13.973032 I-Chemical word.lower():berries
# 13.647593 I-Chemical +1:word.lower():berries
# 13.364312 B-Chemical word.lower():antidepressant
# 13.112010 I-Chemical -1:word.lower():vitamin
# 12.752975 B-Chemical word.lower():antidepressants
# 12.454859 B-Disease word[-3:]:ALL
# 12.082115 B-Chemical word.lower():bupropion
# 11.725991 B-Disease word.lower():constipating
# 11.590410 B-Disease word.lower():depressed
# 11.318494 B-Disease word.lower():hypertension
# 11.136979 B-Disease word.lower():hypertensive
# 11.089364 B-Disease word.lower():epileptic
# 11.076227 B-Disease word.lower():seizure
# 10.968105 B-Chemical +1:word.lower():oxide
# 10.905399 B-Chemical word.lower():luminal
# 10.846778 I-Disease word.lower():vomiting
# 10.771124 B-Disease word.lower():hypotension
# 10.642856 B-Disease word.lower():migraine
# 10.639393 B-Disease word.lower():potter
# 10.514263 I-Chemical word.lower():antidepressants
# 10.469776 B-Chemical word[-3:]:dol
# ...
