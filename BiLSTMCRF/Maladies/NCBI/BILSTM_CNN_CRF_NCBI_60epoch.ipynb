# %% [markdown]
# # BiLSTM CNN CRF pour la reconnaissance des maladies
# Nous utiliserons le codage par réseau neuronal à convolution pour la représentation des mots au niveau des caractères, le LSTM bidirectionnel pour le codage au niveau des mots et les champs aléatoires conditionnels (couche CRF) pour les décodages de sortie.
#
# Réference [model](https://github.com/ZhixiuYe/NER-pytorch)

# %%
import tensorflow as tf
import keras
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D,Flatten, concatenate
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.layers.crf import CRF
from keras.utils import plot_model
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Nadam
import numpy as np
import os
import sys
import codecs
import re
import pickle
from sklearn_crfsuite.metrics import flat_classification_report
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Preprocessing
#
# Data prepocessing comprend le chargement des données, la mise à jour du schéma de balisage, la création d'un mappong pour les mots, les caractères et les tags et enfin la préparation des données qui sont transmises dans le modèle.

# %% [markdown]
# ### Custom Data Loading
# Cette étape comprend le chargement du train et la validation des données dans la liste des phrases.
#
# Le code suivant charge les données de formation et de validation.

# %%
import csv
def corpus_preprocessing(path):
    pairwise = dict()
  
    paths = [path]
    sentences = []
    sentence = []
    p_token = ''

    all_length = []
    length = 0
    longer_entity = 0
    max_length = 0
    entity_count = 0
    labels_list = []
    tokens_list =[]
    tag_list =[]
    for path in paths:
        with open(path) as fin:
            reader = csv.reader(fin, delimiter='\t', quoting=csv.QUOTE_NONE)
            entity_length_turn_on = False
            for i, row in enumerate(reader):
                if i == 0:
                    pass
                if len(row) < 2:
                    sentences.append(sentence)
                    sentence = []
                else:
                    token = row[0]
                    label = row[1]
                    #tag = row[1]

                    labels_list.append(label)
                    #tag_list.append(tag)
                    tokens_list.append(token)
    #return list(zip(tokens_list,labels_list))
    return [list([ele]) for ele in list(zip(tokens_list,labels_list))]

# %%
train_sentences = corpus_preprocessing("NCBI_corpus/train.tsv")
dev_sentences = corpus_preprocessing("NCBI_corpus/devel.tsv")
test_sentences = corpus_preprocessing("NCBI_corpus/test.tsv")
len(train_sentences), len(dev_sentences), len(test_sentences)
# Out:
# (135701, 23969, 24497)

# %%
train_sentences[0:10]
# Out:
# [[('Identification', 'O')],
#  [('of', 'O')],
#  [('APC2', 'O')],
#  [(',', 'O')],
#  [('a', 'O')],
#  [('homologue', 'O')],
#  [('of', 'O')],
#  [('the', 'O')],
#  [('adenomatous', 'B-Disease')],
#  [('polyposis', 'I-Disease')]]

# %% [markdown]
# ### Add Character Information

# %%
def add_char_info(sentences):
    for i, sentence in enumerate(sentences):
        for j, data in enumerate(sentence):
            chars = [c for c in data[0]]
            sentences[i][j] = [data[0], chars, data[1]]
    return sentences

# %%
#add_char_info(train_sentences)
#train_sentences

# %%
train_sentences = add_char_info(train_sentences)
dev_sentences = add_char_info(dev_sentences)
test_sentences = add_char_info(test_sentences)

# %% [markdown]
# ### Tag Mappings

# %%
labels_set = set()
words = {}

# unique words and labels in data  
for dataset in [train_sentences, dev_sentences, test_sentences]:
    for sentence in dataset:
        for token, char, label in sentence:
        # token ... token, char ... list of chars, label ... BIO labels   
            labels_set.add(label)
            words[token.lower()] = True

# %%
labels_set
# Out:
# {'B-Disease', 'E-Disease', 'I-Disease', 'O', 'S-Disease'}

# %%
# mapping for labels
indexes = {"PADDING":0}
for label in labels_set:
  indexes[label] = len(indexes)

  
tag_to_id = {}
for word,index in indexes.items():
    tag_to_id[word] = index

tag_to_id
# Out:
# {'PADDING': 0,
#  'B-Disease': 1,
#  'E-Disease': 2,
#  'S-Disease': 3,
#  'O': 4,
#  'I-Disease': 5}

# %%
id_to_tag = {v: k for k, v in tag_to_id.items()}
len(id_to_tag)
# Out:
# 6

# %% [markdown]
# ### Word and Character Embeddings

# %%
# Download Glove Word Embeddings
#!wget http://nlp.stanford.edu/data/glove.6B.zip && unzip glove.6B.zip -d /content/

# %%
word_to_id = {}
word_embeddings = []

EMBEDDINGS_FILE = open("data/glove.6B.50d.txt", encoding="utf-8")


# loop through each word in embeddings
for line in EMBEDDINGS_FILE:
    split = line.strip().split(" ")
    word = split[0]  # embedding word entry

    if len(word_to_id) == 0:  # add padding+unknown
        word_to_id["PADDING_TOKEN"] = len(word_to_id)
        vector = np.zeros(len(split) - 1)  # zero vector for 'PADDING' word
        word_embeddings.append(vector)

        word_to_id["UNKNOWN_TOKEN"] = len(word_to_id)
        vector = np.random.uniform(-0.25, 0.25, len(split) - 1)
        word_embeddings.append(vector)

    if split[0].lower() in words:
        vector = np.array([float(num) for num in split[1:]])
        word_embeddings.append(vector)  # word embedding vector
        word_to_id[split[0]] = len(word_to_id)  # corresponding word dict

word_embeddings = np.array(word_embeddings)
word_embeddings.shape, len(word_to_id)
# Out:
# ((7618, 50), 7618)

# %%
id_to_word = {v: k for k, v in word_to_id.items()}
len(id_to_word)
# Out:
# 7618

# %%
# Dictionnaire de tous les caractères possibles
char_to_id = {"PADDING": 0, "UNKNOWN": 1}
for c in " 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ.,-_()[]{}!?:;#'\"/\\%$`&=*+@^~|<>":
    char_to_id[c] = len(char_to_id)

len(char_to_id)
# Out:
# 97

# %% [markdown]
# ### Prepare Dataset

# %%
def create_dataset(sentences, word_to_id, tag_to_id, char_to_id):
    unk_index = word_to_id['UNKNOWN_TOKEN']
    pad_index = word_to_id['PADDING_TOKEN']

    dataset = []

    word_count = 0
    unk_word_count = 0

    for sentence in sentences:
        word_indices = []
        char_indices = []
        tag_indices = []

        for word, char, tag in sentence:
            word_count += 1
            if word in word_to_id:
                word_index = word_to_id[word]
            elif word.lower() in word_to_id:
                word_index = word_to_id[word.lower()]
            else:
                word_index = unk_index
                unk_word_count += 1
            char_index = []
            for x in char:
                char_index.append(char_to_id[x])
            # Get the label and map to int
            word_indices.append(word_index)
            char_indices.append(char_index)
            tag_indices.append(tag_to_id[tag])

        dataset.append([word_indices, char_indices, tag_indices])

    return dataset

# %%
def padding(sentences):
    maxlen = 52
    for sentence in sentences:
        char = sentence[1]
        for x in char:
            maxlen = max(maxlen, len(x))
    for i, sentence in enumerate(sentences):
        sentences[i][1] = keras.preprocessing.sequence.pad_sequences(sentences[i][1], 52, padding='post')
    return sentences

# %%
train_set = padding(create_dataset(train_sentences, word_to_id, indexes, char_to_id))
dev_set = padding(create_dataset(dev_sentences, word_to_id, indexes, char_to_id))
test_set = padding(create_dataset(test_sentences, word_to_id, indexes, char_to_id))

# %%
def unpack(dataset):
    words=[]
    chars=[]
    tags = []
    for word, char, tag in dataset:
        words.append(word)
        chars.append(char)
        tags.append(tag)
  
    words = keras.preprocessing.sequence.pad_sequences(words, 52, padding='post')
    chars = keras.preprocessing.sequence.pad_sequences(chars, 52, padding='post')
    tags = keras.preprocessing.sequence.pad_sequences(tags, 52, padding='post')
    tags = keras.utils.to_categorical(tags, num_classes=10)
    return words, chars, tags

# %%
train_words, train_chars, train_tags = unpack(train_set)
valid_words, valid_chars, valid_tags = unpack(dev_set)
test_words, test_chars, test_tags = unpack(test_set)

# %%
train_words.shape, train_chars.shape, train_tags.shape
# Out:
# ((135701, 52), (135701, 52, 52), (135701, 52, 10))

# %% [markdown]
# ## Define Model
# Le modèle qui est mis en œuvre dans ce projet utilise les architectures suivantes:
# - Convolution Neural Network pour le niveau de caractère Représentation des mots
# - Bidirectional LSTM pour le Word Encoding
# - Conditional Random Fields (CRF Layer) pour output decodings.

# %%
from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Define Model Layers
char_input = Input(shape=(None, 52,), name="char_input")
char_embed = TimeDistributed(Embedding(len(char_to_id), 30, embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5)), name="char_embed")(char_input)
char_dropout = Dropout(0.5)(char_embed)
char_cnn = TimeDistributed(Conv1D(kernel_size=3, filters=30, padding='same', activation='tanh', strides=1), name="conv1d")(char_dropout)
maxpool_out = TimeDistributed(MaxPooling1D(52), name="maxpool")(char_cnn)
char_flat = TimeDistributed(Flatten(), name="flatten")(maxpool_out)
char = Dropout(0.5)(char_flat)
words_input = Input(shape=(None,), dtype='int32', name='words_input')
words = Embedding(input_dim=word_embeddings.shape[0], output_dim=word_embeddings.shape[1], weights=[word_embeddings],trainable=False)(words_input)
concat = concatenate([words, char])
lstm = Bidirectional(LSTM(200, return_sequences=True, dropout=0.5,recurrent_dropout=0.25), name="bilstm")(concat)
out = TimeDistributed(Dense(len(tag_to_id), activation='softmax'),name="softmax_layer")(lstm)
crf_layer = CRF(10)
output = crf_layer(out)

# Define Model Inputs and Output
model = keras.models.Model([char_input,words_input],output)
# Compile Model
model.compile(optimizer='adam', loss=crf_loss, metrics=[crf_viterbi_accuracy])
# Model Summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# char_input (InputLayer)         (None, None, 52)     0
# __________________________________________________________________________________________________
# char_embed (TimeDistributed)    (None, None, 52, 30) 2910        char_input[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 52, 30) 0           char_embed[0][0]
# __________________________________________________________________________________________________
# conv1d (TimeDistributed)        (None, None, 52, 30) 2730        dropout_1[0][0]
# __________________________________________________________________________________________________
# maxpool (TimeDistributed)       (None, None, 1, 30)  0           conv1d[0][0]
# __________________________________________________________________________________________________
# words_input (InputLayer)        (None, None)         0
# __________________________________________________________________________________________________
# flatten (TimeDistributed)       (None, None, 30)     0           maxpool[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 50)     380900      words_input[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 30)     0           flatten[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 80)     0           embedding_2[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# bilstm (Bidirectional)          (None, None, 400)    449600      concatenate_1[0][0]
# __________________________________________________________________________________________________
# softmax_layer (TimeDistributed) (None, None, 6)      2406        bilstm[0][0]
# __________________________________________________________________________________________________
# crf_1 (CRF)                     (None, None, 10)     190         softmax_layer[0][0]
# ==================================================================================================
# Total params: 838,736
# Trainable params: 457,836
# Non-trainable params: 380,900
# __________________________________________________________________________________________________

# %%
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Training

# %%
history = model.fit([train_chars,train_words], train_tags,validation_data=[[valid_chars, valid_words], valid_tags],batch_size=64,epochs=60,verbose=1)
# Out:
# /home/user/anaconda/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 135701 samples, validate on 23969 samples
# Epoch 1/60
# 135701/135701 [==============================] - 507s 4ms/step - loss: 0.1952 - crf_viterbi_accuracy: 0.9920 - val_loss: 0.0425 - val_crf_viterbi_accuracy: 0.9985
# Epoch 2/60
# 135701/135701 [==============================] - 499s 4ms/step - loss: 0.0352 - crf_viterbi_accuracy: 0.9984 - val_loss: 0.0284 - val_crf_viterbi_accuracy: 0.9985
# Epoch 3/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: 0.0215 - crf_viterbi_accuracy: 0.9985 - val_loss: 0.0251 - val_crf_viterbi_accuracy: 0.9903
# Epoch 4/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.0036 - crf_viterbi_accuracy: 0.9985 - val_loss: -0.0221 - val_crf_viterbi_accuracy: 0.9987
# Epoch 5/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.0423 - crf_viterbi_accuracy: 0.9986 - val_loss: -0.0642 - val_crf_viterbi_accuracy: 0.9987
# Epoch 6/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.0850 - crf_viterbi_accuracy: 0.9986 - val_loss: -0.1067 - val_crf_viterbi_accuracy: 0.9988
# Epoch 7/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.1272 - crf_viterbi_accuracy: 0.9987 - val_loss: -0.1485 - val_crf_viterbi_accuracy: 0.9988
# Epoch 8/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.1687 - crf_viterbi_accuracy: 0.9987 - val_loss: -0.1899 - val_crf_viterbi_accuracy: 0.9989
# Epoch 9/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.2100 - crf_viterbi_accuracy: 0.9988 - val_loss: -0.2310 - val_crf_viterbi_accuracy: 0.9990
# Epoch 10/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.2511 - crf_viterbi_accuracy: 0.9988 - val_loss: -0.2720 - val_crf_viterbi_accuracy: 0.9990
# Epoch 11/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -0.2920 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.3129 - val_crf_viterbi_accuracy: 0.9990
# Epoch 12/60
# 135701/135701 [==============================] - 499s 4ms/step - loss: -0.3329 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.3538 - val_crf_viterbi_accuracy: 0.9990
# Epoch 13/60
# 135701/135701 [==============================] - 499s 4ms/step - loss: -0.3737 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.3946 - val_crf_viterbi_accuracy: 0.9990
# Epoch 14/60
# 135701/135701 [==============================] - 498s 4ms/step - loss: -0.4145 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.4354 - val_crf_viterbi_accuracy: 0.9990
# Epoch 15/60
# 135701/135701 [==============================] - 497s 4ms/step - loss: -0.4554 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.4762 - val_crf_viterbi_accuracy: 0.9990
# Epoch 16/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -0.4962 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.5170 - val_crf_viterbi_accuracy: 0.9990
# Epoch 17/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -0.5370 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.5579 - val_crf_viterbi_accuracy: 0.9990
# Epoch 18/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -0.5778 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.5986 - val_crf_viterbi_accuracy: 0.9990
# Epoch 19/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -0.6186 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.6394 - val_crf_viterbi_accuracy: 0.9990
# Epoch 20/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -0.6593 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.6802 - val_crf_viterbi_accuracy: 0.9990
# Epoch 21/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.7001 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.7209 - val_crf_viterbi_accuracy: 0.9990
# Epoch 22/60
# 135701/135701 [==============================] - 506s 4ms/step - loss: -0.7409 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.7617 - val_crf_viterbi_accuracy: 0.9990
# Epoch 23/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.7817 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.8025 - val_crf_viterbi_accuracy: 0.9990
# Epoch 24/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.8225 - crf_viterbi_accuracy: 0.9990 - val_loss: -0.8433 - val_crf_viterbi_accuracy: 0.9990
# Epoch 25/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.8633 - crf_viterbi_accuracy: 0.9989 - val_loss: -0.8840 - val_crf_viterbi_accuracy: 0.9990
# Epoch 26/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.9041 - crf_viterbi_accuracy: 0.9990 - val_loss: -0.9248 - val_crf_viterbi_accuracy: 0.9991
# Epoch 27/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.9449 - crf_viterbi_accuracy: 0.9990 - val_loss: -0.9655 - val_crf_viterbi_accuracy: 0.9990
# Epoch 28/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -0.9856 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.0064 - val_crf_viterbi_accuracy: 0.9991
# Epoch 29/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -1.0264 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.0471 - val_crf_viterbi_accuracy: 0.9990
# Epoch 30/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -1.0672 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.0879 - val_crf_viterbi_accuracy: 0.9990
# Epoch 31/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -1.1080 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.1287 - val_crf_viterbi_accuracy: 0.9991
# Epoch 32/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -1.1487 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.1695 - val_crf_viterbi_accuracy: 0.9991
# Epoch 33/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -1.1895 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.2102 - val_crf_viterbi_accuracy: 0.9991
# Epoch 34/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.2303 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.2510 - val_crf_viterbi_accuracy: 0.9990
# Epoch 35/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.2711 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.2918 - val_crf_viterbi_accuracy: 0.9990
# Epoch 36/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.3118 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.3325 - val_crf_viterbi_accuracy: 0.9991
# Epoch 37/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.3526 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.3733 - val_crf_viterbi_accuracy: 0.9990
# Epoch 38/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.3934 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.4141 - val_crf_viterbi_accuracy: 0.9991
# Epoch 39/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.4342 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.4548 - val_crf_viterbi_accuracy: 0.9990
# Epoch 40/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.4750 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.4957 - val_crf_viterbi_accuracy: 0.9991
# Epoch 41/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.5157 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.5364 - val_crf_viterbi_accuracy: 0.9990
# Epoch 42/60
# 135701/135701 [==============================] - 497s 4ms/step - loss: -1.5565 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.5771 - val_crf_viterbi_accuracy: 0.9991
# Epoch 43/60
# 135701/135701 [==============================] - 499s 4ms/step - loss: -1.5973 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.6179 - val_crf_viterbi_accuracy: 0.9990
# Epoch 44/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.6380 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.6587 - val_crf_viterbi_accuracy: 0.9991
# Epoch 45/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.6788 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.6995 - val_crf_viterbi_accuracy: 0.9991
# Epoch 46/60
# 135701/135701 [==============================] - 501s 4ms/step - loss: -1.7196 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.7402 - val_crf_viterbi_accuracy: 0.9991
# Epoch 47/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.7604 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.7810 - val_crf_viterbi_accuracy: 0.9990
# Epoch 48/60
# 135701/135701 [==============================] - 493s 4ms/step - loss: -1.8011 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.8218 - val_crf_viterbi_accuracy: 0.9990
# Epoch 49/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.8419 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.8626 - val_crf_viterbi_accuracy: 0.9991
# Epoch 50/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -1.8827 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.9033 - val_crf_viterbi_accuracy: 0.9991
# Epoch 51/60
# 135701/135701 [==============================] - 510s 4ms/step - loss: -1.9234 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.9441 - val_crf_viterbi_accuracy: 0.9990
# Epoch 52/60
# 135701/135701 [==============================] - 497s 4ms/step - loss: -1.9642 - crf_viterbi_accuracy: 0.9990 - val_loss: -1.9848 - val_crf_viterbi_accuracy: 0.9991
# Epoch 53/60
# 135701/135701 [==============================] - 500s 4ms/step - loss: -2.0050 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.0256 - val_crf_viterbi_accuracy: 0.9990
# Epoch 54/60
# 135701/135701 [==============================] - 495s 4ms/step - loss: -2.0457 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.0664 - val_crf_viterbi_accuracy: 0.9991
# Epoch 55/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -2.0865 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.1072 - val_crf_viterbi_accuracy: 0.9990
# Epoch 56/60
# 135701/135701 [==============================] - 494s 4ms/step - loss: -2.1273 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.1479 - val_crf_viterbi_accuracy: 0.9990
# Epoch 57/60
# 135701/135701 [==============================] - 496s 4ms/step - loss: -2.1681 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.1887 - val_crf_viterbi_accuracy: 0.9991
# Epoch 58/60
# 135701/135701 [==============================] - 519s 4ms/step - loss: -2.2088 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.2294 - val_crf_viterbi_accuracy: 0.9991
# Epoch 59/60
# 135701/135701 [==============================] - 506s 4ms/step - loss: -2.2496 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.2702 - val_crf_viterbi_accuracy: 0.9991
# Epoch 60/60
# 135701/135701 [==============================] - 506s 4ms/step - loss: -2.2903 - crf_viterbi_accuracy: 0.9990 - val_loss: -2.3110 - val_crf_viterbi_accuracy: 0.9991

# %% [markdown]
# ## Training and Testing Accuracy

# %%
_, train_acc = model.evaluate([train_chars, train_words],train_tags)
_, val_acc = model.evaluate([valid_chars, valid_words], valid_tags)
_, test_acc = model.evaluate([test_chars, test_words],test_tags)

print('Training Accuray: ', train_acc * 100)
print('Validation Accuray: ', val_acc * 100)
print('Testing Accuray: ', test_acc * 100)
# Out:
# 135701/135701 [==============================] - 163s 1ms/step
# 23969/23969 [==============================] - 29s 1ms/step
# 24497/24497 [==============================] - 29s 1ms/step
# Training Accuray:  99.91264939308167
# Validation Accuray:  99.90820288658142
# Testing Accuray:  99.90118741989136

# %%
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Evaluation Metrics Report
# Nous allons maintenant utiliser Precision, Recall et F1 score our évaluer la performance de notre modèle sur chaque tag.

# %%
# Evaluate
pred_cat = model.predict([test_chars,test_words])
predicted = [[[np.argmax(i)] for i in w] for w in pred_cat]
predicted = np.array(predicted)
actual = [[[np.argmax(i)] for i in w] for w in test_tags]
actual = np.array(actual)
# Convert the index to tag
predicted_tag = [[id_to_tag[i[0]] for i in row] for row in predicted]
actual_tag = [[id_to_tag[i[0]] for i in row] for row in actual]

# Metrics Report
report = flat_classification_report(y_pred=predicted_tag, y_true=actual_tag)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#    B-Disease       0.67      0.46      0.55       537
#    E-Disease       0.62      0.73      0.67       537
#    I-Disease       0.70      0.13      0.23       550
#            O       0.97      0.99      0.98     22450
#      PADDING       1.00      1.00      1.00   1249347
#    S-Disease       0.71      0.68      0.70       423
#
#     accuracy                           1.00   1273844
#    macro avg       0.78      0.67      0.69   1273844
# weighted avg       1.00      1.00      1.00   1273844

# %%
from sklearn_crfsuite.metrics import sequence_accuracy_score,flat_accuracy_score, flat_recall_score,flat_f1_score
flat_f1_score(predicted_tag, actual_tag, average='weighted')
# Out:
# 0.9991636094075647

# %% [markdown]
# ## Accuracy Curve

# %%
# Plotting Training vs Validation Accuracy
plt.plot(history.history['crf_viterbi_accuracy'])  
plt.plot(history.history['val_crf_viterbi_accuracy'])  
plt.title('Train vs Validation Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation']) 
plt.show()

# %% [markdown]
# ## Loss Curve

# %%
# Plotting Training vs Validation Accuracy
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('Train vs Validation Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation']) 
plt.show()

# %% [markdown]
# ## Testing

# %%
good_example = []
bad_example = []

for i in range(1000):
    for j in range(1):
        if test_words[i][j] != 0:
            word = id_to_word[test_words[i][j]]
            a_tag = actual_tag[i][j]
            p_tag = predicted_tag[i][j]
        if a_tag == p_tag:
            good_example.append([word, p_tag, a_tag])
        else:
            bad_example.append([word, p_tag, a_tag])

col1_width = max([len(x[0]) for x in good_example])
col2_width = max([len(x[1]) for x in good_example])
col3_width = max([len(x[2]) for x in good_example])

print("-------- Good Examples --------")
print ("|{0:<{col1}}  |{1:<{col2}}  |{2:<{col3}}  |".format("Word","Actual","Predicted",col1=col1_width,col2=col2_width,col3=col3_width))

for word, p_tag, a_tag in good_example:
    print ("|{0:<{col1}}  |{1:<{col2}}   |{2:<{col3}}      |".format(word,a_tag,p_tag,col1=col1_width,col2=col2_width,col3=col3_width))
# Out:
# -------- Good Examples --------
# |Word              |Actual     |Predicted  |
# |clustering        |O           |O              |
# |of                |O           |O              |
# |missense          |O           |O              |
# |mutations         |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |telangiectasia    |E-Disease   |E-Disease      |
# |gene              |O           |O              |
# |in                |O           |O              |
# |a                 |O           |O              |
# |.                 |O           |O              |
# |telangiectasia    |E-Disease   |E-Disease      |
# |(                 |O           |O              |
# |)                 |O           |O              |
# |is                |O           |O              |
# |a                 |O           |O              |
# |disorder          |E-Disease   |E-Disease      |
# |caused            |O           |O              |
# |by                |O           |O              |
# |mutations         |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |atm               |O           |O              |
# |gene              |O           |O              |
# |at                |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |-                 |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |(                 |O           |O              |
# |ref               |O           |O              |
# |.                 |O           |O              |
# |3                 |O           |O              |
# |)                 |O           |O              |
# |.                 |O           |O              |
# |the               |O           |O              |
# |risk              |O           |O              |
# |of                |O           |O              |
# |,                 |O           |O              |
# |especially        |O           |O              |
# |,                 |O           |O              |
# |is                |O           |O              |
# |substantially     |O           |O              |
# |elevated          |O           |O              |
# |in                |O           |O              |
# |patients          |O           |O              |
# |and               |O           |O              |
# |has               |O           |O              |
# |long              |O           |O              |
# |been              |O           |O              |
# |associated        |O           |O              |
# |with              |O           |O              |
# |chromosomal       |O           |O              |
# |instability       |O           |O              |
# |.                 |O           |O              |
# |by                |O           |O              |
# |analysing         |O           |O              |
# |tumour            |S-Disease   |S-Disease      |
# |dna               |O           |O              |
# |from              |O           |O              |
# |patients          |O           |O              |
# |with              |O           |O              |
# |(                 |O           |O              |
# |)                 |O           |O              |
# |,                 |O           |O              |
# |a                 |O           |O              |
# |rare              |O           |O              |
# |with              |O           |O              |
# |similarities      |O           |O              |
# |to                |O           |O              |
# |a                 |O           |O              |
# |seen              |O           |O              |
# |in                |O           |O              |
# |,                 |O           |O              |
# |we                |O           |O              |
# |demonstrate       |O           |O              |
# |a                 |O           |O              |
# |high              |O           |O              |
# |frequency         |O           |O              |
# |of                |O           |O              |
# |atm               |O           |O              |
# |mutations         |O           |O              |
# |in                |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |marked            |O           |O              |
# |contrast          |O           |O              |
# |to                |O           |O              |
# |the               |O           |O              |
# |atm               |O           |O              |
# |mutation          |O           |O              |
# |pattern           |O           |O              |
# |in                |O           |O              |
# |,                 |O           |O              |
# |the               |O           |O              |
# |most              |O           |O              |
# |frequent          |O           |O              |
# |nucleotide        |O           |O              |
# |changes           |O           |O              |
# |in                |O           |O              |
# |this              |O           |O              |
# |leukaemia         |S-Disease   |S-Disease      |
# |were              |O           |O              |
# |missense          |O           |O              |
# |mutations         |O           |O              |
# |.                 |O           |O              |
# |these             |O           |O              |
# |clustered         |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |region            |O           |O              |
# |corresponding     |O           |O              |
# |to                |O           |O              |
# |the               |O           |O              |
# |kinase            |O           |O              |
# |domain            |O           |O              |
# |,                 |O           |O              |
# |which             |O           |O              |
# |is                |O           |O              |
# |highly            |O           |O              |
# |conserved         |O           |O              |
# |in                |O           |O              |
# |atm               |O           |O              |
# |-                 |O           |O              |
# |related           |O           |O              |
# |proteins          |O           |O              |
# |in                |O           |O              |
# |mouse             |O           |O              |
# |,                 |O           |O              |
# |yeast             |O           |O              |
# |and               |O           |O              |
# |drosophila        |O           |O              |
# |.                 |O           |O              |
# |the               |O           |O              |
# |resulting         |O           |O              |
# |amino             |O           |O              |
# |-                 |O           |O              |
# |acid              |O           |O              |
# |substitutions     |O           |O              |
# |are               |O           |O              |
# |predicted         |O           |O              |
# |to                |O           |O              |
# |interfere         |O           |O              |
# |with              |O           |O              |
# |atp               |O           |O              |
# |binding           |O           |O              |
# |or                |O           |O              |
# |substrate         |O           |O              |
# |recognition       |O           |O              |
# |.                 |O           |O              |
# |two               |O           |O              |
# |of                |O           |O              |
# |seventeen         |O           |O              |
# |mutated           |O           |O              |
# |samples           |O           |O              |
# |had               |O           |O              |
# |a                 |O           |O              |
# |previously        |O           |O              |
# |reported          |O           |O              |
# |allele            |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |contrast          |O           |O              |
# |,                 |O           |O              |
# |no                |O           |O              |
# |mutations         |O           |O              |
# |were              |O           |O              |
# |detected          |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |p53               |O           |O              |
# |gene              |O           |O              |
# |,                 |O           |O              |
# |suggesting        |O           |O              |
# |that              |O           |O              |
# |this              |O           |O              |
# |tumour            |S-Disease   |S-Disease      |
# |suppressor        |O           |O              |
# |is                |O           |O              |
# |not               |O           |O              |
# |frequently        |O           |O              |
# |altered           |O           |O              |
# |in                |O           |O              |
# |this              |O           |O              |
# |leukaemia         |S-Disease   |S-Disease      |
# |.                 |O           |O              |
# |occasional        |O           |O              |
# |missense          |O           |O              |
# |mutations         |O           |O              |
# |in                |O           |O              |
# |atm               |O           |O              |
# |were              |O           |O              |
# |also              |O           |O              |
# |found             |O           |O              |
# |in                |O           |O              |
# |tumour            |S-Disease   |S-Disease      |
# |dna               |O           |O              |
# |from              |O           |O              |
# |patients          |O           |O              |
# |with              |O           |O              |
# |lymphomas         |E-Disease   |E-Disease      |
# |(                 |O           |O              |
# |)                 |O           |O              |
# |and               |O           |O              |
# |a                 |O           |O              |
# |cell              |O           |O              |
# |line              |O           |O              |
# |.                 |O           |O              |
# |the               |O           |O              |
# |evidence          |O           |O              |
# |of                |O           |O              |
# |a                 |O           |O              |
# |significant       |O           |O              |
# |proportion        |O           |O              |
# |of                |O           |O              |
# |loss              |O           |O              |
# |-                 |O           |O              |
# |of                |O           |O              |
# |-                 |O           |O              |
# |function          |O           |O              |
# |mutations         |O           |O              |
# |and               |O           |O              |
# |a                 |O           |O              |
# |complete          |O           |O              |
# |absence           |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |normal            |O           |O              |
# |copy              |O           |O              |
# |of                |O           |O              |
# |atm               |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |majority          |O           |O              |
# |of                |O           |O              |
# |mutated           |O           |O              |
# |establishes       |O           |O              |
# |somatic           |O           |O              |
# |inactivation      |O           |O              |
# |of                |O           |O              |
# |this              |O           |O              |
# |gene              |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |pathogenesis      |O           |O              |
# |of                |O           |O              |
# |and               |O           |O              |
# |suggests          |O           |O              |
# |that              |O           |O              |
# |atm               |O           |O              |
# |acts              |O           |O              |
# |as                |O           |O              |
# |a                 |O           |O              |
# |tumour            |S-Disease   |S-Disease      |
# |suppressor        |O           |O              |
# |.                 |O           |O              |
# |as                |O           |O              |
# |constitutional    |O           |O              |
# |dna               |O           |O              |
# |was               |O           |O              |
# |not               |O           |O              |
# |available         |O           |O              |
# |,                 |O           |O              |
# |a                 |O           |O              |
# |putative          |O           |O              |
# |predisposition    |O           |O              |
# |to                |O           |O              |
# |will              |O           |O              |
# |require           |O           |O              |
# |further           |O           |O              |
# |investigation     |O           |O              |
# |.                 |O           |O              |
# |.                 |O           |O              |
# |myotonic          |B-Disease   |B-Disease      |
# |dystrophy         |E-Disease   |E-Disease      |
# |protein           |O           |O              |
# |kinase            |O           |O              |
# |is                |O           |O              |
# |involved          |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |modulation        |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |homeostasis       |O           |O              |
# |in                |O           |O              |
# |skeletal          |O           |O              |
# |muscle            |O           |O              |
# |cells             |O           |O              |
# |.                 |O           |O              |
# |myotonic          |B-Disease   |B-Disease      |
# |dystrophy         |E-Disease   |E-Disease      |
# |(                 |O           |O              |
# |dm                |S-Disease   |S-Disease      |
# |)                 |O           |O              |
# |,                 |O           |O              |
# |the               |O           |O              |
# |most              |O           |O              |
# |prevalent         |O           |O              |
# |disorder          |E-Disease   |E-Disease      |
# |in                |O           |O              |
# |adults            |O           |O              |
# |,                 |O           |O              |
# |is                |O           |O              |
# |caused            |O           |O              |
# |by                |O           |O              |
# |(                 |O           |O              |
# |ctg               |O           |O              |
# |)                 |O           |O              |
# |n                 |O           |O              |
# |-                 |O           |O              |
# |repeat            |O           |O              |
# |expansion         |O           |O              |
# |in                |O           |O              |
# |a                 |O           |O              |
# |gene              |O           |O              |
# |encoding          |O           |O              |
# |a                 |O           |O              |
# |protein           |O           |O              |
# |kinase            |O           |O              |
# |(                 |O           |O              |
# |dm                |S-Disease   |S-Disease      |
# |protein           |O           |O              |
# |kinase            |O           |O              |
# |;                 |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |)                 |O           |O              |
# |and               |O           |O              |
# |involves          |O           |O              |
# |changes           |O           |O              |
# |in                |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |and               |O           |O              |
# |ion               |O           |O              |
# |homeostasis       |O           |O              |
# |.                 |O           |O              |
# |to                |O           |O              |
# |obtain            |O           |O              |
# |clues             |O           |O              |
# |to                |O           |O              |
# |the               |O           |O              |
# |normal            |O           |O              |
# |biological        |O           |O              |
# |role              |O           |O              |
# |of                |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |in                |O           |O              |
# |cellular          |O           |O              |
# |ion               |O           |O              |
# |homeostasis       |O           |O              |
# |,                 |O           |O              |
# |we                |O           |O              |
# |have              |O           |O              |
# |compared          |O           |O              |
# |the               |O           |O              |
# |resting           |O           |O              |
# |[                 |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |]                 |O           |O              |
# |i                 |O           |O              |
# |,                 |O           |O              |
# |the               |O           |O              |
# |amplitude         |O           |O              |
# |and               |O           |O              |
# |shape             |O           |O              |
# |of                |O           |O              |
# |depolarization    |O           |O              |
# |-                 |O           |O              |
# |induced           |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |transients        |O           |O              |
# |,                 |O           |O              |
# |and               |O           |O              |
# |the               |O           |O              |
# |content           |O           |O              |
# |of                |O           |O              |
# |atp               |O           |O              |
# |-                 |O           |O              |
# |driven            |O           |O              |
# |ion               |O           |O              |
# |pumps             |O           |O              |
# |in                |O           |O              |
# |cultured          |O           |O              |
# |skeletal          |O           |O              |
# |muscle            |O           |O              |
# |cells             |O           |O              |
# |of                |O           |O              |
# |wild              |O           |O              |
# |-                 |O           |O              |
# |type              |O           |O              |
# |and               |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |[                 |O           |O              |
# |-                 |O           |O              |
# |/                 |O           |O              |
# |-                 |O           |O              |
# |]                 |O           |O              |
# |knockout          |O           |O              |
# |mice              |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |vitro             |O           |O              |
# |-                 |O           |O              |
# |differentiated    |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |[                 |O           |O              |
# |-                 |O           |O              |
# |/                 |O           |O              |
# |-                 |O           |O              |
# |]                 |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |exhibit           |O           |O              |
# |a                 |O           |O              |
# |higher            |O           |O              |
# |resting           |O           |O              |
# |[                 |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |]                 |O           |O              |
# |i                 |O           |O              |
# |than              |O           |O              |
# |do                |O           |O              |
# |wild              |O           |O              |
# |-                 |O           |O              |
# |type              |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |because           |O           |O              |
# |of                |O           |O              |
# |an                |O           |O              |
# |altered           |O           |O              |
# |open              |O           |O              |
# |probability       |O           |O              |
# |of                |O           |O              |
# |voltage           |O           |O              |
# |-                 |O           |O              |
# |dependent         |O           |O              |
# |l                 |O           |O              |
# |-                 |O           |O              |
# |type              |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |and               |O           |O              |
# |na                |O           |O              |
# |+                 |O           |O              |
# |channels          |O           |O              |
# |.                 |O           |O              |
# |the               |O           |O              |
# |mutant            |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |exhibit           |O           |O              |
# |smaller           |O           |O              |
# |and               |O           |O              |
# |slower            |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |responses         |O           |O              |
# |upon              |O           |O              |
# |triggering        |O           |O              |
# |by                |O           |O              |
# |acetylcholine     |O           |O              |
# |or                |O           |O              |
# |high              |O           |O              |
# |external          |O           |O              |
# |k                 |O           |O              |
# |+                 |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |addition          |O           |O              |
# |,                 |O           |O              |
# |we                |O           |O              |
# |observed          |O           |O              |
# |that              |O           |O              |
# |these             |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |transients        |O           |O              |
# |partially         |O           |O              |
# |result            |O           |O              |
# |from              |O           |O              |
# |an                |O           |O              |
# |influx            |O           |O              |
# |of                |O           |O              |
# |extracellular     |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |through           |O           |O              |
# |the               |O           |O              |
# |l                 |O           |O              |
# |-                 |O           |O              |
# |type              |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |channel           |O           |O              |
# |.                 |O           |O              |
# |neither           |O           |O              |
# |the               |O           |O              |
# |content           |O           |O              |
# |nor               |O           |O              |
# |the               |O           |O              |
# |activity          |O           |O              |
# |of                |O           |O              |
# |na                |O           |O              |
# |+                 |O           |O              |
# |/                 |O           |O              |
# |k                 |O           |O              |
# |+                 |O           |O              |
# |atpase            |O           |O              |
# |and               |O           |O              |
# |sarcoplasmic      |O           |O              |
# |reticulum         |O           |O              |
# |ca2               |O           |O              |
# |+                 |O           |O              |
# |-                 |O           |O              |
# |atpase            |O           |O              |
# |are               |O           |O              |
# |affected          |O           |O              |
# |by                |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |absence           |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |conclusion        |O           |O              |
# |,                 |O           |O              |
# |our               |O           |O              |
# |data              |O           |O              |
# |suggest           |O           |O              |
# |that              |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |is                |O           |O              |
# |involved          |O           |O              |
# |in                |O           |O              |
# |modulating        |O           |O              |
# |the               |O           |O              |
# |initial           |O           |O              |
# |events            |O           |O              |
# |of                |O           |O              |
# |excitation        |O           |O              |
# |-                 |O           |O              |
# |contraction       |O           |O              |
# |coupling          |O           |O              |
# |in                |O           |O              |
# |skeletal          |O           |O              |
# |muscle            |O           |O              |
# |.                 |O           |O              |
# |.                 |O           |O              |
# |constitutional    |O           |O              |
# |rb1               |O           |O              |
# |-                 |O           |O              |
# |gene              |O           |O              |
# |mutations         |O           |O              |
# |in                |O           |O              |
# |patients          |O           |O              |
# |with              |O           |O              |
# |isolated          |O           |O              |
# |unilateral        |B-Disease   |B-Disease      |
# |.                 |O           |O              |
# |in                |O           |O              |
# |most              |O           |O              |
# |patients          |O           |O              |
# |with              |O           |O              |
# |isolated          |O           |O              |
# |unilateral        |B-Disease   |B-Disease      |
# |,                 |O           |O              |
# |development       |O           |O              |
# |is                |O           |O              |
# |initiated         |O           |O              |
# |by                |O           |O              |
# |somatic           |O           |O              |
# |inactivation      |O           |O              |
# |of                |O           |O              |
# |both              |O           |O              |
# |alleles           |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |rb1               |O           |O              |
# |gene              |O           |O              |
# |.                 |O           |O              |
# |however           |O           |O              |
# |,                 |O           |O              |
# |some              |O           |O              |
# |of                |O           |O              |
# |these             |O           |O              |
# |patients          |O           |O              |
# |can               |O           |O              |
# |transmit          |O           |O              |
# |retinoblastoma    |S-Disease   |S-Disease      |
# |predisposition    |O           |O              |
# |to                |O           |O              |
# |their             |O           |O              |
# |offspring         |O           |O              |
# |.                 |O           |O              |
# |to                |O           |O              |
# |determine         |O           |O              |
# |the               |O           |O              |
# |frequency         |O           |O              |
# |and               |O           |O              |
# |nature            |O           |O              |
# |of                |O           |O              |
# |constitutional    |O           |O              |
# |rb1               |O           |O              |
# |-                 |O           |O              |
# |gene              |O           |O              |
# |mutations         |O           |O              |
# |in                |O           |O              |
# |patients          |O           |O              |
# |with              |O           |O              |
# |isolated          |O           |O              |
# |unilateral        |B-Disease   |B-Disease      |
# |,                 |O           |O              |
# |we                |O           |O              |
# |analyzed          |O           |O              |
# |dna               |O           |O              |
# |from              |O           |O              |
# |peripheral        |O           |O              |
# |blood             |O           |O              |
# |and               |O           |O              |
# |from              |O           |O              |
# |tissue            |O           |O              |
# |.                 |O           |O              |
# |the               |O           |O              |
# |analysis          |O           |O              |
# |of                |O           |O              |
# |from              |O           |O              |
# |54                |O           |O              |
# |(                 |O           |O              |
# |71                |O           |O              |
# |%                 |O           |O              |
# |)                 |O           |O              |
# |of                |O           |O              |
# |76                |O           |O              |
# |informative       |O           |O              |
# |patients          |O           |O              |
# |showed            |O           |O              |
# |loss              |O           |O              |
# |of                |O           |O              |
# |constitutional    |O           |O              |
# |heterozygosity    |O           |O              |
# |(                 |O           |O              |
# |loh               |O           |O              |
# |)                 |O           |O              |
# |at                |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |loci              |O           |O              |
# |.                 |O           |O              |
# |three             |O           |O              |
# |of                |O           |O              |
# |13                |O           |O              |
# |uninformative     |O           |O              |
# |patients          |O           |O              |
# |had               |O           |O              |
# |constitutional    |O           |O              |
# |deletions         |O           |O              |
# |.                 |O           |O              |
# |for               |O           |O              |
# |39                |O           |O              |
# |randomly          |O           |O              |
# |selected          |O           |O              |
# |,                 |O           |O              |
# |UNKNOWN_TOKEN     |O           |O              |
# |,                 |O           |O              |
# |hetero            |O           |O              |
# |-                 |O           |O              |
# |duplex            |O           |O              |
# |analysis          |O           |O              |
# |,                 |O           |O              |
# |sequencing        |O           |O              |
# |,                 |O           |O              |
# |and               |O           |O              |
# |southern          |O           |O              |
# |blot              |O           |O              |
# |analysis          |O           |O              |
# |were              |O           |O              |
# |used              |O           |O              |
# |to                |O           |O              |
# |identify          |O           |O              |
# |mutations         |O           |O              |
# |.                 |O           |O              |
# |mutations         |O           |O              |
# |were              |O           |O              |
# |detected          |O           |O              |
# |in                |O           |O              |
# |21                |O           |O              |
# |(                 |O           |O              |
# |91                |O           |O              |
# |%                 |O           |O              |
# |)                 |O           |O              |
# |of                |O           |O              |
# |23                |O           |O              |
# |with              |O           |O              |
# |loh               |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |6                 |O           |O              |
# |(                 |O           |O              |
# |38                |O           |O              |
# |%                 |O           |O              |
# |)                 |O           |O              |
# |of                |O           |O              |
# |16                |O           |O              |
# |without           |O           |O              |
# |loh               |O           |O              |
# |,                 |O           |O              |
# |one               |O           |O              |
# |mutation          |O           |O              |
# |was               |O           |O              |
# |detected          |O           |O              |
# |,                 |O           |O              |
# |and               |O           |O              |
# |in                |O           |O              |
# |9                 |O           |O              |
# |(                 |O           |O              |
# |56                |O           |O              |
# |%                 |O           |O              |
# |)                 |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |without           |O           |O              |
# |loh               |O           |O              |
# |,                 |O           |O              |
# |both              |O           |O              |
# |mutations         |O           |O              |
# |were              |O           |O              |
# |found             |O           |O              |
# |.                 |O           |O              |
# |thus              |O           |O              |
# |,                 |O           |O              |
# |a                 |O           |O              |
# |total             |O           |O              |
# |of                |O           |O              |
# |45                |O           |O              |
# |mutations         |O           |O              |
# |were              |O           |O              |
# |identified        |O           |O              |
# |in                |O           |O              |
# |of                |O           |O              |
# |36                |O           |O              |
# |patients          |O           |O              |
# |.                 |O           |O              |
# |thirty            |O           |O              |
# |-                 |O           |O              |
# |nine              |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |mutations         |O           |O              |
# |-                 |O           |O              |
# |including         |O           |O              |
# |34                |O           |O              |
# |small             |O           |O              |
# |mutations         |O           |O              |
# |,                 |O           |O              |
# |2                 |O           |O              |
# |large             |O           |O              |
# |structural        |O           |O              |
# |alterations       |O           |O              |
# |,                 |O           |O              |
# |and               |O           |O              |
# |hypermethylation  |O           |O              |
# |in                |O           |O              |
# |3                 |O           |O              |
# |-                 |O           |O              |
# |were              |O           |O              |
# |not               |O           |O              |
# |detected          |O           |O              |
# |in                |O           |O              |
# |the               |O           |O              |
# |corresponding     |O           |O              |
# |peripheral        |O           |O              |
# |blood             |O           |O              |
# |dna               |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |6                 |O           |O              |
# |(                 |O           |O              |
# |17                |O           |O              |
# |%                 |O           |O              |
# |)                 |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |36                |O           |O              |
# |patients          |O           |O              |
# |,                 |O           |O              |
# |a                 |O           |O              |
# |mutation          |O           |O              |
# |was               |O           |O              |
# |detected          |O           |O              |
# |in                |O           |O              |
# |constitutional    |O           |O              |
# |dna               |O           |O              |
# |,                 |O           |O              |
# |and               |O           |O              |
# |1                 |O           |O              |
# |of                |O           |O              |
# |these             |O           |O              |
# |mutations         |O           |O              |
# |is                |O           |O              |
# |known             |O           |O              |
# |to                |O           |O              |
# |be                |O           |O              |
# |associated        |O           |O              |
# |with              |O           |O              |
# |reduced           |O           |O              |
# |expressivity      |O           |O              |
# |.                 |O           |O              |
# |the               |O           |O              |
# |presence          |O           |O              |
# |of                |O           |O              |
# |a                 |O           |O              |
# |constitutional    |O           |O              |
# |mutation          |O           |O              |
# |was               |O           |O              |
# |not               |O           |O              |
# |associated        |O           |O              |
# |with              |O           |O              |
# |an                |O           |O              |
# |early             |O           |O              |
# |age               |O           |O              |
# |at                |O           |O              |
# |treatment         |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |1                 |O           |O              |
# |patient           |O           |O              |
# |,                 |O           |O              |
# |somatic           |O           |O              |
# |mosaicism         |O           |O              |
# |was               |O           |O              |
# |demonstrated      |O           |O              |
# |by                |O           |O              |
# |molecular         |O           |O              |
# |analysis          |O           |O              |
# |of                |O           |O              |
# |dna               |O           |O              |
# |and               |O           |O              |
# |rna               |O           |O              |
# |from              |O           |O              |
# |peripheral        |O           |O              |
# |blood             |O           |O              |
# |.                 |O           |O              |
# |in                |O           |O              |
# |2                 |O           |O              |
# |patients          |O           |O              |
# |without           |O           |O              |
# |a                 |O           |O              |
# |detectable        |O           |O              |
# |mutation          |O           |O              |
# |in                |O           |O              |
# |peripheral        |O           |O              |
# |blood             |O           |O              |
# |,                 |O           |O              |
# |mosaicism         |O           |O              |
# |was               |O           |O              |
# |suggested         |O           |O              |
# |because           |O           |O              |
# |1                 |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |patients          |O           |O              |
# |showed            |O           |O              |
# |and               |O           |O              |
# |the               |O           |O              |
# |other             |O           |O              |
# |later             |O           |O              |
# |developed         |O           |O              |
# |bilateral         |B-Disease   |B-Disease      |
# |.                 |O           |O              |
# |in                |O           |O              |
# |conclusion        |O           |O              |
# |,                 |O           |O              |
# |our               |O           |O              |
# |results           |O           |O              |
# |emphasize         |O           |O              |
# |that              |O           |O              |
# |the               |O           |O              |
# |manifestation     |O           |O              |
# |and               |O           |O              |
# |transmissibility  |O           |O              |
# |of                |O           |O              |
# |retinoblastoma    |S-Disease   |S-Disease      |
# |depend            |O           |O              |
# |on                |O           |O              |
# |the               |O           |O              |
# |nature            |O           |O              |
# |of                |O           |O              |
# |the               |O           |O              |
# |first             |O           |O              |
# |mutation          |O           |O              |
# |,                 |O           |O              |
# |its               |O           |O              |
# |time              |O           |O              |
# |in                |O           |O              |
# |development       |O           |O              |
# |,                 |O           |O              |
# |and               |O           |O              |
# |the               |O           |O              |
# |number            |O           |O              |
# |and               |O           |O              |
# |types             |O           |O              |
# |of                |O           |O              |
# |cells             |O           |O              |
# |that              |O           |O              |
# |are               |O           |O              |
# |affected          |O           |O              |
# |.                 |O           |O              |
# |.                 |O           |O              |
# |hereditary        |B-Disease   |B-Disease      |

# %%
col1_width = max([len(x[0]) for x in bad_example])
col2_width = max([len(x[1]) for x in bad_example])
col3_width = max([len(x[2]) for x in bad_example])  

print("\n\n-------- Bad Examples --------")
print ("|{0:<{col1}}  |{1:<{col2}}  |{2:<{col3}}  |".format("Word","Actual","Predicted",col1=col1_width,col2=col2_width,col3=col3_width))

for word, p_tag, a_tag in bad_example:
    print ("|{0:<{col1}}  |{1:<{col2}}   |{2:<{col3}}      |".format(word,a_tag,p_tag,col1=col1_width,col2=col2_width,col3=col3_width))
# Out:
# -------- Bad Examples --------
# |Word            |Actual     |Predicted  |
# |ataxia          |B-Disease   |E-Disease      |
# |-               |I-Disease   |O              |
# |sporadic        |B-Disease   |O              |
# |t               |I-Disease   |O              |
# |-               |I-Disease   |O              |
# |cell            |I-Disease   |O              |
# |leukaemia       |E-Disease   |S-Disease      |
# |ataxia          |B-Disease   |E-Disease      |
# |-               |I-Disease   |O              |
# |a               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |t               |E-Disease   |O              |
# |recessive       |B-Disease   |I-Disease      |
# |multi           |I-Disease   |O              |
# |-               |I-Disease   |O              |
# |system          |I-Disease   |O              |
# |cancer          |S-Disease   |E-Disease      |
# |lymphoid        |B-Disease   |O              |
# |UNKNOWN_TOKEN   |E-Disease   |S-Disease      |
# |a               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |t               |E-Disease   |O              |
# |sporadic        |B-Disease   |O              |
# |t               |I-Disease   |O              |
# |-               |I-Disease   |O              |
# |cell            |I-Disease   |O              |
# |UNKNOWN_TOKEN   |I-Disease   |O              |
# |leukaemia       |E-Disease   |S-Disease      |
# |t               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |pll             |E-Disease   |O              |
# |clonal          |B-Disease   |O              |
# |malignancy      |E-Disease   |O              |
# |mature          |B-Disease   |O              |
# |t               |I-Disease   |O              |
# |-               |I-Disease   |O              |
# |cell            |I-Disease   |O              |
# |leukaemia       |E-Disease   |S-Disease      |
# |a               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |t               |E-Disease   |O              |
# |t               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |pll             |E-Disease   |O              |
# |a               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |t               |E-Disease   |O              |
# |t               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |pll             |E-Disease   |O              |
# |a               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |t               |E-Disease   |O              |
# |b               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |cell            |I-Disease   |O              |
# |non             |I-Disease   |O              |
# |-               |I-Disease   |O              |
# |hodgkins        |I-Disease   |B-Disease      |
# |b               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |nhl             |E-Disease   |O              |
# |b               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |nhl             |E-Disease   |O              |
# |tumours         |S-Disease   |E-Disease      |
# |sporadic        |B-Disease   |O              |
# |t               |I-Disease   |O              |
# |-               |I-Disease   |O              |
# |pll             |E-Disease   |O              |
# |hereditary      |O           |B-Disease      |
# |t               |B-Disease   |O              |
# |-               |I-Disease   |O              |
# |pll             |E-Disease   |O              |
# |muscular        |B-Disease   |I-Disease      |
# |retinoblastoma  |E-Disease   |S-Disease      |
# |retinoblastoma  |E-Disease   |S-Disease      |
# |tumor           |S-Disease   |E-Disease      |
# |retinoblastoma  |E-Disease   |S-Disease      |
# |tumor           |S-Disease   |E-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |tumors          |O           |E-Disease      |
# |multifocal      |O           |I-Disease      |
# |tumors          |S-Disease   |E-Disease      |
# |retinoblastoma  |E-Disease   |S-Disease      |
# |deficiency      |I-Disease   |E-Disease      |
# |of              |I-Disease   |O              |
