# %% [markdown]
# # End to End Sequence Labelling using BiLSTM CNN CRF for NER
# This project aims to perform **End to End Sequence Labelling**  on English data from CoNLL using BiLSTM CNN CRF for Named Entity Recognition.
#
# This project aims to implement the pytorch [model](https://https://github.com/jayavardhanr/End-to-end-Sequence-Labeling-via-Bi-directional-LSTM-CNNs-CRF-Tutorial/blob/master/Named_Entity_Recognition-LSTM-CNN-CRF-Tutorial.ipynb) of BiLSTM CNN CRF in Tensorflow Keras. We will use Convolution Neural Network Encoding for Character Level Representation of words, Bidirectional LSTM for Word Level Encoding and Conditional Random Fields (CRF Layer) for output decodings.
#
# Following are the libraries that we will import.

# %%
# Import Libraries
# !pip install tensorflow-gpu
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
# !pip install sklearn-crfsuite
import tensorflow as tf
import keras
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D,Flatten, concatenate
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.layers.crf import CRF
from keras.utils import plot_model
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Nadam
import numpy as np
import os
import sys
import codecs
import re
import pickle
from sklearn_crfsuite.metrics import flat_classification_report
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Download Data

# %%
# # Downloading Data
# !mkdir data
# !wget https://raw.githubusercontent.com/mxhofer/Named-Entity-Recognition-BidirectionalLSTM-CNN-CoNLL/master/data/train.txt
# !wget https://raw.githubusercontent.com/mxhofer/Named-Entity-Recognition-BidirectionalLSTM-CNN-CoNLL/master/data/dev.txt
# !wget https://raw.githubusercontent.com/mxhofer/Named-Entity-Recognition-BidirectionalLSTM-CNN-CoNLL/master/data/test.txt

# %% [markdown]
# ## Data Preprocessing
#
# Data prepocessing comprend le chargement des données, la mise à jour du schéma de balisage, la création d'un mappong pour les mots, les caractères et les tags et enfin la préparation des données qui sont transmises dans le modèle.

# %% [markdown]
# ### Custom Data Loading
# This step includes loading the train and validation data into list of sentences.
#
# Following code loads the training and validation data.

# %%
def load_sentences(filename):
    f = open(filename)
    sentences = []
    sentence = []
    for line in f:
        if len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence) > 0:
                sentences.append(sentence)
                sentence = []
            continue
        splits = line.split(' ')
        sentence.append([splits[0], splits[-1]])

    if len(sentence) > 0:
        sentences.append(sentence)
        sentence = []
    return sentences

# %%
train_sentences = load_sentences("data/train.txt")
dev_sentences = load_sentences("data/dev.txt")
test_sentences = load_sentences("data/test.txt")
len(train_sentences), len(dev_sentences), len(test_sentences)
# Out:
# (14041, 3250, 3453)

# %%
#train_sentences
# Out:
# [[['EU', ['E', 'U'], 'B-ORG\n'],
#   ['rejects', ['r', 'e', 'j', 'e', 'c', 't', 's'], 'O\n'],
#   ['German', ['G', 'e', 'r', 'm', 'a', 'n'], 'B-MISC\n'],
#   ['call', ['c', 'a', 'l', 'l'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['boycott', ['b', 'o', 'y', 'c', 'o', 't', 't'], 'O\n'],
#   ['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#   ['lamb', ['l', 'a', 'm', 'b'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Peter', ['P', 'e', 't', 'e', 'r'], 'B-PER\n'],
#   ['Blackburn', ['B', 'l', 'a', 'c', 'k', 'b', 'u', 'r', 'n'], 'I-PER\n']],
#  [['BRUSSELS', ['B', 'R', 'U', 'S', 'S', 'E', 'L', 'S'], 'B-LOC\n'],
#   ['1996-08-22', ['1', '9', '9', '6', '-', '0', '8', '-', '2', '2'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['European', ['E', 'u', 'r', 'o', 'p', 'e', 'a', 'n'], 'B-ORG\n'],
#   ['Commission',
#    ['C', 'o', 'm', 'm', 'i', 's', 's', 'i', 'o', 'n'],
#    'I-ORG\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   ['disagreed', ['d', 'i', 's', 'a', 'g', 'r', 'e', 'e', 'd'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['German', ['G', 'e', 'r', 'm', 'a', 'n'], 'B-MISC\n'],
#   ['advice', ['a', 'd', 'v', 'i', 'c', 'e'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['consumers', ['c', 'o', 'n', 's', 'u', 'm', 'e', 'r', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['shun', ['s', 'h', 'u', 'n'], 'O\n'],
#   ['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#   ['lamb', ['l', 'a', 'm', 'b'], 'O\n'],
#   ['until', ['u', 'n', 't', 'i', 'l'], 'O\n'],
#   ['scientists', ['s', 'c', 'i', 'e', 'n', 't', 'i', 's', 't', 's'], 'O\n'],
#   ['determine', ['d', 'e', 't', 'e', 'r', 'm', 'i', 'n', 'e'], 'O\n'],
#   ['whether', ['w', 'h', 'e', 't', 'h', 'e', 'r'], 'O\n'],
#   ['mad', ['m', 'a', 'd'], 'O\n'],
#   ['cow', ['c', 'o', 'w'], 'O\n'],
#   ['disease', ['d', 'i', 's', 'e', 'a', 's', 'e'], 'O\n'],
#   ['can', ['c', 'a', 'n'], 'O\n'],
#   ['be', ['b', 'e'], 'O\n'],
#   ['transmitted',
#    ['t', 'r', 'a', 'n', 's', 'm', 'i', 't', 't', 'e', 'd'],
#    'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['sheep', ['s', 'h', 'e', 'e', 'p'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Germany', ['G', 'e', 'r', 'm', 'a', 'n', 'y'], 'B-LOC\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['representative',
#    ['r', 'e', 'p', 'r', 'e', 's', 'e', 'n', 't', 'a', 't', 'i', 'v', 'e'],
#    'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['European', ['E', 'u', 'r', 'o', 'p', 'e', 'a', 'n'], 'B-ORG\n'],
#   ['Union', ['U', 'n', 'i', 'o', 'n'], 'I-ORG\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['veterinary', ['v', 'e', 't', 'e', 'r', 'i', 'n', 'a', 'r', 'y'], 'O\n'],
#   ['committee', ['c', 'o', 'm', 'm', 'i', 't', 't', 'e', 'e'], 'O\n'],
#   ['Werner', ['W', 'e', 'r', 'n', 'e', 'r'], 'B-PER\n'],
#   ['Zwingmann', ['Z', 'w', 'i', 'n', 'g', 'm', 'a', 'n', 'n'], 'I-PER\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Wednesday', ['W', 'e', 'd', 'n', 'e', 's', 'd', 'a', 'y'], 'O\n'],
#   ['consumers', ['c', 'o', 'n', 's', 'u', 'm', 'e', 'r', 's'], 'O\n'],
#   ['should', ['s', 'h', 'o', 'u', 'l', 'd'], 'O\n'],
#   ['buy', ['b', 'u', 'y'], 'O\n'],
#   ['sheepmeat', ['s', 'h', 'e', 'e', 'p', 'm', 'e', 'a', 't'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['countries', ['c', 'o', 'u', 'n', 't', 'r', 'i', 'e', 's'], 'O\n'],
#   ['other', ['o', 't', 'h', 'e', 'r'], 'O\n'],
#   ['than', ['t', 'h', 'a', 'n'], 'O\n'],
#   ['Britain', ['B', 'r', 'i', 't', 'a', 'i', 'n'], 'B-LOC\n'],
#   ['until', ['u', 'n', 't', 'i', 'l'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['scientific', ['s', 'c', 'i', 'e', 'n', 't', 'i', 'f', 'i', 'c'], 'O\n'],
#   ['advice', ['a', 'd', 'v', 'i', 'c', 'e'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['clearer', ['c', 'l', 'e', 'a', 'r', 'e', 'r'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['"', ['"'], 'O\n'],
#   ['We', ['W', 'e'], 'O\n'],
#   ['do', ['d', 'o'], 'O\n'],
#   ["n't", ['n', "'", 't'], 'O\n'],
#   ['support', ['s', 'u', 'p', 'p', 'o', 'r', 't'], 'O\n'],
#   ['any', ['a', 'n', 'y'], 'O\n'],
#   ['such', ['s', 'u', 'c', 'h'], 'O\n'],
#   ['recommendation',
#    ['r', 'e', 'c', 'o', 'm', 'm', 'e', 'n', 'd', 'a', 't', 'i', 'o', 'n'],
#    'O\n'],
#   ['because', ['b', 'e', 'c', 'a', 'u', 's', 'e'], 'O\n'],
#   ['we', ['w', 'e'], 'O\n'],
#   ['do', ['d', 'o'], 'O\n'],
#   ["n't", ['n', "'", 't'], 'O\n'],
#   ['see', ['s', 'e', 'e'], 'O\n'],
#   ['any', ['a', 'n', 'y'], 'O\n'],
#   ['grounds', ['g', 'r', 'o', 'u', 'n', 'd', 's'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['"', ['"'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['Commission',
#    ['C', 'o', 'm', 'm', 'i', 's', 's', 'i', 'o', 'n'],
#    'B-ORG\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['chief', ['c', 'h', 'i', 'e', 'f'], 'O\n'],
#   ['spokesman', ['s', 'p', 'o', 'k', 'e', 's', 'm', 'a', 'n'], 'O\n'],
#   ['Nikolaus', ['N', 'i', 'k', 'o', 'l', 'a', 'u', 's'], 'B-PER\n'],
#   ['van', ['v', 'a', 'n'], 'I-PER\n'],
#   ['der', ['d', 'e', 'r'], 'I-PER\n'],
#   ['Pas', ['P', 'a', 's'], 'I-PER\n'],
#   ['told', ['t', 'o', 'l', 'd'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['news', ['n', 'e', 'w', 's'], 'O\n'],
#   ['briefing', ['b', 'r', 'i', 'e', 'f', 'i', 'n', 'g'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['He', ['H', 'e'], 'O\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['further', ['f', 'u', 'r', 't', 'h', 'e', 'r'], 'O\n'],
#   ['scientific', ['s', 'c', 'i', 'e', 'n', 't', 'i', 'f', 'i', 'c'], 'O\n'],
#   ['study', ['s', 't', 'u', 'd', 'y'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['required', ['r', 'e', 'q', 'u', 'i', 'r', 'e', 'd'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['if', ['i', 'f'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['found', ['f', 'o', 'u', 'n', 'd'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['action', ['a', 'c', 't', 'i', 'o', 'n'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['needed', ['n', 'e', 'e', 'd', 'e', 'd'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   ['should', ['s', 'h', 'o', 'u', 'l', 'd'], 'O\n'],
#   ['be', ['b', 'e'], 'O\n'],
#   ['taken', ['t', 'a', 'k', 'e', 'n'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['European', ['E', 'u', 'r', 'o', 'p', 'e', 'a', 'n'], 'B-ORG\n'],
#   ['Union', ['U', 'n', 'i', 'o', 'n'], 'I-ORG\n'],
#   ['.', ['.'], 'O\n']],
#  [['He', ['H', 'e'], 'O\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['proposal', ['p', 'r', 'o', 'p', 'o', 's', 'a', 'l'], 'O\n'],
#   ['last', ['l', 'a', 's', 't'], 'O\n'],
#   ['month', ['m', 'o', 'n', 't', 'h'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['EU', ['E', 'U'], 'B-ORG\n'],
#   ['Farm', ['F', 'a', 'r', 'm'], 'O\n'],
#   ['Commissioner',
#    ['C', 'o', 'm', 'm', 'i', 's', 's', 'i', 'o', 'n', 'e', 'r'],
#    'O\n'],
#   ['Franz', ['F', 'r', 'a', 'n', 'z'], 'B-PER\n'],
#   ['Fischler', ['F', 'i', 's', 'c', 'h', 'l', 'e', 'r'], 'I-PER\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['ban', ['b', 'a', 'n'], 'O\n'],
#   ['sheep', ['s', 'h', 'e', 'e', 'p'], 'O\n'],
#   ['brains', ['b', 'r', 'a', 'i', 'n', 's'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['spleens', ['s', 'p', 'l', 'e', 'e', 'n', 's'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['spinal', ['s', 'p', 'i', 'n', 'a', 'l'], 'O\n'],
#   ['cords', ['c', 'o', 'r', 'd', 's'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['human', ['h', 'u', 'm', 'a', 'n'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['animal', ['a', 'n', 'i', 'm', 'a', 'l'], 'O\n'],
#   ['food', ['f', 'o', 'o', 'd'], 'O\n'],
#   ['chains', ['c', 'h', 'a', 'i', 'n', 's'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['highly', ['h', 'i', 'g', 'h', 'l', 'y'], 'O\n'],
#   ['specific', ['s', 'p', 'e', 'c', 'i', 'f', 'i', 'c'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['precautionary',
#    ['p', 'r', 'e', 'c', 'a', 'u', 't', 'i', 'o', 'n', 'a', 'r', 'y'],
#    'O\n'],
#   ['move', ['m', 'o', 'v', 'e'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['protect', ['p', 'r', 'o', 't', 'e', 'c', 't'], 'O\n'],
#   ['human', ['h', 'u', 'm', 'a', 'n'], 'O\n'],
#   ['health', ['h', 'e', 'a', 'l', 't', 'h'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Fischler', ['F', 'i', 's', 'c', 'h', 'l', 'e', 'r'], 'B-PER\n'],
#   ['proposed', ['p', 'r', 'o', 'p', 'o', 's', 'e', 'd'], 'O\n'],
#   ['EU-wide', ['E', 'U', '-', 'w', 'i', 'd', 'e'], 'B-MISC\n'],
#   ['measures', ['m', 'e', 'a', 's', 'u', 'r', 'e', 's'], 'O\n'],
#   ['after', ['a', 'f', 't', 'e', 'r'], 'O\n'],
#   ['reports', ['r', 'e', 'p', 'o', 'r', 't', 's'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['Britain', ['B', 'r', 'i', 't', 'a', 'i', 'n'], 'B-LOC\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['France', ['F', 'r', 'a', 'n', 'c', 'e'], 'B-LOC\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['under', ['u', 'n', 'd', 'e', 'r'], 'O\n'],
#   ['laboratory', ['l', 'a', 'b', 'o', 'r', 'a', 't', 'o', 'r', 'y'], 'O\n'],
#   ['conditions', ['c', 'o', 'n', 'd', 'i', 't', 'i', 'o', 'n', 's'], 'O\n'],
#   ['sheep', ['s', 'h', 'e', 'e', 'p'], 'O\n'],
#   ['could', ['c', 'o', 'u', 'l', 'd'], 'O\n'],
#   ['contract', ['c', 'o', 'n', 't', 'r', 'a', 'c', 't'], 'O\n'],
#   ['Bovine', ['B', 'o', 'v', 'i', 'n', 'e'], 'B-MISC\n'],
#   ['Spongiform',
#    ['S', 'p', 'o', 'n', 'g', 'i', 'f', 'o', 'r', 'm'],
#    'I-MISC\n'],
#   ['Encephalopathy',
#    ['E', 'n', 'c', 'e', 'p', 'h', 'a', 'l', 'o', 'p', 'a', 't', 'h', 'y'],
#    'I-MISC\n'],
#   ['(', ['('], 'O\n'],
#   ['BSE', ['B', 'S', 'E'], 'B-MISC\n'],
#   [')', [')'], 'O\n'],
#   ['--', ['-', '-'], 'O\n'],
#   ['mad', ['m', 'a', 'd'], 'O\n'],
#   ['cow', ['c', 'o', 'w'], 'O\n'],
#   ['disease', ['d', 'i', 's', 'e', 'a', 's', 'e'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['But', ['B', 'u', 't'], 'O\n'],
#   ['Fischler', ['F', 'i', 's', 'c', 'h', 'l', 'e', 'r'], 'B-PER\n'],
#   ['agreed', ['a', 'g', 'r', 'e', 'e', 'd'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['review', ['r', 'e', 'v', 'i', 'e', 'w'], 'O\n'],
#   ['his', ['h', 'i', 's'], 'O\n'],
#   ['proposal', ['p', 'r', 'o', 'p', 'o', 's', 'a', 'l'], 'O\n'],
#   ['after', ['a', 'f', 't', 'e', 'r'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['EU', ['E', 'U'], 'B-ORG\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['standing', ['s', 't', 'a', 'n', 'd', 'i', 'n', 'g'], 'O\n'],
#   ['veterinary', ['v', 'e', 't', 'e', 'r', 'i', 'n', 'a', 'r', 'y'], 'O\n'],
#   ['committee', ['c', 'o', 'm', 'm', 'i', 't', 't', 'e', 'e'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['mational', ['m', 'a', 't', 'i', 'o', 'n', 'a', 'l'], 'O\n'],
#   ['animal', ['a', 'n', 'i', 'm', 'a', 'l'], 'O\n'],
#   ['health', ['h', 'e', 'a', 'l', 't', 'h'], 'O\n'],
#   ['officials', ['o', 'f', 'f', 'i', 'c', 'i', 'a', 'l', 's'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['questioned', ['q', 'u', 'e', 's', 't', 'i', 'o', 'n', 'e', 'd'], 'O\n'],
#   ['if', ['i', 'f'], 'O\n'],
#   ['such', ['s', 'u', 'c', 'h'], 'O\n'],
#   ['action', ['a', 'c', 't', 'i', 'o', 'n'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['justified', ['j', 'u', 's', 't', 'i', 'f', 'i', 'e', 'd'], 'O\n'],
#   ['as', ['a', 's'], 'O\n'],
#   ['there', ['t', 'h', 'e', 'r', 'e'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['only', ['o', 'n', 'l', 'y'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['slight', ['s', 'l', 'i', 'g', 'h', 't'], 'O\n'],
#   ['risk', ['r', 'i', 's', 'k'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['human', ['h', 'u', 'm', 'a', 'n'], 'O\n'],
#   ['health', ['h', 'e', 'a', 'l', 't', 'h'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Spanish', ['S', 'p', 'a', 'n', 'i', 's', 'h'], 'B-MISC\n'],
#   ['Farm', ['F', 'a', 'r', 'm'], 'O\n'],
#   ['Minister', ['M', 'i', 'n', 'i', 's', 't', 'e', 'r'], 'O\n'],
#   ['Loyola', ['L', 'o', 'y', 'o', 'l', 'a'], 'B-PER\n'],
#   ['de', ['d', 'e'], 'I-PER\n'],
#   ['Palacio', ['P', 'a', 'l', 'a', 'c', 'i', 'o'], 'I-PER\n'],
#   ['had', ['h', 'a', 'd'], 'O\n'],
#   ['earlier', ['e', 'a', 'r', 'l', 'i', 'e', 'r'], 'O\n'],
#   ['accused', ['a', 'c', 'c', 'u', 's', 'e', 'd'], 'O\n'],
#   ['Fischler', ['F', 'i', 's', 'c', 'h', 'l', 'e', 'r'], 'B-PER\n'],
#   ['at', ['a', 't'], 'O\n'],
#   ['an', ['a', 'n'], 'O\n'],
#   ['EU', ['E', 'U'], 'B-ORG\n'],
#   ['farm', ['f', 'a', 'r', 'm'], 'O\n'],
#   ['ministers', ['m', 'i', 'n', 'i', 's', 't', 'e', 'r', 's'], 'O\n'],
#   ["'", ["'"], 'O\n'],
#   ['meeting', ['m', 'e', 'e', 't', 'i', 'n', 'g'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['causing', ['c', 'a', 'u', 's', 'i', 'n', 'g'], 'O\n'],
#   ['unjustified',
#    ['u', 'n', 'j', 'u', 's', 't', 'i', 'f', 'i', 'e', 'd'],
#    'O\n'],
#   ['alarm', ['a', 'l', 'a', 'r', 'm'], 'O\n'],
#   ['through', ['t', 'h', 'r', 'o', 'u', 'g', 'h'], 'O\n'],
#   ['"', ['"'], 'O\n'],
#   ['dangerous', ['d', 'a', 'n', 'g', 'e', 'r', 'o', 'u', 's'], 'O\n'],
#   ['generalisation',
#    ['g', 'e', 'n', 'e', 'r', 'a', 'l', 'i', 's', 'a', 't', 'i', 'o', 'n'],
#    'O\n'],
#   ['.', ['.'], 'O\n'],
#   ['"', ['"'], 'O\n']],
#  [['.', ['.'], 'O\n']],
#  [['Only', ['O', 'n', 'l', 'y'], 'O\n'],
#   ['France', ['F', 'r', 'a', 'n', 'c', 'e'], 'B-LOC\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['Britain', ['B', 'r', 'i', 't', 'a', 'i', 'n'], 'B-LOC\n'],
#   ['backed', ['b', 'a', 'c', 'k', 'e', 'd'], 'O\n'],
#   ['Fischler', ['F', 'i', 's', 'c', 'h', 'l', 'e', 'r'], 'B-PER\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['proposal', ['p', 'r', 'o', 'p', 'o', 's', 'a', 'l'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['EU', ['E', 'U'], 'B-ORG\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['scientific', ['s', 'c', 'i', 'e', 'n', 't', 'i', 'f', 'i', 'c'], 'O\n'],
#   ['veterinary', ['v', 'e', 't', 'e', 'r', 'i', 'n', 'a', 'r', 'y'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['multidisciplinary',
#    ['m',
#     'u',
#     'l',
#     't',
#     'i',
#     'd',
#     'i',
#     's',
#     'c',
#     'i',
#     'p',
#     'l',
#     'i',
#     'n',
#     'a',
#     'r',
#     'y'],
#    'O\n'],
#   ['committees', ['c', 'o', 'm', 'm', 'i', 't', 't', 'e', 'e', 's'], 'O\n'],
#   ['are', ['a', 'r', 'e'], 'O\n'],
#   ['due', ['d', 'u', 'e'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['re-examine', ['r', 'e', '-', 'e', 'x', 'a', 'm', 'i', 'n', 'e'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['issue', ['i', 's', 's', 'u', 'e'], 'O\n'],
#   ['early', ['e', 'a', 'r', 'l', 'y'], 'O\n'],
#   ['next', ['n', 'e', 'x', 't'], 'O\n'],
#   ['month', ['m', 'o', 'n', 't', 'h'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['make', ['m', 'a', 'k', 'e'], 'O\n'],
#   ['recommendations',
#    ['r', 'e', 'c', 'o', 'm', 'm', 'e', 'n', 'd', 'a', 't', 'i', 'o', 'n', 's'],
#    'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['senior', ['s', 'e', 'n', 'i', 'o', 'r'], 'O\n'],
#   ['veterinary', ['v', 'e', 't', 'e', 'r', 'i', 'n', 'a', 'r', 'y'], 'O\n'],
#   ['officials', ['o', 'f', 'f', 'i', 'c', 'i', 'a', 'l', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Sheep', ['S', 'h', 'e', 'e', 'p'], 'O\n'],
#   ['have', ['h', 'a', 'v', 'e'], 'O\n'],
#   ['long', ['l', 'o', 'n', 'g'], 'O\n'],
#   ['been', ['b', 'e', 'e', 'n'], 'O\n'],
#   ['known', ['k', 'n', 'o', 'w', 'n'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['contract', ['c', 'o', 'n', 't', 'r', 'a', 'c', 't'], 'O\n'],
#   ['scrapie', ['s', 'c', 'r', 'a', 'p', 'i', 'e'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['brain-wasting',
#    ['b', 'r', 'a', 'i', 'n', '-', 'w', 'a', 's', 't', 'i', 'n', 'g'],
#    'O\n'],
#   ['disease', ['d', 'i', 's', 'e', 'a', 's', 'e'], 'O\n'],
#   ['similar', ['s', 'i', 'm', 'i', 'l', 'a', 'r'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['BSE', ['B', 'S', 'E'], 'B-MISC\n'],
#   ['which', ['w', 'h', 'i', 'c', 'h'], 'O\n'],
#   ['is', ['i', 's'], 'O\n'],
#   ['believed', ['b', 'e', 'l', 'i', 'e', 'v', 'e', 'd'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['have', ['h', 'a', 'v', 'e'], 'O\n'],
#   ['been', ['b', 'e', 'e', 'n'], 'O\n'],
#   ['transferred',
#    ['t', 'r', 'a', 'n', 's', 'f', 'e', 'r', 'r', 'e', 'd'],
#    'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['cattle', ['c', 'a', 't', 't', 'l', 'e'], 'O\n'],
#   ['through', ['t', 'h', 'r', 'o', 'u', 'g', 'h'], 'O\n'],
#   ['feed', ['f', 'e', 'e', 'd'], 'O\n'],
#   ['containing', ['c', 'o', 'n', 't', 'a', 'i', 'n', 'i', 'n', 'g'], 'O\n'],
#   ['animal', ['a', 'n', 'i', 'm', 'a', 'l'], 'O\n'],
#   ['waste', ['w', 'a', 's', 't', 'e'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#   ['farmers', ['f', 'a', 'r', 'm', 'e', 'r', 's'], 'O\n'],
#   ['denied', ['d', 'e', 'n', 'i', 'e', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ['there', ['t', 'h', 'e', 'r', 'e'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['any', ['a', 'n', 'y'], 'O\n'],
#   ['danger', ['d', 'a', 'n', 'g', 'e', 'r'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['human', ['h', 'u', 'm', 'a', 'n'], 'O\n'],
#   ['health', ['h', 'e', 'a', 'l', 't', 'h'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['their', ['t', 'h', 'e', 'i', 'r'], 'O\n'],
#   ['sheep', ['s', 'h', 'e', 'e', 'p'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['but', ['b', 'u', 't'], 'O\n'],
#   ['expressed', ['e', 'x', 'p', 'r', 'e', 's', 's', 'e', 'd'], 'O\n'],
#   ['concern', ['c', 'o', 'n', 'c', 'e', 'r', 'n'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['German', ['G', 'e', 'r', 'm', 'a', 'n'], 'B-MISC\n'],
#   ['government', ['g', 'o', 'v', 'e', 'r', 'n', 'm', 'e', 'n', 't'], 'O\n'],
#   ['advice', ['a', 'd', 'v', 'i', 'c', 'e'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['consumers', ['c', 'o', 'n', 's', 'u', 'm', 'e', 'r', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['avoid', ['a', 'v', 'o', 'i', 'd'], 'O\n'],
#   ['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#   ['lamb', ['l', 'a', 'm', 'b'], 'O\n'],
#   ['might', ['m', 'i', 'g', 'h', 't'], 'O\n'],
#   ['influence', ['i', 'n', 'f', 'l', 'u', 'e', 'n', 'c', 'e'], 'O\n'],
#   ['consumers', ['c', 'o', 'n', 's', 'u', 'm', 'e', 'r', 's'], 'O\n'],
#   ['across', ['a', 'c', 'r', 'o', 's', 's'], 'O\n'],
#   ['Europe', ['E', 'u', 'r', 'o', 'p', 'e'], 'B-LOC\n'],
#   ['.', ['.'], 'O\n']],
#  [['"', ['"'], 'O\n'],
#   ['What', ['W', 'h', 'a', 't'], 'O\n'],
#   ['we', ['w', 'e'], 'O\n'],
#   ['have', ['h', 'a', 'v', 'e'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['be', ['b', 'e'], 'O\n'],
#   ['extremely', ['e', 'x', 't', 'r', 'e', 'm', 'e', 'l', 'y'], 'O\n'],
#   ['careful', ['c', 'a', 'r', 'e', 'f', 'u', 'l'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['is', ['i', 's'], 'O\n'],
#   ['how', ['h', 'o', 'w'], 'O\n'],
#   ['other', ['o', 't', 'h', 'e', 'r'], 'O\n'],
#   ['countries', ['c', 'o', 'u', 'n', 't', 'r', 'i', 'e', 's'], 'O\n'],
#   ['are', ['a', 'r', 'e'], 'O\n'],
#   ['going', ['g', 'o', 'i', 'n', 'g'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['take', ['t', 'a', 'k', 'e'], 'O\n'],
#   ['Germany', ['G', 'e', 'r', 'm', 'a', 'n', 'y'], 'B-LOC\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['lead', ['l', 'e', 'a', 'd'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['"', ['"'], 'O\n'],
#   ['Welsh', ['W', 'e', 'l', 's', 'h'], 'B-ORG\n'],
#   ['National', ['N', 'a', 't', 'i', 'o', 'n', 'a', 'l'], 'I-ORG\n'],
#   ['Farmers', ['F', 'a', 'r', 'm', 'e', 'r', 's'], 'I-ORG\n'],
#   ["'", ["'"], 'I-ORG\n'],
#   ['Union', ['U', 'n', 'i', 'o', 'n'], 'I-ORG\n'],
#   ['(', ['('], 'O\n'],
#   ['NFU', ['N', 'F', 'U'], 'B-ORG\n'],
#   [')', [')'], 'O\n'],
#   ['chairman', ['c', 'h', 'a', 'i', 'r', 'm', 'a', 'n'], 'O\n'],
#   ['John', ['J', 'o', 'h', 'n'], 'B-PER\n'],
#   ['Lloyd', ['L', 'l', 'o', 'y', 'd'], 'I-PER\n'],
#   ['Jones', ['J', 'o', 'n', 'e', 's'], 'I-PER\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['BBC', ['B', 'B', 'C'], 'B-ORG\n'],
#   ['radio', ['r', 'a', 'd', 'i', 'o'], 'I-ORG\n'],
#   ['.', ['.'], 'O\n']],
#  [['Bonn', ['B', 'o', 'n', 'n'], 'B-LOC\n'],
#   ['has', ['h', 'a', 's'], 'O\n'],
#   ['led', ['l', 'e', 'd'], 'O\n'],
#   ['efforts', ['e', 'f', 'f', 'o', 'r', 't', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['protect', ['p', 'r', 'o', 't', 'e', 'c', 't'], 'O\n'],
#   ['public', ['p', 'u', 'b', 'l', 'i', 'c'], 'O\n'],
#   ['health', ['h', 'e', 'a', 'l', 't', 'h'], 'O\n'],
#   ['after', ['a', 'f', 't', 'e', 'r'], 'O\n'],
#   ['consumer', ['c', 'o', 'n', 's', 'u', 'm', 'e', 'r'], 'O\n'],
#   ['confidence', ['c', 'o', 'n', 'f', 'i', 'd', 'e', 'n', 'c', 'e'], 'O\n'],
#   ['collapsed', ['c', 'o', 'l', 'l', 'a', 'p', 's', 'e', 'd'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['March', ['M', 'a', 'r', 'c', 'h'], 'O\n'],
#   ['after', ['a', 'f', 't', 'e', 'r'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#   ['report', ['r', 'e', 'p', 'o', 'r', 't'], 'O\n'],
#   ['suggested', ['s', 'u', 'g', 'g', 'e', 's', 't', 'e', 'd'], 'O\n'],
#   ['humans', ['h', 'u', 'm', 'a', 'n', 's'], 'O\n'],
#   ['could', ['c', 'o', 'u', 'l', 'd'], 'O\n'],
#   ['contract', ['c', 'o', 'n', 't', 'r', 'a', 'c', 't'], 'O\n'],
#   ['an', ['a', 'n'], 'O\n'],
#   ['illness', ['i', 'l', 'l', 'n', 'e', 's', 's'], 'O\n'],
#   ['similar', ['s', 'i', 'm', 'i', 'l', 'a', 'r'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['mad', ['m', 'a', 'd'], 'O\n'],
#   ['cow', ['c', 'o', 'w'], 'O\n'],
#   ['disease', ['d', 'i', 's', 'e', 'a', 's', 'e'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['eating', ['e', 'a', 't', 'i', 'n', 'g'], 'O\n'],
#   ['contaminated',
#    ['c', 'o', 'n', 't', 'a', 'm', 'i', 'n', 'a', 't', 'e', 'd'],
#    'O\n'],
#   ['beef', ['b', 'e', 'e', 'f'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Germany', ['G', 'e', 'r', 'm', 'a', 'n', 'y'], 'B-LOC\n'],
#   ['imported', ['i', 'm', 'p', 'o', 'r', 't', 'e', 'd'], 'O\n'],
#   ['47,600', ['4', '7', ',', '6', '0', '0'], 'O\n'],
#   ['sheep', ['s', 'h', 'e', 'e', 'p'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['Britain', ['B', 'r', 'i', 't', 'a', 'i', 'n'], 'B-LOC\n'],
#   ['last', ['l', 'a', 's', 't'], 'O\n'],
#   ['year', ['y', 'e', 'a', 'r'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['nearly', ['n', 'e', 'a', 'r', 'l', 'y'], 'O\n'],
#   ['half', ['h', 'a', 'l', 'f'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['total', ['t', 'o', 't', 'a', 'l'], 'O\n'],
#   ['imports', ['i', 'm', 'p', 'o', 'r', 't', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['It', ['I', 't'], 'O\n'],
#   ['brought', ['b', 'r', 'o', 'u', 'g', 'h', 't'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['4,275', ['4', ',', '2', '7', '5'], 'O\n'],
#   ['tonnes', ['t', 'o', 'n', 'n', 'e', 's'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#   ['mutton', ['m', 'u', 't', 't', 'o', 'n'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['some', ['s', 'o', 'm', 'e'], 'O\n'],
#   ['10', ['1', '0'], 'O\n'],
#   ['percent', ['p', 'e', 'r', 'c', 'e', 'n', 't'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['overall', ['o', 'v', 'e', 'r', 'a', 'l', 'l'], 'O\n'],
#   ['imports', ['i', 'm', 'p', 'o', 'r', 't', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Rare', ['R', 'a', 'r', 'e'], 'O\n'],
#   ['Hendrix', ['H', 'e', 'n', 'd', 'r', 'i', 'x'], 'B-PER\n'],
#   ['song', ['s', 'o', 'n', 'g'], 'O\n'],
#   ['draft', ['d', 'r', 'a', 'f', 't'], 'O\n'],
#   ['sells', ['s', 'e', 'l', 'l', 's'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['almost', ['a', 'l', 'm', 'o', 's', 't'], 'O\n'],
#   ['$', ['$'], 'O\n'],
#   ['17,000', ['1', '7', ',', '0', '0', '0'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['LONDON', ['L', 'O', 'N', 'D', 'O', 'N'], 'B-LOC\n'],
#   ['1996-08-22', ['1', '9', '9', '6', '-', '0', '8', '-', '2', '2'], 'O\n']],
#  [['A', ['A'], 'O\n'],
#   ['rare', ['r', 'a', 'r', 'e'], 'O\n'],
#   ['early', ['e', 'a', 'r', 'l', 'y'], 'O\n'],
#   ['handwritten',
#    ['h', 'a', 'n', 'd', 'w', 'r', 'i', 't', 't', 'e', 'n'],
#    'O\n'],
#   ['draft', ['d', 'r', 'a', 'f', 't'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['song', ['s', 'o', 'n', 'g'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['U.S.', ['U', '.', 'S', '.'], 'B-LOC\n'],
#   ['guitar', ['g', 'u', 'i', 't', 'a', 'r'], 'O\n'],
#   ['legend', ['l', 'e', 'g', 'e', 'n', 'd'], 'O\n'],
#   ['Jimi', ['J', 'i', 'm', 'i'], 'B-PER\n'],
#   ['Hendrix', ['H', 'e', 'n', 'd', 'r', 'i', 'x'], 'I-PER\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['sold', ['s', 'o', 'l', 'd'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['almost', ['a', 'l', 'm', 'o', 's', 't'], 'O\n'],
#   ['$', ['$'], 'O\n'],
#   ['17,000', ['1', '7', ',', '0', '0', '0'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ['at', ['a', 't'], 'O\n'],
#   ['an', ['a', 'n'], 'O\n'],
#   ['auction', ['a', 'u', 'c', 't', 'i', 'o', 'n'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['some', ['s', 'o', 'm', 'e'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['late', ['l', 'a', 't', 'e'], 'O\n'],
#   ['musician', ['m', 'u', 's', 'i', 'c', 'i', 'a', 'n'], 'O\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['favourite', ['f', 'a', 'v', 'o', 'u', 'r', 'i', 't', 'e'], 'O\n'],
#   ['possessions',
#    ['p', 'o', 's', 's', 'e', 's', 's', 'i', 'o', 'n', 's'],
#    'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['A', ['A'], 'O\n'],
#   ['Florida', ['F', 'l', 'o', 'r', 'i', 'd', 'a'], 'B-LOC\n'],
#   ['restaurant', ['r', 'e', 's', 't', 'a', 'u', 'r', 'a', 'n', 't'], 'O\n'],
#   ['paid', ['p', 'a', 'i', 'd'], 'O\n'],
#   ['10,925', ['1', '0', ',', '9', '2', '5'], 'O\n'],
#   ['pounds', ['p', 'o', 'u', 'n', 'd', 's'], 'O\n'],
#   ['(', ['('], 'O\n'],
#   ['$', ['$'], 'O\n'],
#   ['16,935', ['1', '6', ',', '9', '3', '5'], 'O\n'],
#   [')', [')'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['draft', ['d', 'r', 'a', 'f', 't'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['"', ['"'], 'O\n'],
#   ['Ai', ['A', 'i'], 'B-MISC\n'],
#   ["n't", ['n', "'", 't'], 'I-MISC\n'],
#   ['no', ['n', 'o'], 'I-MISC\n'],
#   ['telling', ['t', 'e', 'l', 'l', 'i', 'n', 'g'], 'I-MISC\n'],
#   ['"', ['"'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['which', ['w', 'h', 'i', 'c', 'h'], 'O\n'],
#   ['Hendrix', ['H', 'e', 'n', 'd', 'r', 'i', 'x'], 'B-PER\n'],
#   ['penned', ['p', 'e', 'n', 'n', 'e', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['piece', ['p', 'i', 'e', 'c', 'e'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['London', ['L', 'o', 'n', 'd', 'o', 'n'], 'B-LOC\n'],
#   ['hotel', ['h', 'o', 't', 'e', 'l'], 'O\n'],
#   ['stationery', ['s', 't', 'a', 't', 'i', 'o', 'n', 'e', 'r', 'y'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['late', ['l', 'a', 't', 'e'], 'O\n'],
#   ['1966', ['1', '9', '6', '6'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['At', ['A', 't'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['end', ['e', 'n', 'd'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['January', ['J', 'a', 'n', 'u', 'a', 'r', 'y'], 'O\n'],
#   ['1967', ['1', '9', '6', '7'], 'O\n'],
#   ['concert', ['c', 'o', 'n', 'c', 'e', 'r', 't'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['English', ['E', 'n', 'g', 'l', 'i', 's', 'h'], 'B-MISC\n'],
#   ['city', ['c', 'i', 't', 'y'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['Nottingham',
#    ['N', 'o', 't', 't', 'i', 'n', 'g', 'h', 'a', 'm'],
#    'B-LOC\n'],
#   ['he', ['h', 'e'], 'O\n'],
#   ['threw', ['t', 'h', 'r', 'e', 'w'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['sheet', ['s', 'h', 'e', 'e', 't'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['paper', ['p', 'a', 'p', 'e', 'r'], 'O\n'],
#   ['into', ['i', 'n', 't', 'o'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['audience', ['a', 'u', 'd', 'i', 'e', 'n', 'c', 'e'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['where', ['w', 'h', 'e', 'r', 'e'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['retrieved', ['r', 'e', 't', 'r', 'i', 'e', 'v', 'e', 'd'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['fan', ['f', 'a', 'n'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Buyers', ['B', 'u', 'y', 'e', 'r', 's'], 'O\n'],
#   ['also', ['a', 'l', 's', 'o'], 'O\n'],
#   ['snapped', ['s', 'n', 'a', 'p', 'p', 'e', 'd'], 'O\n'],
#   ['up', ['u', 'p'], 'O\n'],
#   ['16', ['1', '6'], 'O\n'],
#   ['other', ['o', 't', 'h', 'e', 'r'], 'O\n'],
#   ['items', ['i', 't', 'e', 'm', 's'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['were', ['w', 'e', 'r', 'e'], 'O\n'],
#   ['put', ['p', 'u', 't'], 'O\n'],
#   ['up', ['u', 'p'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['auction', ['a', 'u', 'c', 't', 'i', 'o', 'n'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['Hendrix', ['H', 'e', 'n', 'd', 'r', 'i', 'x'], 'B-PER\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['former', ['f', 'o', 'r', 'm', 'e', 'r'], 'O\n'],
#   ['girlfriend', ['g', 'i', 'r', 'l', 'f', 'r', 'i', 'e', 'n', 'd'], 'O\n'],
#   ['Kathy', ['K', 'a', 't', 'h', 'y'], 'B-PER\n'],
#   ['Etchingham',
#    ['E', 't', 'c', 'h', 'i', 'n', 'g', 'h', 'a', 'm'],
#    'I-PER\n'],
#   [',', [','], 'O\n'],
#   ['who', ['w', 'h', 'o'], 'O\n'],
#   ['lived', ['l', 'i', 'v', 'e', 'd'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['him', ['h', 'i', 'm'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['1966', ['1', '9', '6', '6'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['1969', ['1', '9', '6', '9'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['They', ['T', 'h', 'e', 'y'], 'O\n'],
#   ['included', ['i', 'n', 'c', 'l', 'u', 'd', 'e', 'd'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['black', ['b', 'l', 'a', 'c', 'k'], 'O\n'],
#   ['lacquer', ['l', 'a', 'c', 'q', 'u', 'e', 'r'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['mother', ['m', 'o', 't', 'h', 'e', 'r'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['pearl', ['p', 'e', 'a', 'r', 'l'], 'O\n'],
#   ['inlaid', ['i', 'n', 'l', 'a', 'i', 'd'], 'O\n'],
#   ['box', ['b', 'o', 'x'], 'O\n'],
#   ['used', ['u', 's', 'e', 'd'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['Hendrix', ['H', 'e', 'n', 'd', 'r', 'i', 'x'], 'B-PER\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['store', ['s', 't', 'o', 'r', 'e'], 'O\n'],
#   ['his', ['h', 'i', 's'], 'O\n'],
#   ['drugs', ['d', 'r', 'u', 'g', 's'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['which', ['w', 'h', 'i', 'c', 'h'], 'O\n'],
#   ['an', ['a', 'n'], 'O\n'],
#   ['anonymous', ['a', 'n', 'o', 'n', 'y', 'm', 'o', 'u', 's'], 'O\n'],
#   ['Australian',
#    ['A', 'u', 's', 't', 'r', 'a', 'l', 'i', 'a', 'n'],
#    'B-MISC\n'],
#   ['purchaser', ['p', 'u', 'r', 'c', 'h', 'a', 's', 'e', 'r'], 'O\n'],
#   ['bought', ['b', 'o', 'u', 'g', 'h', 't'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['5,060', ['5', ',', '0', '6', '0'], 'O\n'],
#   ['pounds', ['p', 'o', 'u', 'n', 'd', 's'], 'O\n'],
#   ['(', ['('], 'O\n'],
#   ['$', ['$'], 'O\n'],
#   ['7,845', ['7', ',', '8', '4', '5'], 'O\n'],
#   [')', [')'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['guitarist', ['g', 'u', 'i', 't', 'a', 'r', 'i', 's', 't'], 'O\n'],
#   ['died', ['d', 'i', 'e', 'd'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['drugs', ['d', 'r', 'u', 'g', 's'], 'O\n'],
#   ['overdose', ['o', 'v', 'e', 'r', 'd', 'o', 's', 'e'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['1970', ['1', '9', '7', '0'], 'O\n'],
#   ['aged', ['a', 'g', 'e', 'd'], 'O\n'],
#   ['27', ['2', '7'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['China', ['C', 'h', 'i', 'n', 'a'], 'B-LOC\n'],
#   ['says', ['s', 'a', 'y', 's'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   ['spoils', ['s', 'p', 'o', 'i', 'l', 's'], 'O\n'],
#   ['atmosphere', ['a', 't', 'm', 'o', 's', 'p', 'h', 'e', 'r', 'e'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['BEIJING', ['B', 'E', 'I', 'J', 'I', 'N', 'G'], 'B-LOC\n'],
#   ['1996-08-22', ['1', '9', '9', '6', '-', '0', '8', '-', '2', '2'], 'O\n']],
#  [['China', ['C', 'h', 'i', 'n', 'a'], 'B-LOC\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ['accused', ['a', 'c', 'c', 'u', 's', 'e', 'd'], 'O\n'],
#   ['Taipei', ['T', 'a', 'i', 'p', 'e', 'i'], 'B-LOC\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['spoiling', ['s', 'p', 'o', 'i', 'l', 'i', 'n', 'g'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['atmosphere', ['a', 't', 'm', 'o', 's', 'p', 'h', 'e', 'r', 'e'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['resumption', ['r', 'e', 's', 'u', 'm', 'p', 't', 'i', 'o', 'n'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['across', ['a', 'c', 'r', 'o', 's', 's'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   ['Strait', ['S', 't', 'r', 'a', 'i', 't'], 'I-LOC\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['visit', ['v', 'i', 's', 'i', 't'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['Ukraine', ['U', 'k', 'r', 'a', 'i', 'n', 'e'], 'B-LOC\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['Taiwanese', ['T', 'a', 'i', 'w', 'a', 'n', 'e', 's', 'e'], 'B-MISC\n'],
#   ['Vice', ['V', 'i', 'c', 'e'], 'O\n'],
#   ['President', ['P', 'r', 'e', 's', 'i', 'd', 'e', 'n', 't'], 'O\n'],
#   ['Lien', ['L', 'i', 'e', 'n'], 'B-PER\n'],
#   ['Chan', ['C', 'h', 'a', 'n'], 'I-PER\n'],
#   ['this', ['t', 'h', 'i', 's'], 'O\n'],
#   ['week', ['w', 'e', 'e', 'k'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['infuriated', ['i', 'n', 'f', 'u', 'r', 'i', 'a', 't', 'e', 'd'], 'O\n'],
#   ['Beijing', ['B', 'e', 'i', 'j', 'i', 'n', 'g'], 'B-LOC\n'],
#   ['.', ['.'], 'O\n']],
#  [['Speaking', ['S', 'p', 'e', 'a', 'k', 'i', 'n', 'g'], 'O\n'],
#   ['only', ['o', 'n', 'l', 'y'], 'O\n'],
#   ['hours', ['h', 'o', 'u', 'r', 's'], 'O\n'],
#   ['after', ['a', 'f', 't', 'e', 'r'], 'O\n'],
#   ['Chinese', ['C', 'h', 'i', 'n', 'e', 's', 'e'], 'B-MISC\n'],
#   ['state', ['s', 't', 'a', 't', 'e'], 'O\n'],
#   ['media', ['m', 'e', 'd', 'i', 'a'], 'O\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['right', ['r', 'i', 'g', 'h', 't'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['engage', ['e', 'n', 'g', 'a', 'g', 'e'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['political', ['p', 'o', 'l', 'i', 't', 'i', 'c', 'a', 'l'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['Foreign', ['F', 'o', 'r', 'e', 'i', 'g', 'n'], 'B-ORG\n'],
#   ['Ministry', ['M', 'i', 'n', 'i', 's', 't', 'r', 'y'], 'I-ORG\n'],
#   ['spokesman', ['s', 'p', 'o', 'k', 'e', 's', 'm', 'a', 'n'], 'O\n'],
#   ['Shen', ['S', 'h', 'e', 'n'], 'B-PER\n'],
#   ['Guofang', ['G', 'u', 'o', 'f', 'a', 'n', 'g'], 'I-PER\n'],
#   ['told', ['t', 'o', 'l', 'd'], 'O\n'],
#   ['Reuters', ['R', 'e', 'u', 't', 'e', 'r', 's'], 'B-ORG\n'],
#   [':', [':'], 'O\n'],
#   ['"', ['"'], 'O\n'],
#   ['The', ['T', 'h', 'e'], 'O\n'],
#   ['necessary', ['n', 'e', 'c', 'e', 's', 's', 'a', 'r', 'y'], 'O\n'],
#   ['atmosphere', ['a', 't', 'm', 'o', 's', 'p', 'h', 'e', 'r', 'e'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['opening', ['o', 'p', 'e', 'n', 'i', 'n', 'g'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['has', ['h', 'a', 's'], 'O\n'],
#   ['been', ['b', 'e', 'e', 'n'], 'O\n'],
#   ['disrupted', ['d', 'i', 's', 'r', 'u', 'p', 't', 'e', 'd'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   ['authorities',
#    ['a', 'u', 't', 'h', 'o', 'r', 'i', 't', 'i', 'e', 's'],
#    'O\n'],
#   ['.', ['.'], 'O\n'],
#   ['"', ['"'], 'O\n']],
#  [['State', ['S', 't', 'a', 't', 'e'], 'O\n'],
#   ['media', ['m', 'e', 'd', 'i', 'a'], 'O\n'],
#   ['quoted', ['q', 'u', 'o', 't', 'e', 'd'], 'O\n'],
#   ['China', ['C', 'h', 'i', 'n', 'a'], 'B-LOC\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['top', ['t', 'o', 'p'], 'O\n'],
#   ['negotiator', ['n', 'e', 'g', 'o', 't', 'i', 'a', 't', 'o', 'r'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['Taipei', ['T', 'a', 'i', 'p', 'e', 'i'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['Tang', ['T', 'a', 'n', 'g'], 'B-PER\n'],
#   ['Shubei', ['S', 'h', 'u', 'b', 'e', 'i'], 'I-PER\n'],
#   [',', [','], 'O\n'],
#   ['as', ['a', 's'], 'O\n'],
#   ['telling', ['t', 'e', 'l', 'l', 'i', 'n', 'g'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['visiting', ['v', 'i', 's', 'i', 't', 'i', 'n', 'g'], 'O\n'],
#   ['group', ['g', 'r', 'o', 'u', 'p'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Wednesday', ['W', 'e', 'd', 'n', 'e', 's', 'd', 'a', 'y'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['rivals', ['r', 'i', 'v', 'a', 'l', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['hold', ['h', 'o', 'l', 'd'], 'O\n'],
#   ['political', ['p', 'o', 'l', 'i', 't', 'i', 'c', 'a', 'l'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['"', ['"'], 'O\n'],
#   ['Now', ['N', 'o', 'w'], 'O\n'],
#   ['is', ['i', 's'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['two', ['t', 'w', 'o'], 'O\n'],
#   ['sides', ['s', 'i', 'd', 'e', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['engage', ['e', 'n', 'g', 'a', 'g', 'e'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['political', ['p', 'o', 'l', 'i', 't', 'i', 'c', 'a', 'l'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['...', ['.', '.', '.'], 'O\n']],
#  [['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['is', ['i', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['end', ['e', 'n', 'd'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['state', ['s', 't', 'a', 't', 'e'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['hostility', ['h', 'o', 's', 't', 'i', 'l', 'i', 't', 'y'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['"', ['"'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['overseas', ['o', 'v', 'e', 'r', 's', 'e', 'a', 's'], 'O\n'],
#   ['edition', ['e', 'd', 'i', 't', 'i', 'o', 'n'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['People', ['P', 'e', 'o', 'p', 'l', 'e'], 'B-ORG\n'],
#   ["'s", ["'", 's'], 'I-ORG\n'],
#   ['Daily', ['D', 'a', 'i', 'l', 'y'], 'I-ORG\n'],
#   ['quoted', ['q', 'u', 'o', 't', 'e', 'd'], 'O\n'],
#   ['Tang', ['T', 'a', 'n', 'g'], 'B-PER\n'],
#   ['as', ['a', 's'], 'O\n'],
#   ['saying', ['s', 'a', 'y', 'i', 'n', 'g'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['foreign', ['f', 'o', 'r', 'e', 'i', 'g', 'n'], 'O\n'],
#   ['ministry', ['m', 'i', 'n', 'i', 's', 't', 'r', 'y'], 'O\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['Shen', ['S', 'h', 'e', 'n'], 'B-ORG\n'],
#   ['told', ['t', 'o', 'l', 'd'], 'O\n'],
#   ['Reuters', ['R', 'e', 'u', 't', 'e', 'r', 's'], 'B-ORG\n'],
#   ['Television',
#    ['T', 'e', 'l', 'e', 'v', 'i', 's', 'i', 'o', 'n'],
#    'I-ORG\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['an', ['a', 'n'], 'O\n'],
#   ['interview', ['i', 'n', 't', 'e', 'r', 'v', 'i', 'e', 'w'], 'O\n'],
#   ['he', ['h', 'e'], 'O\n'],
#   ['had', ['h', 'a', 'd'], 'O\n'],
#   ['read', ['r', 'e', 'a', 'd'], 'O\n'],
#   ['reports', ['r', 'e', 'p', 'o', 'r', 't', 's'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['Tang', ['T', 'a', 'n', 'g'], 'B-PER\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['comments', ['c', 'o', 'm', 'm', 'e', 'n', 't', 's'], 'O\n'],
#   ['but', ['b', 'u', 't'], 'O\n'],
#   ['gave', ['g', 'a', 'v', 'e'], 'O\n'],
#   ['no', ['n', 'o'], 'O\n'],
#   ['details', ['d', 'e', 't', 'a', 'i', 'l', 's'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['why', ['w', 'h', 'y'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['negotiator', ['n', 'e', 'g', 'o', 't', 'i', 'a', 't', 'o', 'r'], 'O\n'],
#   ['had', ['h', 'a', 'd'], 'O\n'],
#   ['considered', ['c', 'o', 'n', 's', 'i', 'd', 'e', 'r', 'e', 'd'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['right', ['r', 'i', 'g', 'h', 't'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['which', ['w', 'h', 'i', 'c', 'h'], 'O\n'],
#   ['Beijing', ['B', 'e', 'i', 'j', 'i', 'n', 'g'], 'B-LOC\n'],
#   ['considers', ['c', 'o', 'n', 's', 'i', 'd', 'e', 'r', 's'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['renegade', ['r', 'e', 'n', 'e', 'g', 'a', 'd', 'e'], 'O\n'],
#   ['province', ['p', 'r', 'o', 'v', 'i', 'n', 'c', 'e'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['China', ['C', 'h', 'i', 'n', 'a'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['which', ['w', 'h', 'i', 'c', 'h'], 'O\n'],
#   ['has', ['h', 'a', 's'], 'O\n'],
#   ['long', ['l', 'o', 'n', 'g'], 'O\n'],
#   ['opposed', ['o', 'p', 'p', 'o', 's', 'e', 'd'], 'O\n'],
#   ['all', ['a', 'l', 'l'], 'O\n'],
#   ['Taipei', ['T', 'a', 'i', 'p', 'e', 'i'], 'B-LOC\n'],
#   ['efforts', ['e', 'f', 'f', 'o', 'r', 't', 's'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['gain', ['g', 'a', 'i', 'n'], 'O\n'],
#   ['greater', ['g', 'r', 'e', 'a', 't', 'e', 'r'], 'O\n'],
#   ['international',
#    ['i', 'n', 't', 'e', 'r', 'n', 'a', 't', 'i', 'o', 'n', 'a', 'l'],
#    'O\n'],
#   ['recognition',
#    ['r', 'e', 'c', 'o', 'g', 'n', 'i', 't', 'i', 'o', 'n'],
#    'O\n'],
#   [',', [','], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['infuriated', ['i', 'n', 'f', 'u', 'r', 'i', 'a', 't', 'e', 'd'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['visit', ['v', 'i', 's', 'i', 't'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['Ukraine', ['U', 'k', 'r', 'a', 'i', 'n', 'e'], 'B-LOC\n'],
#   ['this', ['t', 'h', 'i', 's'], 'O\n'],
#   ['week', ['w', 'e', 'e', 'k'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['Taiwanese', ['T', 'a', 'i', 'w', 'a', 'n', 'e', 's', 'e'], 'B-MISC\n'],
#   ['Vice', ['V', 'i', 'c', 'e'], 'O\n'],
#   ['President', ['P', 'r', 'e', 's', 'i', 'd', 'e', 'n', 't'], 'O\n'],
#   ['Lien', ['L', 'i', 'e', 'n'], 'B-PER\n'],
#   ['.', ['.'], 'O\n']],
#  [['China', ['C', 'h', 'i', 'n', 'a'], 'B-LOC\n'],
#   ['says', ['s', 'a', 'y', 's'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['right', ['r', 'i', 'g', 'h', 't'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['BEIJING', ['B', 'E', 'I', 'J', 'I', 'N', 'G'], 'B-LOC\n'],
#   ['1996-08-22', ['1', '9', '9', '6', '-', '0', '8', '-', '2', '2'], 'O\n']],
#  [['China', ['C', 'h', 'i', 'n', 'a'], 'B-LOC\n'],
#   ['has', ['h', 'a', 's'], 'O\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['it', ['i', 't'], 'O\n'],
#   ['was', ['w', 'a', 's'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['political', ['p', 'o', 'l', 'i', 't', 'i', 'c', 'a', 'l'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'B-LOC\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['rival', ['r', 'i', 'v', 'a', 'l'], 'O\n'],
#   ['island', ['i', 's', 'l', 'a', 'n', 'd'], 'O\n'],
#   ['should', ['s', 'h', 'o', 'u', 'l', 'd'], 'O\n'],
#   ['take', ['t', 'a', 'k', 'e'], 'O\n'],
#   ['practical', ['p', 'r', 'a', 'c', 't', 'i', 'c', 'a', 'l'], 'O\n'],
#   ['steps', ['s', 't', 'e', 'p', 's'], 'O\n'],
#   ['towards', ['t', 'o', 'w', 'a', 'r', 'd', 's'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['goal', ['g', 'o', 'a', 'l'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Consultations',
#    ['C', 'o', 'n', 's', 'u', 'l', 't', 'a', 't', 'i', 'o', 'n', 's'],
#    'O\n'],
#   ['should', ['s', 'h', 'o', 'u', 'l', 'd'], 'O\n'],
#   ['be', ['b', 'e'], 'O\n'],
#   ['held', ['h', 'e', 'l', 'd'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['set', ['s', 'e', 't'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['time', ['t', 'i', 'm', 'e'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['format', ['f', 'o', 'r', 'm', 'a', 't'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['talks', ['t', 'a', 'l', 'k', 's'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['official', ['o', 'f', 'f', 'i', 'c', 'i', 'a', 'l'], 'O\n'],
#   ['Xinhua', ['X', 'i', 'n', 'h', 'u', 'a'], 'B-ORG\n'],
#   ['news', ['n', 'e', 'w', 's'], 'O\n'],
#   ['agency', ['a', 'g', 'e', 'n', 'c', 'y'], 'O\n'],
#   ['quoted', ['q', 'u', 'o', 't', 'e', 'd'], 'O\n'],
#   ['Tang', ['T', 'a', 'n', 'g'], 'B-PER\n'],
#   ['Shubei', ['S', 'h', 'u', 'b', 'e', 'i'], 'I-PER\n'],
#   [',', [','], 'O\n'],
#   ['executive', ['e', 'x', 'e', 'c', 'u', 't', 'i', 'v', 'e'], 'O\n'],
#   ['vice', ['v', 'i', 'c', 'e'], 'O\n'],
#   ['chairman', ['c', 'h', 'a', 'i', 'r', 'm', 'a', 'n'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['Association',
#    ['A', 's', 's', 'o', 'c', 'i', 'a', 't', 'i', 'o', 'n'],
#    'B-ORG\n'],
#   ['for', ['f', 'o', 'r'], 'I-ORG\n'],
#   ['Relations', ['R', 'e', 'l', 'a', 't', 'i', 'o', 'n', 's'], 'I-ORG\n'],
#   ['Across', ['A', 'c', 'r', 'o', 's', 's'], 'I-ORG\n'],
#   ['the', ['t', 'h', 'e'], 'I-ORG\n'],
#   ['Taiwan', ['T', 'a', 'i', 'w', 'a', 'n'], 'I-ORG\n'],
#   ['Straits', ['S', 't', 'r', 'a', 'i', 't', 's'], 'I-ORG\n'],
#   [',', [','], 'O\n'],
#   ['as', ['a', 's'], 'O\n'],
#   ['saying', ['s', 'a', 'y', 'i', 'n', 'g'], 'O\n'],
#   ['late', ['l', 'a', 't', 'e'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Wednesday', ['W', 'e', 'd', 'n', 'e', 's', 'd', 'a', 'y'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['German', ['G', 'e', 'r', 'm', 'a', 'n'], 'B-MISC\n'],
#   ['July', ['J', 'u', 'l', 'y'], 'O\n'],
#   ['car', ['c', 'a', 'r'], 'O\n'],
#   ['registrations',
#    ['r', 'e', 'g', 'i', 's', 't', 'r', 'a', 't', 'i', 'o', 'n', 's'],
#    'O\n'],
#   ['up', ['u', 'p'], 'O\n'],
#   ['14.2', ['1', '4', '.', '2'], 'O\n'],
#   ['pct', ['p', 'c', 't'], 'O\n'],
#   ['yr', ['y', 'r'], 'O\n'],
#   ['/', ['/'], 'O\n'],
#   ['yr', ['y', 'r'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['FRANKFURT', ['F', 'R', 'A', 'N', 'K', 'F', 'U', 'R', 'T'], 'B-LOC\n'],
#   ['1996-08-22', ['1', '9', '9', '6', '-', '0', '8', '-', '2', '2'], 'O\n']],
#  [['German', ['G', 'e', 'r', 'm', 'a', 'n'], 'B-MISC\n'],
#   ['first-time', ['f', 'i', 'r', 's', 't', '-', 't', 'i', 'm', 'e'], 'O\n'],
#   ['registrations',
#    ['r', 'e', 'g', 'i', 's', 't', 'r', 'a', 't', 'i', 'o', 'n', 's'],
#    'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['motor', ['m', 'o', 't', 'o', 'r'], 'O\n'],
#   ['vehicles', ['v', 'e', 'h', 'i', 'c', 'l', 'e', 's'], 'O\n'],
#   ['jumped', ['j', 'u', 'm', 'p', 'e', 'd'], 'O\n'],
#   ['14.2', ['1', '4', '.', '2'], 'O\n'],
#   ['percent', ['p', 'e', 'r', 'c', 'e', 'n', 't'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['July', ['J', 'u', 'l', 'y'], 'O\n'],
#   ['this', ['t', 'h', 'i', 's'], 'O\n'],
#   ['year', ['y', 'e', 'a', 'r'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['year-earlier',
#    ['y', 'e', 'a', 'r', '-', 'e', 'a', 'r', 'l', 'i', 'e', 'r'],
#    'O\n'],
#   ['period', ['p', 'e', 'r', 'i', 'o', 'd'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['Federal', ['F', 'e', 'd', 'e', 'r', 'a', 'l'], 'B-ORG\n'],
#   ['office', ['o', 'f', 'f', 'i', 'c', 'e'], 'I-ORG\n'],
#   ['for', ['f', 'o', 'r'], 'I-ORG\n'],
#   ['motor', ['m', 'o', 't', 'o', 'r'], 'I-ORG\n'],
#   ['vehicles', ['v', 'e', 'h', 'i', 'c', 'l', 'e', 's'], 'I-ORG\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['office', ['o', 'f', 'f', 'i', 'c', 'e'], 'O\n'],
#   ['said', ['s', 'a', 'i', 'd'], 'O\n'],
#   ['356,725', ['3', '5', '6', ',', '7', '2', '5'], 'O\n'],
#   ['new', ['n', 'e', 'w'], 'O\n'],
#   ['cars', ['c', 'a', 'r', 's'], 'O\n'],
#   ['were', ['w', 'e', 'r', 'e'], 'O\n'],
#   ['registered', ['r', 'e', 'g', 'i', 's', 't', 'e', 'r', 'e', 'd'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['July', ['J', 'u', 'l', 'y'], 'O\n'],
#   ['1996', ['1', '9', '9', '6'], 'O\n'],
#   ['--', ['-', '-'], 'O\n'],
#   ['304,850', ['3', '0', '4', ',', '8', '5', '0'], 'O\n'],
#   ['passenger', ['p', 'a', 's', 's', 'e', 'n', 'g', 'e', 'r'], 'O\n'],
#   ['cars', ['c', 'a', 'r', 's'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['15,613', ['1', '5', ',', '6', '1', '3'], 'O\n'],
#   ['trucks', ['t', 'r', 'u', 'c', 'k', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['figures', ['f', 'i', 'g', 'u', 'r', 'e', 's'], 'O\n'],
#   ['represent', ['r', 'e', 'p', 'r', 'e', 's', 'e', 'n', 't'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['13.6', ['1', '3', '.', '6'], 'O\n'],
#   ['percent', ['p', 'e', 'r', 'c', 'e', 'n', 't'], 'O\n'],
#   ['increase', ['i', 'n', 'c', 'r', 'e', 'a', 's', 'e'], 'O\n'],
# ...
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['rankings', ['r', 'a', 'n', 'k', 'i', 'n', 'g', 's'], 'O\n'],
#   ['are', ['a', 'r', 'e'], 'O\n'],
#   ['based', ['b', 'a', 's', 'e', 'd'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['formula', ['f', 'o', 'r', 'm', 'u', 'l', 'a'], 'O\n'],
#   ['that', ['t', 'h', 'a', 't'], 'O\n'],
#   ['takes', ['t', 'a', 'k', 'e', 's'], 'O\n'],
#   ['into', ['i', 'n', 't', 'o'], 'O\n'],
#   ['account', ['a', 'c', 'c', 'o', 'u', 'n', 't'], 'O\n'],
#   ['many', ['m', 'a', 'n', 'y'], 'O\n'],
#   ['factors', ['f', 'a', 'c', 't', 'o', 'r', 's'], 'O\n'],
#   ['including', ['i', 'n', 'c', 'l', 'u', 'd', 'i', 'n', 'g'], 'O\n'],
#   ['red', ['r', 'e', 'd'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['yellow', ['y', 'e', 'l', 'l', 'o', 'w'], 'O\n'],
#   ['cards', ['c', 'a', 'r', 'd', 's'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['coaching', ['c', 'o', 'a', 'c', 'h', 'i', 'n', 'g'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['spectators', ['s', 'p', 'e', 'c', 't', 'a', 't', 'o', 'r', 's'], 'O\n'],
#   ["'", ["'"], 'O\n'],
#   ['behaviour', ['b', 'e', 'h', 'a', 'v', 'i', 'o', 'u', 'r'], 'O\n'],
#   ['at', ['a', 't'], 'O\n'],
#   ['matches', ['m', 'a', 't', 'c', 'h', 'e', 's'], 'O\n'],
#   ['played', ['p', 'l', 'a', 'y', 'e', 'd'], 'O\n'],
#   ['at', ['a', 't'], 'O\n'],
#   ['an', ['a', 'n'], 'O\n'],
#   ['international',
#    ['i', 'n', 't', 'e', 'r', 'n', 'a', 't', 'i', 'o', 'n', 'a', 'l'],
#    'O\n'],
#   ['level', ['l', 'e', 'v', 'e', 'l'], 'O\n'],
#   ['by', ['b', 'y'], 'O\n'],
#   ['clubs', ['c', 'l', 'u', 'b', 's'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['national', ['n', 'a', 't', 'i', 'o', 'n', 'a', 'l'], 'O\n'],
#   ['teams', ['t', 'e', 'a', 'm', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Only', ['O', 'n', 'l', 'y'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['top', ['t', 'o', 'p'], 'O\n'],
#   ['three', ['t', 'h', 'r', 'e', 'e'], 'O\n'],
#   ['countries', ['c', 'o', 'u', 'n', 't', 'r', 'i', 'e', 's'], 'O\n'],
#   ['are', ['a', 'r', 'e'], 'O\n'],
#   ['allocated', ['a', 'l', 'l', 'o', 'c', 'a', 't', 'e', 'd'], 'O\n'],
#   ['additional', ['a', 'd', 'd', 'i', 't', 'i', 'o', 'n', 'a', 'l'], 'O\n'],
#   ['places', ['p', 'l', 'a', 'c', 'e', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['UEFA', ['U', 'E', 'F', 'A'], 'B-MISC\n'],
#   ['Fair', ['F', 'a', 'i', 'r'], 'I-MISC\n'],
#   ['Play', ['P', 'l', 'a', 'y'], 'I-MISC\n'],
#   ['rankings', ['r', 'a', 'n', 'k', 'i', 'n', 'g', 's'], 'O\n'],
#   ['are', ['a', 'r', 'e'], 'O\n'],
#   [':', [':'], 'O\n'],
#   ['1', ['1'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Norway', ['N', 'o', 'r', 'w', 'a', 'y'], 'B-LOC\n'],
#   ['8.62', ['8', '.', '6', '2'], 'O\n'],
#   ['points', ['p', 'o', 'i', 'n', 't', 's'], 'O\n']],
#  [['2.', ['2', '.'], 'O\n'],
#   ['England', ['E', 'n', 'g', 'l', 'a', 'n', 'd'], 'B-LOC\n'],
#   ['8.61', ['8', '.', '6', '1'], 'O\n']],
#  [['3.', ['3', '.'], 'O\n'],
#   ['Sweden', ['S', 'w', 'e', 'd', 'e', 'n'], 'B-LOC\n'],
#   ['8.57', ['8', '.', '5', '7'], 'O\n']],
#  [['4.', ['4', '.'], 'O\n'],
#   ['Faroe', ['F', 'a', 'r', 'o', 'e'], 'B-LOC\n'],
#   ['Islands', ['I', 's', 'l', 'a', 'n', 'd', 's'], 'I-LOC\n'],
#   ['8.56', ['8', '.', '5', '6'], 'O\n']],
#  [['5.', ['5', '.'], 'O\n'],
#   ['Wales', ['W', 'a', 'l', 'e', 's'], 'B-LOC\n'],
#   ['8.54', ['8', '.', '5', '4'], 'O\n']],
#  [['6.', ['6', '.'], 'O\n'],
#   ['Estonia', ['E', 's', 't', 'o', 'n', 'i', 'a'], 'B-LOC\n'],
#   ['8.52', ['8', '.', '5', '2'], 'O\n']],
#  [['7.', ['7', '.'], 'O\n'],
#   ['Ireland', ['I', 'r', 'e', 'l', 'a', 'n', 'd'], 'B-LOC\n'],
#   ['8.45', ['8', '.', '4', '5'], 'O\n']],
#  [['8.', ['8', '.'], 'O\n'],
#   ['Belarus', ['B', 'e', 'l', 'a', 'r', 'u', 's'], 'B-LOC\n'],
#   ['8.39', ['8', '.', '3', '9'], 'O\n']],
#  [['9.', ['9', '.'], 'O\n'],
#   ['Iceland', ['I', 'c', 'e', 'l', 'a', 'n', 'd'], 'B-LOC\n'],
#   ['8.35', ['8', '.', '3', '5'], 'O\n']],
#  [['10.', ['1', '0', '.'], 'O\n'],
#   ['Netherlands',
#    ['N', 'e', 't', 'h', 'e', 'r', 'l', 'a', 'n', 'd', 's'],
#    'B-LOC\n'],
#   ['8.30', ['8', '.', '3', '0'], 'O\n']],
#  [['10.', ['1', '0', '.'], 'O\n'],
#   ['Denmark', ['D', 'e', 'n', 'm', 'a', 'r', 'k'], 'B-LOC\n'],
#   ['8.30', ['8', '.', '3', '0'], 'O\n']],
#  [['10.', ['1', '0', '.'], 'O\n'],
#   ['Germany', ['G', 'e', 'r', 'm', 'a', 'n', 'y'], 'B-LOC\n'],
#   ['8.30', ['8', '.', '3', '0'], 'O\n']],
#  [['13.', ['1', '3', '.'], 'O\n'],
#   ['Scotland', ['S', 'c', 'o', 't', 'l', 'a', 'n', 'd'], 'B-LOC\n'],
#   ['8.29', ['8', '.', '2', '9'], 'O\n']],
#  [['13.', ['1', '3', '.'], 'O\n'],
#   ['Latvia', ['L', 'a', 't', 'v', 'i', 'a'], 'B-LOC\n'],
#   ['8.29', ['8', '.', '2', '9'], 'O\n']],
#  [['15.', ['1', '5', '.'], 'O\n'],
#   ['Moldova', ['M', 'o', 'l', 'd', 'o', 'v', 'a'], 'B-LOC\n'],
#   ['8.24', ['8', '.', '2', '4'], 'O\n']],
#  [['16.', ['1', '6', '.'], 'O\n'],
#   ['Yugoslavia',
#    ['Y', 'u', 'g', 'o', 's', 'l', 'a', 'v', 'i', 'a'],
#    'B-LOC\n'],
#   ['8.22', ['8', '.', '2', '2'], 'O\n']],
#  [['16.', ['1', '6', '.'], 'O\n'],
#   ['Belgium', ['B', 'e', 'l', 'g', 'i', 'u', 'm'], 'B-LOC\n'],
#   ['8.22', ['8', '.', '2', '2'], 'O\n']],
#  [['18.', ['1', '8', '.'], 'O\n'],
#   ['Luxembourg',
#    ['L', 'u', 'x', 'e', 'm', 'b', 'o', 'u', 'r', 'g'],
#    'B-LOC\n'],
#   ['8.20', ['8', '.', '2', '0'], 'O\n']],
#  [['19.', ['1', '9', '.'], 'O\n'],
#   ['France', ['F', 'r', 'a', 'n', 'c', 'e'], 'B-LOC\n'],
#   ['8.18', ['8', '.', '1', '8'], 'O\n']],
#  [['20.', ['2', '0', '.'], 'O\n'],
#   ['Israel', ['I', 's', 'r', 'a', 'e', 'l'], 'B-LOC\n'],
#   ['8.17', ['8', '.', '1', '7'], 'O\n']],
#  [['21.', ['2', '1', '.'], 'O\n'],
#   ['Switzerland',
#    ['S', 'w', 'i', 't', 'z', 'e', 'r', 'l', 'a', 'n', 'd'],
#    'B-LOC\n'],
#   ['8.15', ['8', '.', '1', '5'], 'O\n']],
#  [['21.', ['2', '1', '.'], 'O\n'],
#   ['Slovakia', ['S', 'l', 'o', 'v', 'a', 'k', 'i', 'a'], 'B-LOC\n'],
#   ['8.15', ['8', '.', '1', '5'], 'O\n']],
#  [['23.', ['2', '3', '.'], 'O\n'],
#   ['Poland', ['P', 'o', 'l', 'a', 'n', 'd'], 'B-LOC\n'],
#   ['8.12', ['8', '.', '1', '2'], 'O\n']],
#  [['23.', ['2', '3', '.'], 'O\n'],
#   ['Portugal', ['P', 'o', 'r', 't', 'u', 'g', 'a', 'l'], 'B-LOC\n'],
#   ['8.12', ['8', '.', '1', '2'], 'O\n']],
#  [['25.', ['2', '5', '.'], 'O\n'],
#   ['Georgia', ['G', 'e', 'o', 'r', 'g', 'i', 'a'], 'B-LOC\n'],
#   ['8.10', ['8', '.', '1', '0'], 'O\n']],
#  [['26.', ['2', '6', '.'], 'O\n'],
#   ['Ukraine', ['U', 'k', 'r', 'a', 'i', 'n', 'e'], 'B-LOC\n'],
#   ['8.09', ['8', '.', '0', '9'], 'O\n']],
#  [['26.', ['2', '6', '.'], 'O\n'],
#   ['Spain', ['S', 'p', 'a', 'i', 'n'], 'B-LOC\n'],
#   ['8.09', ['8', '.', '0', '9'], 'O\n']],
#  [['26.', ['2', '6', '.'], 'O\n'],
#   ['Finland', ['F', 'i', 'n', 'l', 'a', 'n', 'd'], 'B-LOC\n'],
#   ['8.09', ['8', '.', '0', '9'], 'O\n']],
#  [['29.', ['2', '9', '.'], 'O\n'],
#   ['Macedonia', ['M', 'a', 'c', 'e', 'd', 'o', 'n', 'i', 'a'], 'B-LOC\n'],
#   ['8.07', ['8', '.', '0', '7'], 'O\n']],
#  [['30.', ['3', '0', '.'], 'O\n'],
#   ['Lithuania', ['L', 'i', 't', 'h', 'u', 'a', 'n', 'i', 'a'], 'B-LOC\n'],
#   ['8.06', ['8', '.', '0', '6'], 'O\n']],
#  [['31.', ['3', '1', '.'], 'O\n'],
#   ['Austria', ['A', 'u', 's', 't', 'r', 'i', 'a'], 'B-LOC\n'],
#   ['8.05', ['8', '.', '0', '5'], 'O\n']],
#  [['32.', ['3', '2', '.'], 'O\n'],
#   ['Russia', ['R', 'u', 's', 's', 'i', 'a'], 'B-LOC\n'],
#   ['8.03', ['8', '.', '0', '3'], 'O\n']],
#  [['33.', ['3', '3', '.'], 'O\n'],
#   ['Romania', ['R', 'o', 'm', 'a', 'n', 'i', 'a'], 'B-LOC\n'],
#   ['8.02', ['8', '.', '0', '2'], 'O\n']],
#  [['33.', ['3', '3', '.'], 'O\n'],
#   ['Turkey', ['T', 'u', 'r', 'k', 'e', 'y'], 'B-LOC\n'],
#   ['8.02', ['8', '.', '0', '2'], 'O\n']],
#  [['35.', ['3', '5', '.'], 'O\n'],
#   ['Hungary', ['H', 'u', 'n', 'g', 'a', 'r', 'y'], 'B-LOC\n'],
#   ['7.98', ['7', '.', '9', '8'], 'O\n']],
#  [['36.', ['3', '6', '.'], 'O\n'],
#   ['Czech', ['C', 'z', 'e', 'c', 'h'], 'B-LOC\n'],
#   ['Republic', ['R', 'e', 'p', 'u', 'b', 'l', 'i', 'c'], 'I-LOC\n'],
#   ['7.95', ['7', '.', '9', '5'], 'O\n']],
#  [['37.', ['3', '7', '.'], 'O\n'],
#   ['Greece', ['G', 'r', 'e', 'e', 'c', 'e'], 'B-LOC\n'],
#   ['7.89', ['7', '.', '8', '9'], 'O\n']],
#  [['37.', ['3', '7', '.'], 'O\n'],
#   ['Northern', ['N', 'o', 'r', 't', 'h', 'e', 'r', 'n'], 'B-LOC\n'],
#   ['Ireland', ['I', 'r', 'e', 'l', 'a', 'n', 'd'], 'I-LOC\n'],
#   ['7.89', ['7', '.', '8', '9'], 'O\n']],
#  [['39.', ['3', '9', '.'], 'O\n'],
#   ['Italy', ['I', 't', 'a', 'l', 'y'], 'B-LOC\n'],
#   ['7.85', ['7', '.', '8', '5'], 'O\n']],
#  [['40.', ['4', '0', '.'], 'O\n'],
#   ['Cyprus', ['C', 'y', 'p', 'r', 'u', 's'], 'B-LOC\n'],
#   ['7.83', ['7', '.', '8', '3'], 'O\n']],
#  [['41.', ['4', '1', '.'], 'O\n'],
#   ['Armenia', ['A', 'r', 'm', 'e', 'n', 'i', 'a'], 'B-LOC\n'],
#   ['7.80', ['7', '.', '8', '0'], 'O\n']],
#  [['42.', ['4', '2', '.'], 'O\n'],
#   ['Slovenia', ['S', 'l', 'o', 'v', 'e', 'n', 'i', 'a'], 'B-LOC\n'],
#   ['7.77', ['7', '.', '7', '7'], 'O\n']],
#  [['43.', ['4', '3', '.'], 'O\n'],
#   ['Croatia', ['C', 'r', 'o', 'a', 't', 'i', 'a'], 'B-LOC\n'],
#   ['7.75', ['7', '.', '7', '5'], 'O\n']],
#  [['44.', ['4', '4', '.'], 'O\n'],
#   ['Bulgaria', ['B', 'u', 'l', 'g', 'a', 'r', 'i', 'a'], 'B-LOC\n'],
#   ['7.73', ['7', '.', '7', '3'], 'O\n']],
#  [['45.', ['4', '5', '.'], 'O\n'],
#   ['Malta', ['M', 'a', 'l', 't', 'a'], 'B-LOC\n'],
#   ['7.40', ['7', '.', '4', '0'], 'O\n']],
#  [['CRICKET', ['C', 'R', 'I', 'C', 'K', 'E', 'T'], 'O\n'],
#   ['-', ['-'], 'O\n'],
#   ['POLICE', ['P', 'O', 'L', 'I', 'C', 'E'], 'O\n'],
#   ['COMMANDOS', ['C', 'O', 'M', 'M', 'A', 'N', 'D', 'O', 'S'], 'O\n'],
#   ['ON', ['O', 'N'], 'O\n'],
#   ['HAND', ['H', 'A', 'N', 'D'], 'O\n'],
#   ['FOR', ['F', 'O', 'R'], 'O\n'],
#   ['AUSTRALIANS',
#    ['A', 'U', 'S', 'T', 'R', 'A', 'L', 'I', 'A', 'N', 'S'],
#    'B-MISC\n'],
#   ["'", ["'"], 'O\n'],
#   ['FIRST', ['F', 'I', 'R', 'S', 'T'], 'O\n'],
#   ['MATCH', ['M', 'A', 'T', 'C', 'H'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['COLOMBO', ['C', 'O', 'L', 'O', 'M', 'B', 'O'], 'B-LOC\n'],
#   ['1996-08-22', ['1', '9', '9', '6', '-', '0', '8', '-', '2', '2'], 'O\n']],
#  [['Armed', ['A', 'r', 'm', 'e', 'd'], 'O\n'],
#   ['police', ['p', 'o', 'l', 'i', 'c', 'e'], 'O\n'],
#   ['commandos', ['c', 'o', 'm', 'm', 'a', 'n', 'd', 'o', 's'], 'O\n'],
#   ['patrolled', ['p', 'a', 't', 'r', 'o', 'l', 'l', 'e', 'd'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['ground', ['g', 'r', 'o', 'u', 'n', 'd'], 'O\n'],
#   ['when', ['w', 'h', 'e', 'n'], 'O\n'],
#   ['Australia', ['A', 'u', 's', 't', 'r', 'a', 'l', 'i', 'a'], 'B-LOC\n'],
#   ['opened', ['o', 'p', 'e', 'n', 'e', 'd'], 'O\n'],
#   ['their', ['t', 'h', 'e', 'i', 'r'], 'O\n'],
#   ['short', ['s', 'h', 'o', 'r', 't'], 'O\n'],
#   ['tour', ['t', 'o', 'u', 'r'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['Sri', ['S', 'r', 'i'], 'B-LOC\n'],
#   ['Lanka', ['L', 'a', 'n', 'k', 'a'], 'I-LOC\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['five-run', ['f', 'i', 'v', 'e', '-', 'r', 'u', 'n'], 'O\n'],
#   ['win', ['w', 'i', 'n'], 'O\n'],
#   ['over', ['o', 'v', 'e', 'r'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['country', ['c', 'o', 'u', 'n', 't', 'r', 'y'], 'O\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['youth', ['y', 'o', 'u', 't', 'h'], 'O\n'],
#   ['team', ['t', 'e', 'a', 'm'], 'O\n'],
#   ['on', ['o', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Australia', ['A', 'u', 's', 't', 'r', 'a', 'l', 'i', 'a'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['Sri', ['S', 'r', 'i'], 'B-LOC\n'],
#   ['Lanka', ['L', 'a', 'n', 'k', 'a'], 'I-LOC\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['limited', ['l', 'i', 'm', 'i', 't', 'e', 'd'], 'O\n'],
#   ['overs', ['o', 'v', 'e', 'r', 's'], 'O\n'],
#   ['tournament', ['t', 'o', 'u', 'r', 'n', 'a', 'm', 'e', 'n', 't'], 'O\n'],
#   ['which', ['w', 'h', 'i', 'c', 'h'], 'O\n'],
#   ['also', ['a', 'l', 's', 'o'], 'O\n'],
#   ['includes', ['i', 'n', 'c', 'l', 'u', 'd', 'e', 's'], 'O\n'],
#   ['India', ['I', 'n', 'd', 'i', 'a'], 'B-LOC\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['Zimbabwe', ['Z', 'i', 'm', 'b', 'a', 'b', 'w', 'e'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['have', ['h', 'a', 'v', 'e'], 'O\n'],
#   ['been', ['b', 'e', 'e', 'n'], 'O\n'],
#   ['promised', ['p', 'r', 'o', 'm', 'i', 's', 'e', 'd'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['presence', ['p', 'r', 'e', 's', 'e', 'n', 'c', 'e'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['commandos', ['c', 'o', 'm', 'm', 'a', 'n', 'd', 'o', 's'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['sniffer', ['s', 'n', 'i', 'f', 'f', 'e', 'r'], 'O\n'],
#   ['dogs', ['d', 'o', 'g', 's'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['plainclothes',
#    ['p', 'l', 'a', 'i', 'n', 'c', 'l', 'o', 't', 'h', 'e', 's'],
#    'O\n'],
#   ['policemen', ['p', 'o', 'l', 'i', 'c', 'e', 'm', 'e', 'n'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['ensure', ['e', 'n', 's', 'u', 'r', 'e'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['tournament', ['t', 'o', 'u', 'r', 'n', 'a', 'm', 'e', 'n', 't'], 'O\n'],
#   ['is', ['i', 's'], 'O\n'],
#   ['trouble-free',
#    ['t', 'r', 'o', 'u', 'b', 'l', 'e', '-', 'f', 'r', 'e', 'e'],
#    'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['They', ['T', 'h', 'e', 'y'], 'O\n'],
#   ['are', ['a', 'r', 'e'], 'O\n'],
#   ['making', ['m', 'a', 'k', 'i', 'n', 'g'], 'O\n'],
#   ['their', ['t', 'h', 'e', 'i', 'r'], 'O\n'],
#   ['first', ['f', 'i', 'r', 's', 't'], 'O\n'],
#   ['visit', ['v', 'i', 's', 'i', 't'], 'O\n'],
#   ['to', ['t', 'o'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['island', ['i', 's', 'l', 'a', 'n', 'd'], 'O\n'],
#   ['since', ['s', 'i', 'n', 'c', 'e'], 'O\n'],
#   ['boycotting', ['b', 'o', 'y', 'c', 'o', 't', 't', 'i', 'n', 'g'], 'O\n'],
#   ['a', ['a'], 'O\n'],
#   ['World', ['W', 'o', 'r', 'l', 'd'], 'B-MISC\n'],
#   ['Cup', ['C', 'u', 'p'], 'I-MISC\n'],
#   ['fixture', ['f', 'i', 'x', 't', 'u', 'r', 'e'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['February', ['F', 'e', 'b', 'r', 'u', 'a', 'r', 'y'], 'O\n'],
#   ['because', ['b', 'e', 'c', 'a', 'u', 's', 'e'], 'O\n'],
#   ['of', ['o', 'f'], 'O\n'],
#   ['fears', ['f', 'e', 'a', 'r', 's'], 'O\n'],
#   ['over', ['o', 'v', 'e', 'r'], 'O\n'],
#   ['ethnic', ['e', 't', 'h', 'n', 'i', 'c'], 'O\n'],
#   ['violence', ['v', 'i', 'o', 'l', 'e', 'n', 'c', 'e'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Australia', ['A', 'u', 's', 't', 'r', 'a', 'l', 'i', 'a'], 'B-LOC\n'],
#   [',', [','], 'O\n'],
#   ['batting', ['b', 'a', 't', 't', 'i', 'n', 'g'], 'O\n'],
#   ['first', ['f', 'i', 'r', 's', 't'], 'O\n'],
#   ['in', ['i', 'n'], 'O\n'],
#   ['Thursday', ['T', 'h', 'u', 'r', 's', 'd', 'a', 'y'], 'O\n'],
#   ["'s", ["'", 's'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['warm-up', ['w', 'a', 'r', 'm', '-', 'u', 'p'], 'O\n'],
#   ['match', ['m', 'a', 't', 'c', 'h'], 'O\n'],
#   [',', [','], 'O\n'],
#   ['scored', ['s', 'c', 'o', 'r', 'e', 'd'], 'O\n'],
#   ['251', ['2', '5', '1'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['seven', ['s', 'e', 'v', 'e', 'n'], 'O\n'],
#   ['from', ['f', 'r', 'o', 'm'], 'O\n'],
#   ['their', ['t', 'h', 'e', 'i', 'r'], 'O\n'],
#   ['50', ['5', '0'], 'O\n'],
#   ['overs', ['o', 'v', 'e', 'r', 's'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['Ricky', ['R', 'i', 'c', 'k', 'y'], 'B-PER\n'],
#   ['Ponting', ['P', 'o', 'n', 't', 'i', 'n', 'g'], 'I-PER\n'],
#   ['led', ['l', 'e', 'd'], 'O\n'],
#   ['the', ['t', 'h', 'e'], 'O\n'],
#   ['way', ['w', 'a', 'y'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['100', ['1', '0', '0'], 'O\n'],
#   ['off', ['o', 'f', 'f'], 'O\n'],
#   ['119', ['1', '1', '9'], 'O\n'],
#   ['balls', ['b', 'a', 'l', 'l', 's'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['two', ['t', 'w', 'o'], 'O\n'],
#   ['sixes', ['s', 'i', 'x', 'e', 's'], 'O\n'],
#   ['and', ['a', 'n', 'd'], 'O\n'],
#   ['nine', ['n', 'i', 'n', 'e'], 'O\n'],
#   ['fours', ['f', 'o', 'u', 'r', 's'], 'O\n'],
#   ['before', ['b', 'e', 'f', 'o', 'r', 'e'], 'O\n'],
#   ['retiring', ['r', 'e', 't', 'i', 'r', 'i', 'n', 'g'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  [['The', ['T', 'h', 'e'], 'O\n'],
#   ['youth', ['y', 'o', 'u', 't', 'h'], 'O\n'],
#   ['side', ['s', 'i', 'd', 'e'], 'O\n'],
#   ['replied', ['r', 'e', 'p', 'l', 'i', 'e', 'd'], 'O\n'],
#   ['with', ['w', 'i', 't', 'h'], 'O\n'],
#   ['246', ['2', '4', '6'], 'O\n'],
#   ['for', ['f', 'o', 'r'], 'O\n'],
#   ['seven', ['s', 'e', 'v', 'e', 'n'], 'O\n'],
#   ['.', ['.'], 'O\n']],
#  ...]

# %% [markdown]
# ### Add Character Information

# %%
def add_char_info(sentences):
    for i, sentence in enumerate(sentences):
        for j, data in enumerate(sentence):
            chars = [c for c in data[0]]
            sentences[i][j] = [data[0], chars, data[1]]
    return sentences

# %%
train_sentences = add_char_info(train_sentences)
dev_sentences = add_char_info(dev_sentences)
test_sentences = add_char_info(test_sentences)
train_sentences[0]
# Out:
# [['EU', ['E', 'U'], 'B-ORG\n'],
#  ['rejects', ['r', 'e', 'j', 'e', 'c', 't', 's'], 'O\n'],
#  ['German', ['G', 'e', 'r', 'm', 'a', 'n'], 'B-MISC\n'],
#  ['call', ['c', 'a', 'l', 'l'], 'O\n'],
#  ['to', ['t', 'o'], 'O\n'],
#  ['boycott', ['b', 'o', 'y', 'c', 'o', 't', 't'], 'O\n'],
#  ['British', ['B', 'r', 'i', 't', 'i', 's', 'h'], 'B-MISC\n'],
#  ['lamb', ['l', 'a', 'm', 'b'], 'O\n'],
#  ['.', ['.'], 'O\n']]

# %% [markdown]
# ### Tag Mappings

# %%
labels_set = set()
words = {}

# unique words and labels in data  
for dataset in [train_sentences, dev_sentences, test_sentences]:
  for sentence in dataset:
    for token, char, label in sentence:
      # token ... token, char ... list of chars, label ... BIO labels   
      labels_set.add(label)
      words[token.lower()] = True

# %%
# mapping for labels
indexes = {"PADDING":0}
for label in labels_set:
  indexes[label] = len(indexes)

  
tag_to_id = {}
for word,index in indexes.items():
  if index != 0:
    word = word[:len(word)-1]
  
  tag_to_id[word] = index
  
tag_to_id
# Out:
# {'PADDING': 0,
#  'B-PER': 1,
#  'B-LOC': 2,
#  'I-MISC': 3,
#  'B-ORG': 4,
#  'I-LOC': 5,
#  'B-MISC': 6,
#  'I-PER': 7,
#  'I-ORG': 8,
#  'O': 9}

# %%
id_to_tag = {v: k for k, v in tag_to_id.items()}
len(id_to_tag)
# Out:
# 10

# %% [markdown]
# ### Word and Character Embeddings

# %%
# Download Glove Word Embeddings
#!wget http://nlp.stanford.edu/data/glove.6B.zip && unzip glove.6B.zip -d /content/

# %%
word_to_id = {}
word_embeddings = []

EMBEDDINGS_FILE = open("data/glove.6B.50d.txt", encoding="utf-8")


# loop through each word in embeddings
for line in EMBEDDINGS_FILE:
    split = line.strip().split(" ")
    word = split[0]  # embedding word entry

    if len(word_to_id) == 0:  # add padding+unknown
        word_to_id["PADDING_TOKEN"] = len(word_to_id)
        vector = np.zeros(len(split) - 1)  # zero vector for 'PADDING' word
        word_embeddings.append(vector)

        word_to_id["UNKNOWN_TOKEN"] = len(word_to_id)
        vector = np.random.uniform(-0.25, 0.25, len(split) - 1)
        word_embeddings.append(vector)

    if split[0].lower() in words:
        vector = np.array([float(num) for num in split[1:]])
        word_embeddings.append(vector)  # word embedding vector
        word_to_id[split[0]] = len(word_to_id)  # corresponding word dict

word_embeddings = np.array(word_embeddings)
word_embeddings.shape, len(word_to_id)
# Out:
# ((22949, 50), 22949)

# %%
id_to_word = {v: k for k, v in word_to_id.items()}
len(id_to_word)
# Out:
# 22949

# %%
# dictionary of all possible characters
char_to_id = {"PADDING": 0, "UNKNOWN": 1}
for c in " 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ.,-_()[]{}!?:;#'\"/\\%$`&=*+@^~|<>":
    char_to_id[c] = len(char_to_id)

len(char_to_id)
# Out:
# 97

# %% [markdown]
# ### Prepare Dataset

# %%
def create_dataset(sentences, word_to_id, tag_to_id, char_to_id):
    unk_index = word_to_id['UNKNOWN_TOKEN']
    pad_index = word_to_id['PADDING_TOKEN']

    dataset = []

    word_count = 0
    unk_word_count = 0

    for sentence in sentences:
        word_indices = []
        char_indices = []
        tag_indices = []

        for word, char, tag in sentence:
            word_count += 1
            if word in word_to_id:
                word_index = word_to_id[word]
            elif word.lower() in word_to_id:
                word_index = word_to_id[word.lower()]
            else:
                word_index = unk_index
                unk_word_count += 1
            char_index = []
            for x in char:
                char_index.append(char_to_id[x])
            # Get the label and map to int
            word_indices.append(word_index)
            char_indices.append(char_index)
            tag_indices.append(tag_to_id[tag])

        dataset.append([word_indices, char_indices, tag_indices])

    return dataset

# %%
def padding(sentences):
  maxlen = 52
  for sentence in sentences:
      char = sentence[1]
      for x in char:
          maxlen = max(maxlen, len(x))
  for i, sentence in enumerate(sentences):
      sentences[i][1] = keras.preprocessing.sequence.pad_sequences(sentences[i][1], 52, padding='post')
  return sentences

# %%
train_set = padding(create_dataset(train_sentences, word_to_id, indexes, char_to_id))
dev_set = padding(create_dataset(dev_sentences, word_to_id, indexes, char_to_id))
test_set = padding(create_dataset(test_sentences, word_to_id, indexes, char_to_id))

# %%
def unpack(dataset):
  words=[]
  chars=[]
  tags = []
  for word, char, tag in dataset:
    words.append(word)
    chars.append(char)
    tags.append(tag)
  
  words = keras.preprocessing.sequence.pad_sequences(words, 52, padding='post')
  chars = keras.preprocessing.sequence.pad_sequences(chars, 52, padding='post')
  tags = keras.preprocessing.sequence.pad_sequences(tags, 52, padding='post')
  tags = keras.utils.to_categorical(tags, num_classes=10)
  
  return words, chars, tags

# %%
train_words, train_chars, train_tags = unpack(train_set)
valid_words, valid_chars, valid_tags = unpack(dev_set)
test_words, test_chars, test_tags = unpack(test_set)

# %%
train_words.shape, train_chars.shape, train_tags.shape
# Out:
# ((14041, 52), (14041, 52, 52), (14041, 52, 10))

# %% [markdown]
# ## Define Model
# The model that is implemented in this project uses the following architectures:
# - Convolution Neural Network for Character Level Representation of words
# - Bidirectional LSTM for Word Level Encoding
# - Conditional Random Fields (CRF Layer) for output decodings.

# %%
# Define Model Layers
char_input = Input(shape=(None, 52,), name="char_input")
char_embed = TimeDistributed(Embedding(len(char_to_id), 30, embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5)), name="char_embed")(char_input)
char_dropout = Dropout(0.5)(char_embed)
char_cnn = TimeDistributed(Conv1D(kernel_size=3, filters=30, padding='same', activation='tanh', strides=1), name="conv1d")(char_dropout)
maxpool_out = TimeDistributed(MaxPooling1D(52), name="maxpool")(char_cnn)
char_flat = TimeDistributed(Flatten(), name="flatten")(maxpool_out)
char = Dropout(0.5)(char_flat)
words_input = Input(shape=(None,), dtype='int32', name='words_input')
words = Embedding(input_dim=word_embeddings.shape[0], output_dim=word_embeddings.shape[1], weights=[word_embeddings],trainable=False)(words_input)
concat = concatenate([words, char])
lstm = Bidirectional(LSTM(200, return_sequences=True, dropout=0.5,recurrent_dropout=0.25), name="bilstm")(concat)
out = TimeDistributed(Dense(len(tag_to_id), activation='softmax'),name="softmax_layer")(lstm)
crf_layer = CRF(10)
output = crf_layer(out)

# Define Model Inputs and Output
model = keras.models.Model([char_input,words_input],output)
# Compile Model
model.compile(optimizer='adam', loss=crf_loss, metrics=[crf_viterbi_accuracy])
# Model Summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# char_input (InputLayer)         (None, None, 52)     0
# __________________________________________________________________________________________________
# char_embed (TimeDistributed)    (None, None, 52, 30) 2910        char_input[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 52, 30) 0           char_embed[0][0]
# __________________________________________________________________________________________________
# conv1d (TimeDistributed)        (None, None, 52, 30) 2730        dropout_1[0][0]
# __________________________________________________________________________________________________
# maxpool (TimeDistributed)       (None, None, 1, 30)  0           conv1d[0][0]
# __________________________________________________________________________________________________
# words_input (InputLayer)        (None, None)         0
# __________________________________________________________________________________________________
# flatten (TimeDistributed)       (None, None, 30)     0           maxpool[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, None, 50)     1147450     words_input[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 30)     0           flatten[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 80)     0           embedding_2[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# bilstm (Bidirectional)          (None, None, 400)    449600      concatenate_1[0][0]
# __________________________________________________________________________________________________
# softmax_layer (TimeDistributed) (None, None, 10)     4010        bilstm[0][0]
# __________________________________________________________________________________________________
# crf_1 (CRF)                     (None, None, 10)     230         softmax_layer[0][0]
# ==================================================================================================
# Total params: 1,606,930
# Trainable params: 459,480
# Non-trainable params: 1,147,450
# __________________________________________________________________________________________________

# %%
#plot_model(model, to_file='data/model.png')

# %%
#!pip install pydot

# %% [markdown]
# ## Training

# %%
history = model.fit([train_chars,train_words], train_tags,validation_data=[[valid_chars, valid_words], valid_tags],batch_size=64,epochs=20,verbose=1)
# Out:
# /home/user/anaconda/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 14041 samples, validate on 3250 samples
# Epoch 1/20
# 14041/14041 [==============================] - 50s 4ms/step - loss: 1.5846 - crf_viterbi_accuracy: 0.5519 - val_loss: 1.1676 - val_crf_viterbi_accuracy: 0.6976
# Epoch 2/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.8526 - crf_viterbi_accuracy: 0.7541 - val_loss: 0.5910 - val_crf_viterbi_accuracy: 0.9460
# Epoch 3/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.4274 - crf_viterbi_accuracy: 0.9523 - val_loss: 0.3539 - val_crf_viterbi_accuracy: 0.9495
# Epoch 4/20
# 14041/14041 [==============================] - 56s 4ms/step - loss: 0.3030 - crf_viterbi_accuracy: 0.9530 - val_loss: 0.2776 - val_crf_viterbi_accuracy: 0.9481
# Epoch 5/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.2336 - crf_viterbi_accuracy: 0.9506 - val_loss: 0.2068 - val_crf_viterbi_accuracy: 0.9477
# Epoch 6/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.1776 - crf_viterbi_accuracy: 0.9526 - val_loss: 0.1587 - val_crf_viterbi_accuracy: 0.9504
# Epoch 7/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.1434 - crf_viterbi_accuracy: 0.9640 - val_loss: 0.1335 - val_crf_viterbi_accuracy: 0.9679
# Epoch 8/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.1232 - crf_viterbi_accuracy: 0.9749 - val_loss: 0.1178 - val_crf_viterbi_accuracy: 0.9769
# Epoch 9/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.1100 - crf_viterbi_accuracy: 0.9786 - val_loss: 0.1059 - val_crf_viterbi_accuracy: 0.9797
# Epoch 10/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.1001 - crf_viterbi_accuracy: 0.9805 - val_loss: 0.0976 - val_crf_viterbi_accuracy: 0.9808
# Epoch 11/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.0925 - crf_viterbi_accuracy: 0.9811 - val_loss: 0.0907 - val_crf_viterbi_accuracy: 0.9810
# Epoch 12/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.0864 - crf_viterbi_accuracy: 0.9815 - val_loss: 0.0848 - val_crf_viterbi_accuracy: 0.9812
# Epoch 13/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.0814 - crf_viterbi_accuracy: 0.9815 - val_loss: 0.0804 - val_crf_viterbi_accuracy: 0.9811
# Epoch 14/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.0768 - crf_viterbi_accuracy: 0.9819 - val_loss: 0.0761 - val_crf_viterbi_accuracy: 0.9813
# Epoch 15/20
# 14041/14041 [==============================] - 53s 4ms/step - loss: 0.0728 - crf_viterbi_accuracy: 0.9821 - val_loss: 0.0727 - val_crf_viterbi_accuracy: 0.9815
# Epoch 16/20
# 14041/14041 [==============================] - 55s 4ms/step - loss: 0.0696 - crf_viterbi_accuracy: 0.9821 - val_loss: 0.0691 - val_crf_viterbi_accuracy: 0.9815
# Epoch 17/20
# 14041/14041 [==============================] - 58s 4ms/step - loss: 0.0663 - crf_viterbi_accuracy: 0.9823 - val_loss: 0.0657 - val_crf_viterbi_accuracy: 0.9817
# Epoch 18/20
# 14041/14041 [==============================] - 58s 4ms/step - loss: 0.0633 - crf_viterbi_accuracy: 0.9824 - val_loss: 0.0630 - val_crf_viterbi_accuracy: 0.9817
# Epoch 19/20
# 14041/14041 [==============================] - 55s 4ms/step - loss: 0.0604 - crf_viterbi_accuracy: 0.9826 - val_loss: 0.0606 - val_crf_viterbi_accuracy: 0.9816
# Epoch 20/20
# 14041/14041 [==============================] - 57s 4ms/step - loss: 0.0578 - crf_viterbi_accuracy: 0.9826 - val_loss: 0.0576 - val_crf_viterbi_accuracy: 0.9816

# %% [markdown]
# ## Training and Testing Accuracy

# %%
_, train_acc = model.evaluate([train_chars, train_words],train_tags)
_, val_acc = model.evaluate([valid_chars, valid_words], valid_tags)
_, test_acc = model.evaluate([test_chars, test_words],test_tags)

print('Training Accuray: ', train_acc * 100)
print('Validation Accuray: ', val_acc * 100)
print('Testing Accuray: ', test_acc * 100)
# Out:
# 14041/14041 [==============================] - 15s 1ms/step
# 3250/3250 [==============================] - 4s 1ms/step
# 3453/3453 [==============================] - 4s 1ms/step
# Training Accuray:  98.36094975471497
# Validation Accuray:  98.16222786903381
# Testing Accuray:  98.3401894569397

# %% [markdown]
# ## Evaluation Metrics Report
# Now we will use Precision, Recall and F1 score to evaluate the performance of our model on each tag.

# %%
# Evaluate
pred_cat = model.predict([test_chars,test_words])
predicted = [[[np.argmax(i)] for i in w] for w in pred_cat]
predicted = np.array(predicted)
actual = [[[np.argmax(i)] for i in w] for w in test_tags]
actual = np.array(actual)
# Convert the index to tag
predicted_tag = [[id_to_tag[i[0]] for i in row] for row in predicted]
actual_tag = [[id_to_tag[i[0]] for i in row] for row in actual]

# Metrics Report
report = flat_classification_report(y_pred=predicted_tag, y_true=actual_tag)
print(report)
# Out:
# /home/user/anaconda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        B-LOC       0.50      0.64      0.56      1653
#       B-MISC       0.67      0.00      0.01       701
#        B-ORG       0.53      0.60      0.56      1657
#        B-PER       0.92      0.96      0.94      1582
#        I-LOC       0.00      0.00      0.00       256
#       I-MISC       0.00      0.00      0.00       216
#        I-ORG       0.54      0.82      0.65       835
#        I-PER       0.96      0.98      0.97      1122
#            O       0.99      0.99      0.99     38169
#      PADDING       1.00      1.00      1.00    133365
#
#     accuracy                           0.98    179556
#    macro avg       0.61      0.60      0.57    179556
# weighted avg       0.98      0.98      0.98    179556

# %% [markdown]
# ## Accuracy Curve

# %%
# Plotting Training vs Validation Accuracy
plt.plot(history.history['crf_viterbi_accuracy'])  
plt.plot(history.history['val_crf_viterbi_accuracy'])  
plt.title('Train vs Validation Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation']) 
plt.show()

# %% [markdown]
# ## Loss Curve

# %%
# Plotting Training vs Validation Accuracy
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('Train vs Validation Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation']) 
plt.show()

# %% [markdown]
# ## Testing

# %%
good_example = []
bad_example = []

for i in range(5):
  for j in range(5):
    if test_words[i][j] != 0:
      word = id_to_word[test_words[i][j]]
      a_tag = actual_tag[i][j]
      p_tag = predicted_tag[i][j]
      if a_tag == p_tag:
        good_example.append([word, p_tag, a_tag])
      else:
        bad_example.append([word, p_tag, a_tag])

col1_width = max([len(x[0]) for x in good_example])
col2_width = max([len(x[1]) for x in good_example])
col3_width = max([len(x[2]) for x in good_example])

print("-------- Good Examples --------")
print ("|{0:<{col1}}  |{1:<{col2}}  |{2:<{col3}}  |".format("Word","Actual","Predicted",col1=col1_width,col2=col2_width,col3=col3_width))

for word, p_tag, a_tag in good_example:
  print ("|{0:<{col1}}  |{1:<{col2}}   |{2:<{col3}}      |".format(word,a_tag,p_tag,col1=col1_width,col2=col2_width,col3=col3_width))

col1_width = max([len(x[0]) for x in bad_example])
col2_width = max([len(x[1]) for x in bad_example])
col3_width = max([len(x[2]) for x in bad_example])  

print("\n\n-------- Bad Examples --------")
print ("|{0:<{col1}}  |{1:<{col2}}  |{2:<{col3}}  |".format("Word","Actual","Predicted",col1=col1_width,col2=col2_width,col3=col3_width))

for word, p_tag, a_tag in bad_example:
   print ("|{0:<{col1}}  |{1:<{col2}}   |{2:<{col3}}      |".format(word,a_tag,p_tag,col1=col1_width,col2=col2_width,col3=col3_width))
# Out:
# -------- Good Examples --------
# |Word     |Actual  |Predicted  |
# |soccer   |O       |O          |
# |-        |O       |O          |
# |japan    |B-LOC   |B-LOC      |
# |get      |O       |O          |
# |lucky    |O       |O          |
# |nadim    |B-PER   |B-PER      |
# |ladki    |I-PER   |I-PER      |
# |,        |O       |O          |
# |began    |O       |O          |
# |the      |O       |O          |
# |defence  |O       |O          |
# |of       |O       |O          |
# |but      |O       |O          |
# |china    |B-LOC   |B-LOC      |
# |saw      |O       |O          |
# |their    |O       |O          |
# |luck     |O       |O          |
#
#
# -------- Bad Examples --------
# |Word      |Actual  |Predicted  |
# |al-ain    |B-LOC   |B-ORG      |
# |united    |B-LOC   |B-ORG      |
# |arab      |I-LOC   |I-ORG      |
# |emirates  |I-LOC   |I-ORG      |
# |japan     |B-LOC   |B-ORG      |
