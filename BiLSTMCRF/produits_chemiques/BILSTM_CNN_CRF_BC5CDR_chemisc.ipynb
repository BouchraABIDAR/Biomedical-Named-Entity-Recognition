# %% [markdown]
# # BiLSTM CNN CRF pour la reconnaissance des produits chimiques
# Nous utiliserons le codage par réseau neuronal à convolution pour la représentation des mots au niveau des caractères, le LSTM bidirectionnel pour le codage au niveau des mots et les champs aléatoires conditionnels (couche CRF) pour les décodages de sortie.
#
# Réference [model](https://github.com/ZhixiuYe/NER-pytorch)

# %%
import tensorflow as tf
import keras
from keras.layers import TimeDistributed, Conv1D, Dense, Embedding, Input, Dropout, LSTM, Bidirectional, MaxPooling1D,Flatten, concatenate
from keras_contrib.losses import crf_loss
from keras_contrib.metrics import crf_viterbi_accuracy
from keras_contrib.layers.crf import CRF
from keras.utils import plot_model
from keras.initializers import RandomUniform
from keras.optimizers import SGD, Nadam
import numpy as np
import os
import sys
import codecs
import re
import pickle
from sklearn_crfsuite.metrics import flat_classification_report
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Preprocessing
#
# Data prepocessing comprend le chargement des données, la mise à jour du schéma de balisage, la création d'un mappong pour les mots, les caractères et les tags et enfin la préparation des données qui sont transmises dans le modèle.

# %% [markdown]
# ### Custom Data Loading
# Cette étape comprend le chargement du train et la validation des données dans la liste des phrases.
#
# Le code suivant charge les données de formation et de validation.

# %%
import csv
def corpus_preprocessing(path):
    pairwise = dict()
  
    paths = [path]
    sentences = []
    sentence = []
    p_token = ''

    all_length = []
    length = 0
    longer_entity = 0
    max_length = 0
    entity_count = 0
    labels_list = []
    tokens_list =[]
    tag_list =[]
    for path in paths:
        with open(path) as fin:
            reader = csv.reader(fin, delimiter='\t', quoting=csv.QUOTE_NONE)
            entity_length_turn_on = False
            for i, row in enumerate(reader):
                if i == 0:
                    pass
                if len(row) < 2:
                    sentences.append(sentence)
                    sentence = []
                else:
                    token = row[0]
                    label = row[1]
                    #tag = row[1]

                    labels_list.append(label)
                    #tag_list.append(tag)
                    tokens_list.append(token)
    #return list(zip(tokens_list,labels_list))
    return [list([ele]) for ele in list(zip(tokens_list,labels_list))]

# %%
train_sentences = corpus_preprocessing("BC5CDR-chem-IOBES/train.tsv")
dev_sentences = corpus_preprocessing("BC5CDR-chem-IOBES/devel.tsv")
test_sentences = corpus_preprocessing("BC5CDR-chem-IOBES/test.tsv")
len(train_sentences), len(dev_sentences), len(test_sentences)
# Out:
# (118170, 117453, 124750)

# %%
train_sentences[1][0][1]
st =[]
for i in range(len(train_sentences)):
    if train_sentences[i][0][1] !='O':
        st.append(train_sentences[i])
train_sentences = st

# %% [markdown]
# ### Add Character Information

# %%
def add_char_info(sentences):
    for i, sentence in enumerate(sentences):
        for j, data in enumerate(sentence):
            chars = [c for c in data[0]]
            sentences[i][j] = [data[0], chars, data[1]]
    return sentences

# %%
#add_char_info(train_sentences)
#train_sentences

# %%
train_sentences = add_char_info(train_sentences)
dev_sentences = add_char_info(dev_sentences)
test_sentences = add_char_info(test_sentences)

# %% [markdown]
# ### Tag Mappings

# %%
labels_set = set()
words = {}

# unique words and labels in data  
for dataset in [train_sentences, dev_sentences, test_sentences]:
    for sentence in dataset:
        for token, char, label in sentence:
        # token ... token, char ... list of chars, label ... BIO labels   
            labels_set.add(label)
            words[token.lower()] = True

# %%
labels_set
# Out:
# {'B-Chemical', 'E-Chemical', 'I-Chemical', 'O', 'S-Chemical'}

# %%
# mapping for labels
indexes = {"PADDING":0}
for label in labels_set:
    indexes[label] = len(indexes)

tag_to_id = {}
for word,index in indexes.items():
    tag_to_id[word] = index

tag_to_id
# Out:
# {'PADDING': 0,
#  'E-Chemical': 1,
#  'B-Chemical': 2,
#  'O': 3,
#  'I-Chemical': 4,
#  'S-Chemical': 5}

# %%
id_to_tag = {v: k for k, v in tag_to_id.items()}
len(id_to_tag)
# Out:
# 6

# %% [markdown]
# ### Word and Character Embeddings

# %%
# Download Glove Word Embeddings
#!wget http://nlp.stanford.edu/data/glove.6B.zip && unzip glove.6B.zip -d /content/

# %%
word_to_id = {}
word_embeddings = []

EMBEDDINGS_FILE = open("/home/user/PPD_project/BILSTM-CRF/Maladies/glove.6B.50d.txt", encoding="utf-8")


# loop through each word in embeddings
for line in EMBEDDINGS_FILE:
    split = line.strip().split(" ")
    word = split[0]  # embedding word entry

    if len(word_to_id) == 0:  # add padding+unknown
        word_to_id["PADDING_TOKEN"] = len(word_to_id)
        vector = np.zeros(len(split) - 1)  # zero vector for 'PADDING' word
        word_embeddings.append(vector)

        word_to_id["UNKNOWN_TOKEN"] = len(word_to_id)
        vector = np.random.uniform(-0.25, 0.25, len(split) - 1)
        word_embeddings.append(vector)

    if split[0].lower() in words:
        vector = np.array([float(num) for num in split[1:]])
        word_embeddings.append(vector)  # word embedding vector
        word_to_id[split[0]] = len(word_to_id)  # corresponding word dict

word_embeddings = np.array(word_embeddings)
word_embeddings.shape, len(word_to_id)
# Out:
# ((10141, 50), 10141)

# %%
id_to_word = {v: k for k, v in word_to_id.items()}
len(id_to_word)
# Out:
# 10141

# %%
# Dictionnaire de tous les caractères possibles
char_to_id = {"PADDING": 0, "UNKNOWN": 1}
for c in " 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ.,-_()[]{}!?:;#'\"/\\%$`&=*+@^~|<>":
    char_to_id[c] = len(char_to_id)

len(char_to_id)
# Out:
# 97

# %% [markdown]
# ### Prepare Dataset

# %%
def create_dataset(sentences, word_to_id, tag_to_id, char_to_id):
    unk_index = word_to_id['UNKNOWN_TOKEN']
    pad_index = word_to_id['PADDING_TOKEN']

    dataset = []

    word_count = 0
    unk_word_count = 0

    for sentence in sentences:
        word_indices = []
        char_indices = []
        tag_indices = []

        for word, char, tag in sentence:
            word_count += 1
            if word in word_to_id:
                word_index = word_to_id[word]
            elif word.lower() in word_to_id:
                word_index = word_to_id[word.lower()]
            else:
                word_index = unk_index
                unk_word_count += 1
            char_index = []
            for x in char:
                char_index.append(char_to_id[x])
            # Get the label and map to int
            word_indices.append(word_index)
            char_indices.append(char_index)
            tag_indices.append(tag_to_id[tag])

        dataset.append([word_indices, char_indices, tag_indices])

    return dataset

# %%
def padding(sentences):
    maxlen = 52
    for sentence in sentences:
        char = sentence[1]
        for x in char:
            maxlen = max(maxlen, len(x))
    for i, sentence in enumerate(sentences):
        sentences[i][1] = keras.preprocessing.sequence.pad_sequences(sentences[i][1], 52, padding='post')
    return sentences

# %%
train_set = padding(create_dataset(train_sentences, word_to_id, indexes, char_to_id))
dev_set = padding(create_dataset(dev_sentences, word_to_id, indexes, char_to_id))
test_set = padding(create_dataset(test_sentences, word_to_id, indexes, char_to_id))

# %%
def unpack(dataset):
    words=[]
    chars=[]
    tags = []
    for word, char, tag in dataset:
        words.append(word)
        chars.append(char)
        tags.append(tag)
  
    words = keras.preprocessing.sequence.pad_sequences(words, 52, padding='post')
    chars = keras.preprocessing.sequence.pad_sequences(chars, 52, padding='post')
    tags = keras.preprocessing.sequence.pad_sequences(tags, 52, padding='post')
    tags = keras.utils.to_categorical(tags, num_classes=7)
    return words, chars, tags

# %%
train_words, train_chars, train_tags = unpack(train_set)
valid_words, valid_chars, valid_tags = unpack(dev_set)
test_words, test_chars, test_tags = unpack(test_set)

# %%
train_words.shape, train_chars.shape, train_tags.shape
# Out:
# ((7103, 52), (7103, 52, 52), (7103, 52, 7))

# %% [markdown]
# ## Define Model
# Le modèle qui est mis en œuvre dans ce projet utilise les architectures suivantes:
# - Convolution Neural Network pour le niveau de caractère Représentation des mots
# - Bidirectional LSTM pour le Word Encoding
# - Conditional Random Fields (CRF Layer) pour output decodings.

# %%
from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Define Model Layers
char_input = Input(shape=(None, 52,), name="char_input")
char_embed = TimeDistributed(Embedding(len(char_to_id), 30, embeddings_initializer=RandomUniform(minval=-0.5, maxval=0.5)), name="char_embed")(char_input)
char_dropout = Dropout(0.5)(char_embed)
char_cnn = TimeDistributed(Conv1D(kernel_size=3, filters=30, padding='same', activation='tanh', strides=1), name="conv1d")(char_dropout)
maxpool_out = TimeDistributed(MaxPooling1D(52), name="maxpool")(char_cnn)
char_flat = TimeDistributed(Flatten(), name="flatten")(maxpool_out)
char = Dropout(0.5)(char_flat)
words_input = Input(shape=(None,), dtype='int32', name='words_input')
words = Embedding(input_dim=word_embeddings.shape[0], output_dim=word_embeddings.shape[1], weights=[word_embeddings],trainable=False)(words_input)
concat = concatenate([words, char])
lstm = Bidirectional(LSTM(200, return_sequences=True, dropout=0.5,recurrent_dropout=0.25), name="bilstm")(concat)
out = TimeDistributed(Dense(len(tag_to_id), activation='softmax'),name="softmax_layer")(lstm)
crf_layer = CRF(7)
output = crf_layer(out)

# Define Model Inputs and Output
model = keras.models.Model([char_input,words_input],output)
# Compile Model
model.compile(optimizer='adam', loss=crf_loss, metrics=[crf_viterbi_accuracy])
# Model Summary
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# char_input (InputLayer)         (None, None, 52)     0
# __________________________________________________________________________________________________
# char_embed (TimeDistributed)    (None, None, 52, 30) 2910        char_input[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, None, 52, 30) 0           char_embed[0][0]
# __________________________________________________________________________________________________
# conv1d (TimeDistributed)        (None, None, 52, 30) 2730        dropout_3[0][0]
# __________________________________________________________________________________________________
# maxpool (TimeDistributed)       (None, None, 1, 30)  0           conv1d[0][0]
# __________________________________________________________________________________________________
# words_input (InputLayer)        (None, None)         0
# __________________________________________________________________________________________________
# flatten (TimeDistributed)       (None, None, 30)     0           maxpool[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, None, 50)     507050      words_input[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, None, 30)     0           flatten[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, 80)     0           embedding_4[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# bilstm (Bidirectional)          (None, None, 400)    449600      concatenate_2[0][0]
# __________________________________________________________________________________________________
# softmax_layer (TimeDistributed) (None, None, 6)      2406        bilstm[0][0]
# __________________________________________________________________________________________________
# crf_2 (CRF)                     (None, None, 7)      112         softmax_layer[0][0]
# ==================================================================================================
# Total params: 964,808
# Trainable params: 457,758
# Non-trainable params: 507,050
# __________________________________________________________________________________________________

# %%
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Training

# %%
history = model.fit([train_chars,train_words], train_tags,validation_data=[[valid_chars, valid_words], valid_tags],batch_size=64,epochs=40,verbose=1)
# Out:
# Train on 118170 samples, validate on 117453 samples
# Epoch 1/40
# 118170/118170 [==============================] - 525s 4ms/step - loss: 0.1340 - crf_viterbi_accuracy: 0.9931 - val_loss: 0.0351 - val_crf_viterbi_accuracy: 0.9988
# Epoch 2/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: 0.0268 - crf_viterbi_accuracy: 0.9988 - val_loss: 0.0203 - val_crf_viterbi_accuracy: 0.9988
# Epoch 3/40
# 118170/118170 [==============================] - 529s 4ms/step - loss: 0.0152 - crf_viterbi_accuracy: 0.9989 - val_loss: 0.0122 - val_crf_viterbi_accuracy: 0.9988
# Epoch 4/40
# 118170/118170 [==============================] - 528s 4ms/step - loss: -0.0016 - crf_viterbi_accuracy: 0.9991 - val_loss: -0.0122 - val_crf_viterbi_accuracy: 0.9993
# Epoch 5/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.0302 - crf_viterbi_accuracy: 0.9992 - val_loss: -0.0480 - val_crf_viterbi_accuracy: 0.9993
# Epoch 6/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.0662 - crf_viterbi_accuracy: 0.9992 - val_loss: -0.0850 - val_crf_viterbi_accuracy: 0.9994
# Epoch 7/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.1032 - crf_viterbi_accuracy: 0.9993 - val_loss: -0.1217 - val_crf_viterbi_accuracy: 0.9994
# Epoch 8/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.1396 - crf_viterbi_accuracy: 0.9993 - val_loss: -0.1579 - val_crf_viterbi_accuracy: 0.9994
# Epoch 9/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.1757 - crf_viterbi_accuracy: 0.9993 - val_loss: -0.1938 - val_crf_viterbi_accuracy: 0.9994
# Epoch 10/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.2116 - crf_viterbi_accuracy: 0.9993 - val_loss: -0.2295 - val_crf_viterbi_accuracy: 0.9994
# Epoch 11/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.2473 - crf_viterbi_accuracy: 0.9993 - val_loss: -0.2652 - val_crf_viterbi_accuracy: 0.9994
# Epoch 12/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.2829 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.3008 - val_crf_viterbi_accuracy: 0.9994
# Epoch 13/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.3185 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.3364 - val_crf_viterbi_accuracy: 0.9994
# Epoch 14/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.3541 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.3718 - val_crf_viterbi_accuracy: 0.9994
# Epoch 15/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.3896 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.4074 - val_crf_viterbi_accuracy: 0.9994
# Epoch 16/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.4251 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.4428 - val_crf_viterbi_accuracy: 0.9994
# Epoch 17/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.4606 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.4784 - val_crf_viterbi_accuracy: 0.9994
# Epoch 18/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.4962 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.5139 - val_crf_viterbi_accuracy: 0.9994
# Epoch 19/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.5317 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.5493 - val_crf_viterbi_accuracy: 0.9994
# Epoch 20/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.5672 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.5848 - val_crf_viterbi_accuracy: 0.9994
# Epoch 21/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.6027 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.6203 - val_crf_viterbi_accuracy: 0.9994
# Epoch 22/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.6382 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.6559 - val_crf_viterbi_accuracy: 0.9994
# Epoch 23/40
# 118170/118170 [==============================] - 522s 4ms/step - loss: -0.6737 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.6913 - val_crf_viterbi_accuracy: 0.9994
# Epoch 24/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.7092 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.7269 - val_crf_viterbi_accuracy: 0.9994
# Epoch 25/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.7447 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.7624 - val_crf_viterbi_accuracy: 0.9994
# Epoch 26/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.7802 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.7979 - val_crf_viterbi_accuracy: 0.9994
# Epoch 27/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.8158 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.8334 - val_crf_viterbi_accuracy: 0.9994
# Epoch 28/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.8513 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.8689 - val_crf_viterbi_accuracy: 0.9994
# Epoch 29/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.8868 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.9043 - val_crf_viterbi_accuracy: 0.9994
# Epoch 30/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.9223 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.9399 - val_crf_viterbi_accuracy: 0.9994
# Epoch 31/40
# 118170/118170 [==============================] - 520s 4ms/step - loss: -0.9578 - crf_viterbi_accuracy: 0.9994 - val_loss: -0.9754 - val_crf_viterbi_accuracy: 0.9994
# Epoch 32/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -0.9933 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.0108 - val_crf_viterbi_accuracy: 0.9994
# Epoch 33/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -1.0288 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.0464 - val_crf_viterbi_accuracy: 0.9994
# Epoch 34/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -1.0643 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.0819 - val_crf_viterbi_accuracy: 0.9994
# Epoch 35/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -1.0998 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.1174 - val_crf_viterbi_accuracy: 0.9994
# Epoch 36/40
# 118170/118170 [==============================] - 521s 4ms/step - loss: -1.1353 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.1529 - val_crf_viterbi_accuracy: 0.9994
# Epoch 37/40
# 118170/118170 [==============================] - 522s 4ms/step - loss: -1.1708 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.1884 - val_crf_viterbi_accuracy: 0.9994
# Epoch 38/40
# 118170/118170 [==============================] - 527s 4ms/step - loss: -1.2063 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.2238 - val_crf_viterbi_accuracy: 0.9994
# Epoch 39/40
# 118170/118170 [==============================] - 535s 5ms/step - loss: -1.2418 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.2594 - val_crf_viterbi_accuracy: 0.9994
# Epoch 40/40
# 118170/118170 [==============================] - 557s 5ms/step - loss: -1.2773 - crf_viterbi_accuracy: 0.9994 - val_loss: -1.2949 - val_crf_viterbi_accuracy: 0.9994

# %%
#history_2 = model.fit([train_chars,train_words], train_tags,validation_data=[[valid_chars, valid_words], valid_tags],batch_size=64,epochs=40,verbose=1)

# %% [markdown]
# ## Training and Testing Accuracy

# %%
_, train_acc = model.evaluate([train_chars, train_words],train_tags)
_, val_acc = model.evaluate([valid_chars, valid_words], valid_tags)
_, test_acc = model.evaluate([test_chars, test_words],test_tags)

print('Training Accuray: ', train_acc * 100)
print('Validation Accuray: ', val_acc * 100)
print('Testing Accuray: ', test_acc * 100)
# Out:
# 118170/118170 [==============================] - 138s 1ms/step
# 117453/117453 [==============================] - 144s 1ms/step
# 124750/124750 [==============================] - 151s 1ms/step
# Training Accuray:  99.95512962341309
# Validation Accuray:  99.94361400604248
# Testing Accuray:  99.9483048915863

# %%
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Evaluation Metrics Report
# Nous allons maintenant utiliser Precision, Recall et F1 score our évaluer la performance de notre modèle sur chaque tag.

# %%
# Evaluate
pred_cat = model.predict([test_chars,test_words])
predicted = [[[np.argmax(i)] for i in w] for w in pred_cat]
predicted = np.array(predicted)
actual = [[[np.argmax(i)] for i in w] for w in test_tags]
actual = np.array(actual)
# Convert the index to tag
predicted_tag = [[id_to_tag[i[0]] for i in row] for row in predicted]
actual_tag = [[id_to_tag[i[0]] for i in row] for row in actual]

# Metrics Report
report = flat_classification_report(y_pred=predicted_tag, y_true=actual_tag)
print(report)
# Out:
# /home/user/anaconda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#   B-Chemical       0.24      0.03      0.06       644
#   E-Chemical       0.44      0.38      0.41       644
#   I-Chemical       0.00      0.00      0.00       984
#            O       0.98      0.99      0.99    117737
#      PADDING       1.00      1.00      1.00   6362250
#   S-Chemical       0.80      0.87      0.83      4741
#
#     accuracy                           1.00   6487000
#    macro avg       0.58      0.55      0.55   6487000
# weighted avg       1.00      1.00      1.00   6487000

# %%
from sklearn_crfsuite.metrics import sequence_accuracy_score,flat_accuracy_score, flat_recall_score,flat_f1_score
flat_f1_score(predicted_tag, actual_tag, average='weighted')
# Out:
# 0.9995889970371192

# %% [markdown]
# ## Accuracy Curve

# %%
# Plotting Training vs Validation Accuracy
plt.plot(history.history['crf_viterbi_accuracy'])  
plt.plot(history.history['val_crf_viterbi_accuracy'])  
plt.title('Train vs Validation Accuracy')  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation']) 
plt.show()

# %% [markdown]
# ## Loss Curve

# %%
# Plotting Training vs Validation Accuracy
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('Train vs Validation Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['train', 'validation']) 
plt.show()

# %% [markdown]
# ## Testing

# %%
good_example = []
bad_example = []

for i in range(1000):
    for j in range(1):
        if test_words[i][j] != 0:
            word = id_to_word[test_words[i][j]]
            a_tag = actual_tag[i][j]
            p_tag = predicted_tag[i][j]
        if a_tag == p_tag:
            good_example.append([word, p_tag, a_tag])
        else:
            bad_example.append([word, p_tag, a_tag])

col1_width = max([len(x[0]) for x in good_example])
col2_width = max([len(x[1]) for x in good_example])
col3_width = max([len(x[2]) for x in good_example])

print("-------- Good Examples --------")
print ("|{0:<{col1}}  |{1:<{col2}}  |{2:<{col3}}  |".format("Word","Actual","Predicted",col1=col1_width,col2=col2_width,col3=col3_width))

for word, p_tag, a_tag in good_example:
    print ("|{0:<{col1}}  |{1:<{col2}}   |{2:<{col3}}      |".format(word,a_tag,p_tag,col1=col1_width,col2=col2_width,col3=col3_width))
# Out:
# -------- Good Examples --------
# |Word             |Actual      |Predicted   |
# |de               |O            |O               |
# |pointes          |O            |O               |
# |ventricular      |O            |O               |
# |tachycardia      |O            |O               |
# |during           |O            |O               |
# |low              |O            |O               |
# |dose             |O            |O               |
# |intermittent     |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |treatment        |O            |O               |
# |in               |O            |O               |
# |a                |O            |O               |
# |patient          |O            |O               |
# |with             |O            |O               |
# |dilated          |O            |O               |
# |cardiomyopathy   |O            |O               |
# |and              |O            |O               |
# |congestive       |O            |O               |
# |heart            |O            |O               |
# |failure          |O            |O               |
# |.                |O            |O               |
# |the              |O            |O               |
# |authors          |O            |O               |
# |describe         |O            |O               |
# |the              |O            |O               |
# |case             |O            |O               |
# |of               |O            |O               |
# |a                |O            |O               |
# |56               |O            |O               |
# |-                |O            |O               |
# |year             |O            |O               |
# |-                |O            |O               |
# |old              |O            |O               |
# |woman            |O            |O               |
# |with             |O            |O               |
# |chronic          |O            |O               |
# |,                |O            |O               |
# |severe           |O            |O               |
# |heart            |O            |O               |
# |failure          |O            |O               |
# |secondary        |O            |O               |
# |to               |O            |O               |
# |dilated          |O            |O               |
# |cardiomyopathy   |O            |O               |
# |and              |O            |O               |
# |absence          |O            |O               |
# |of               |O            |O               |
# |significant      |O            |O               |
# |ventricular      |O            |O               |
# |arrhythmias      |O            |O               |
# |who              |O            |O               |
# |developed        |O            |O               |
# |qt               |O            |O               |
# |prolongation     |O            |O               |
# |and              |O            |O               |
# |de               |O            |O               |
# |pointes          |O            |O               |
# |ventricular      |O            |O               |
# |tachycardia      |O            |O               |
# |during           |O            |O               |
# |one              |O            |O               |
# |cycle            |O            |O               |
# |of               |O            |O               |
# |intermittent     |O            |O               |
# |low              |O            |O               |
# |dose             |O            |O               |
# |(                |O            |O               |
# |2                |O            |O               |
# |.                |O            |O               |
# |5                |O            |O               |
# |mcg              |O            |O               |
# |/                |O            |O               |
# |kg               |O            |O               |
# |per              |O            |O               |
# |min              |O            |O               |
# |)                |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |.                |O            |O               |
# |this             |O            |O               |
# |report           |O            |O               |
# |of               |O            |O               |
# |de               |O            |O               |
# |pointes          |O            |O               |
# |ventricular      |O            |O               |
# |tachycardia      |O            |O               |
# |during           |O            |O               |
# |intermittent     |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |supports         |O            |O               |
# |the              |O            |O               |
# |hypothesis       |O            |O               |
# |that             |O            |O               |
# |unpredictable    |O            |O               |
# |fatal            |O            |O               |
# |arrhythmias      |O            |O               |
# |may              |O            |O               |
# |occur            |O            |O               |
# |even             |O            |O               |
# |with             |O            |O               |
# |low              |O            |O               |
# |doses            |O            |O               |
# |and              |O            |O               |
# |in               |O            |O               |
# |patients         |O            |O               |
# |with             |O            |O               |
# |no               |O            |O               |
# |history          |O            |O               |
# |of               |O            |O               |
# |significant      |O            |O               |
# |rhythm           |O            |O               |
# |disturbances     |O            |O               |
# |.                |O            |O               |
# |the              |O            |O               |
# |mechanisms       |O            |O               |
# |of               |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |effects          |O            |O               |
# |of               |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |are              |O            |O               |
# |discussed        |O            |O               |
# |.                |O            |O               |
# |positive         |O            |O               |
# |skin             |O            |O               |
# |tests            |O            |O               |
# |in               |O            |O               |
# |late             |O            |O               |
# |reactions        |O            |O               |
# |to               |O            |O               |
# |radiographic     |O            |O               |
# |.                |O            |O               |
# |in               |O            |O               |
# |the              |O            |O               |
# |last             |O            |O               |
# |few              |O            |O               |
# |years            |O            |O               |
# |delayed          |O            |O               |
# |reactions        |O            |O               |
# |several          |O            |O               |
# |hours            |O            |O               |
# |after            |O            |O               |
# |the              |O            |O               |
# |injection        |O            |O               |
# |of               |O            |O               |
# |radiographic     |O            |O               |
# |and              |O            |O               |
# |(                |O            |O               |
# |)                |O            |O               |
# |have             |O            |O               |
# |been             |O            |O               |
# |described        |O            |O               |
# |with             |O            |O               |
# |increasing       |O            |O               |
# |frequency        |O            |O               |
# |.                |O            |O               |
# |the              |O            |O               |
# |authors          |O            |O               |
# |report           |O            |O               |
# |two              |O            |O               |
# |observations     |O            |O               |
# |on               |O            |O               |
# |patients         |O            |O               |
# |with             |O            |O               |
# |delayed          |O            |O               |
# |reactions        |O            |O               |
# |in               |O            |O               |
# |whom             |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |(                |O            |O               |
# |idr              |O            |O               |
# |)                |O            |O               |
# |and              |O            |O               |
# |patch            |O            |O               |
# |tests            |O            |O               |
# |to               |O            |O               |
# |a                |O            |O               |
# |series           |O            |O               |
# |of               |O            |O               |
# |ionic            |O            |O               |
# |and              |O            |O               |
# |non              |O            |O               |
# |ionic            |O            |O               |
# |were             |O            |O               |
# |studied          |O            |O               |
# |.                |O            |O               |
# |after            |O            |O               |
# |angiography      |O            |O               |
# |by               |O            |O               |
# |the              |O            |O               |
# |venous           |O            |O               |
# |route            |O            |O               |
# |in               |O            |O               |
# |patient          |O            |O               |
# |n                |O            |O               |
# |degree           |O            |O               |
# |1                |O            |O               |
# |a                |O            |O               |
# |biphasic         |O            |O               |
# |reaction         |O            |O               |
# |with             |O            |O               |
# |an               |O            |O               |
# |immediate        |O            |O               |
# |reaction         |O            |O               |
# |(                |O            |O               |
# |dyspnea          |O            |O               |
# |,                |O            |O               |
# |loss             |O            |O               |
# |of               |O            |O               |
# |consciousness    |O            |O               |
# |)                |O            |O               |
# |and              |O            |O               |
# |delayed          |O            |O               |
# |macro            |O            |O               |
# |-                |O            |O               |
# |papular          |O            |O               |
# |rash             |O            |O               |
# |appeared         |O            |O               |
# |,                |O            |O               |
# |whilst           |O            |O               |
# |patient          |O            |O               |
# |n                |O            |O               |
# |degree           |O            |O               |
# |2                |O            |O               |
# |developed        |O            |O               |
# |a                |O            |O               |
# |generalised      |O            |O               |
# |sensation        |O            |O               |
# |of               |O            |O               |
# |heat             |O            |O               |
# |,                |O            |O               |
# |persistent       |O            |O               |
# |pain             |O            |O               |
# |at               |O            |O               |
# |the              |O            |O               |
# |site             |O            |O               |
# |of               |O            |O               |
# |injection        |O            |O               |
# |immediately      |O            |O               |
# |and              |O            |O               |
# |a                |O            |O               |
# |generalised      |O            |O               |
# |macro            |O            |O               |
# |-                |O            |O               |
# |papular          |O            |O               |
# |reaction         |O            |O               |
# |after            |O            |O               |
# |24               |O            |O               |
# |hours            |O            |O               |
# |.                |O            |O               |
# |the              |O            |O               |
# |skin             |O            |O               |
# |tests            |O            |O               |
# |revealed         |O            |O               |
# |positive         |O            |O               |
# |delayed          |O            |O               |
# |reactions        |O            |O               |
# |of               |O            |O               |
# |24               |O            |O               |
# |hours            |O            |O               |
# |and              |O            |O               |
# |48               |O            |O               |
# |hours            |O            |O               |
# |by               |O            |O               |
# |idr              |O            |O               |
# |and              |O            |O               |
# |patch            |O            |O               |
# |tests            |O            |O               |
# |to               |O            |O               |
# |only             |O            |O               |
# |some             |O            |O               |
# |with             |O            |O               |
# |common           |O            |O               |
# |chains           |O            |O               |
# |in               |O            |O               |
# |their            |O            |O               |
# |structures       |O            |O               |
# |.                |O            |O               |
# |the              |O            |O               |
# |positive         |O            |O               |
# |skin             |O            |O               |
# |tests            |O            |O               |
# |are              |O            |O               |
# |in               |O            |O               |
# |favour           |O            |O               |
# |of               |O            |O               |
# |immunological    |O            |O               |
# |reactions        |O            |O               |
# |and              |O            |O               |
# |may              |O            |O               |
# |help             |O            |O               |
# |in               |O            |O               |
# |diagnosis        |O            |O               |
# |of               |O            |O               |
# |allergy          |O            |O               |
# |in               |O            |O               |
# |the              |O            |O               |
# |patients         |O            |O               |
# |.                |O            |O               |
# |risk             |O            |O               |
# |of               |O            |O               |
# |transient        |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |encephalopathy   |O            |O               |
# |in               |O            |O               |
# |cancer           |O            |O               |
# |patients         |O            |O               |
# |who              |O            |O               |
# |received         |O            |O               |
# |continuous       |O            |O               |
# |infusion         |O            |O               |
# |of               |O            |O               |
# |fluorouracil     |E-Chemical   |E-Chemical      |
# |with             |O            |O               |
# |the              |O            |O               |
# |complication     |O            |O               |
# |of               |O            |O               |
# |dehydration      |O            |O               |
# |and              |O            |O               |
# |infection        |O            |O               |
# |.                |O            |O               |
# |from             |O            |O               |
# |1986             |O            |O               |
# |to               |O            |O               |
# |1998             |O            |O               |
# |,                |O            |O               |
# |29               |O            |O               |
# |cancer           |O            |O               |
# |patients         |O            |O               |
# |who              |O            |O               |
# |had              |O            |O               |
# |32               |O            |O               |
# |episodes         |O            |O               |
# |of               |O            |O               |
# |transient        |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |encephalopathy   |O            |O               |
# |related          |O            |O               |
# |to               |O            |O               |
# |continuous       |O            |O               |
# |infusion         |O            |O               |
# |of               |O            |O               |
# |fluorouracil     |E-Chemical   |E-Chemical      |
# |(                |O            |O               |
# |fu               |E-Chemical   |E-Chemical      |
# |)                |O            |O               |
# |were             |O            |O               |
# |identified       |O            |O               |
# |.                |O            |O               |
# |none             |O            |O               |
# |of               |O            |O               |
# |the              |O            |O               |
# |patients         |O            |O               |
# |had              |O            |O               |
# |decompensated    |O            |O               |
# |liver            |O            |O               |
# |disease          |O            |O               |
# |.                |O            |O               |
# |onset            |O            |O               |
# |of               |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |encephalopathy   |O            |O               |
# |varied           |O            |O               |
# |from             |O            |O               |
# |0                |O            |O               |
# |.                |O            |O               |
# |5                |O            |O               |
# |to               |O            |O               |
# |5                |O            |O               |
# |days             |O            |O               |
# |(                |O            |O               |
# |mean             |O            |O               |
# |:                |O            |O               |
# |2                |O            |O               |
# |.                |O            |O               |
# |6                |O            |O               |
# |+                |O            |O               |
# |/                |O            |O               |
# |-                |O            |O               |
# |1                |O            |O               |
# |.                |O            |O               |
# |3                |O            |O               |
# |days             |O            |O               |
# |)                |O            |O               |
# |after            |O            |O               |
# |the              |O            |O               |
# |initiation       |O            |O               |
# |of               |O            |O               |
# |chemotherapy     |O            |O               |
# |.                |O            |O               |
# |plasma           |O            |O               |
# |level            |O            |O               |
# |ranged           |O            |O               |
# |from             |O            |O               |
# |248              |O            |O               |
# |to               |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |%                |O            |O               |
# |(                |O            |O               |
# |mean             |O            |O               |
# |:                |O            |O               |
# |626              |O            |O               |
# |+                |O            |O               |
# |/                |O            |O               |
# |-                |O            |O               |
# |431              |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |%                |O            |O               |
# |)                |O            |O               |
# |.                |O            |O               |
# |among            |O            |O               |
# |the              |O            |O               |
# |32               |O            |O               |
# |episodes         |O            |O               |
# |,                |O            |O               |
# |26               |O            |O               |
# |(                |O            |O               |
# |81               |O            |O               |
# |%                |O            |O               |
# |)                |O            |O               |
# |had              |O            |O               |
# |various          |O            |O               |
# |degrees          |O            |O               |
# |of               |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |,                |O            |O               |
# |18               |O            |O               |
# |(                |O            |O               |
# |56               |O            |O               |
# |%                |O            |O               |
# |)                |O            |O               |
# |occurred         |O            |O               |
# |during           |O            |O               |
# |bacterial        |O            |O               |
# |infections       |O            |O               |
# |and              |O            |O               |
# |14               |O            |O               |
# |(                |O            |O               |
# |44               |O            |O               |
# |%                |O            |O               |
# |)                |O            |O               |
# |without          |O            |O               |
# |infection        |O            |O               |
# |occurred         |O            |O               |
# |during           |O            |O               |
# |periods          |O            |O               |
# |of               |O            |O               |
# |dehydration      |O            |O               |
# |.                |O            |O               |
# |higher           |O            |O               |
# |plasma           |O            |O               |
# |levels           |O            |O               |
# |and              |O            |O               |
# |more             |O            |O               |
# |rapid            |O            |O               |
# |onset            |O            |O               |
# |of               |O            |O               |
# |hyperammonemia   |O            |O               |
# |were             |O            |O               |
# |seen             |O            |O               |
# |in               |O            |O               |
# |18               |O            |O               |
# |patients         |O            |O               |
# |with             |O            |O               |
# |bacterial        |O            |O               |
# |infections       |O            |O               |
# |(                |O            |O               |
# |p                |O            |O               |
# |=                |O            |O               |
# |0                |O            |O               |
# |.                |O            |O               |
# |003              |O            |O               |
# |and              |O            |O               |
# |0                |O            |O               |
# |.                |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |,                |O            |O               |
# |respectively     |O            |O               |
# |)                |O            |O               |
# |and              |O            |O               |
# |in               |O            |O               |
# |nine             |O            |O               |
# |patients         |O            |O               |
# |receiving        |O            |O               |
# |high             |O            |O               |
# |daily            |O            |O               |
# |doses            |O            |O               |
# |(                |O            |O               |
# |2600             |O            |O               |
# |or               |O            |O               |
# |1800             |O            |O               |
# |mg               |O            |O               |
# |/                |O            |O               |
# |m2               |O            |O               |
# |)                |O            |O               |
# |of               |O            |O               |
# |fu               |E-Chemical   |E-Chemical      |
# |(                |O            |O               |
# |p                |O            |O               |
# |=                |O            |O               |
# |0                |O            |O               |
# |.                |O            |O               |
# |0001             |O            |O               |
# |and              |O            |O               |
# |<                |O            |O               |
# |0                |O            |O               |
# |.                |O            |O               |
# |0001             |O            |O               |
# |,                |O            |O               |
# |respectively     |O            |O               |
# |)                |O            |O               |
# |.                |O            |O               |
# |in               |O            |O               |
# |25               |O            |O               |
# |out              |O            |O               |
# |of               |O            |O               |
# |32               |O            |O               |
# |episodes         |O            |O               |
# |(                |O            |O               |
# |78               |O            |O               |
# |%                |O            |O               |
# |)                |O            |O               |
# |,                |O            |O               |
# |plasma           |O            |O               |
# |levels           |O            |O               |
# |and              |O            |O               |
# |mental           |O            |O               |
# |status           |O            |O               |
# |returned         |O            |O               |
# |to               |O            |O               |
# |normal           |O            |O               |
# |within           |O            |O               |
# |2                |O            |O               |
# |days             |O            |O               |
# |after            |O            |O               |
# |adequate         |O            |O               |
# |management       |O            |O               |
# |.                |O            |O               |
# |in               |O            |O               |
# |conclusion       |O            |O               |
# |,                |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |encephalopathy   |O            |O               |
# |can              |O            |O               |
# |occur            |O            |O               |
# |in               |O            |O               |
# |patients         |O            |O               |
# |receiving        |O            |O               |
# |continuous       |O            |O               |
# |infusion         |O            |O               |
# |of               |O            |O               |
# |fu               |E-Chemical   |E-Chemical      |
# |.                |O            |O               |
# |,                |O            |O               |
# |body             |O            |O               |
# |fluid            |O            |O               |
# |insufficiency    |O            |O               |
# |and              |O            |O               |
# |bacterial        |O            |O               |
# |infections       |O            |O               |
# |were             |O            |O               |
# |frequently       |O            |O               |
# |found            |O            |O               |
# |in               |O            |O               |
# |these            |O            |O               |
# |patients         |O            |O               |
# |.                |O            |O               |
# |it               |O            |O               |
# |is               |O            |O               |
# |therefore        |O            |O               |
# |important        |O            |O               |
# |to               |O            |O               |
# |recognize        |O            |O               |
# |this             |O            |O               |
# |condition        |O            |O               |
# |in               |O            |O               |
# |patients         |O            |O               |
# |receiving        |O            |O               |
# |continuous       |O            |O               |
# |infusion         |O            |O               |
# |of               |O            |O               |
# |fu               |E-Chemical   |E-Chemical      |
# |.                |O            |O               |
# |the              |O            |O               |
# |effects          |O            |O               |
# |of               |O            |O               |
# |quinine          |S-Chemical   |S-Chemical      |
# |and              |O            |O               |
# |on               |O            |O               |
# |conditioned      |O            |O               |
# |place            |O            |O               |
# |preference       |O            |O               |
# |and              |O            |O               |
# |changes          |O            |O               |
# |in               |O            |O               |
# |motor            |O            |O               |
# |activity         |O            |O               |
# |induced          |O            |O               |
# |by               |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |in               |O            |O               |
# |rats             |O            |O               |
# |.                |O            |O               |
# |1                |O            |O               |
# |.                |O            |O               |
# |the              |O            |O               |
# |effects          |O            |O               |
# |of               |O            |O               |
# |two              |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |potassium        |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |)                |O            |O               |
# |channel          |O            |O               |
# |blockers         |O            |O               |
# |,                |O            |O               |
# |quinine          |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |12               |O            |O               |
# |.                |O            |O               |
# |5                |O            |O               |
# |,                |O            |O               |
# |25               |O            |O               |
# |and              |O            |O               |
# |50               |O            |O               |
# |mg               |O            |O               |
# |/                |O            |O               |
# |kg               |O            |O               |
# |)                |O            |O               |
# |and              |O            |O               |
# |(                |O            |O               |
# |1                |O            |O               |
# |and              |O            |O               |
# |2                |O            |O               |
# |mg               |O            |O               |
# |/                |O            |O               |
# |kg               |O            |O               |
# |)                |O            |O               |
# |,                |O            |O               |
# |on               |O            |O               |
# |conditioned      |O            |O               |
# |place            |O            |O               |
# |preference       |O            |O               |
# |and              |O            |O               |
# |biphasic         |O            |O               |
# |changes          |O            |O               |
# |in               |O            |O               |
# |motor            |O            |O               |
# |activity         |O            |O               |
# |induced          |O            |O               |
# |by               |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |10               |O            |O               |
# |mg               |O            |O               |
# |/                |O            |O               |
# |kg               |O            |O               |
# |)                |O            |O               |
# |were             |O            |O               |
# |tested           |O            |O               |
# |in               |O            |O               |
# |wistar           |O            |O               |
# |rats             |O            |O               |
# |.                |O            |O               |
# |quinine          |S-Chemical   |S-Chemical      |
# |is               |O            |O               |
# |known            |O            |O               |
# |to               |O            |O               |
# |block            |O            |O               |
# |voltage          |O            |O               |
# |-                |O            |O               |
# |,                |O            |O               |
# |calcium          |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |and              |O            |O               |
# |atp              |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |sensitive        |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channels         |O            |O               |
# |while            |O            |O               |
# |is               |O            |O               |
# |known            |O            |O               |
# |to               |O            |O               |
# |block            |O            |O               |
# |voltage          |O            |O               |
# |-                |O            |O               |
# |sensitive        |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channels         |O            |O               |
# |.                |O            |O               |
# |2                |O            |O               |
# |.                |O            |O               |
# |in               |O            |O               |
# |the              |O            |O               |
# |counterbalanced  |O            |O               |
# |method           |O            |O               |
# |,                |O            |O               |
# |quinine          |S-Chemical   |S-Chemical      |
# |attenuated       |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |induced          |O            |O               |
# |place            |O            |O               |
# |preference       |O            |O               |
# |,                |O            |O               |
# |whereas          |O            |O               |
# |was              |O            |O               |
# |ineffective      |O            |O               |
# |.                |O            |O               |
# |in               |O            |O               |
# |the              |O            |O               |
# |motor            |O            |O               |
# |activity         |O            |O               |
# |test             |O            |O               |
# |measured         |O            |O               |
# |with             |O            |O               |
# |an               |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |-                |O            |O               |
# |activity         |O            |O               |
# |meter            |O            |O               |
# |neither          |O            |O               |
# |of               |O            |O               |
# |the              |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channel          |O            |O               |
# |blockers         |O            |O               |
# |affected         |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |induced          |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |,                |O            |O               |
# |but              |O            |O               |
# |both             |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channel          |O            |O               |
# |blockers         |O            |O               |
# |prevented        |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |induced          |O            |O               |
# |secondary        |O            |O               |
# |hyperactivity    |O            |O               |
# |.                |O            |O               |
# |3                |O            |O               |
# |.                |O            |O               |
# |these            |O            |O               |
# |results          |O            |O               |
# |suggest          |O            |O               |
# |the              |O            |O               |
# |involvement      |O            |O               |
# |of               |O            |O               |
# |quinine          |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |sensitive        |O            |O               |
# |but              |O            |O               |
# |not              |O            |O               |
# |-                |O            |O               |
# |sensitive        |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channels         |O            |O               |
# |in               |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |reward           |O            |O               |
# |.                |O            |O               |
# |it               |O            |O               |
# |is               |O            |O               |
# |also             |O            |O               |
# |suggested        |O            |O               |
# |that             |O            |O               |
# |the              |O            |O               |
# |blockade         |O            |O               |
# |of               |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channels         |O            |O               |
# |sensitive        |O            |O               |
# |to               |O            |O               |
# |these            |O            |O               |
# |blockers         |O            |O               |
# |is               |O            |O               |
# |not              |O            |O               |
# |sufficient       |O            |O               |
# |to               |O            |O               |
# |prevent          |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |induced          |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |whereas          |O            |O               |
# |morphine         |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |induced          |O            |O               |
# |hyperactivity    |O            |O               |
# |seems            |O            |O               |
# |to               |O            |O               |
# |be               |O            |O               |
# |connected        |O            |O               |
# |to               |O            |O               |
# |both             |O            |O               |
# |quinine          |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |and              |O            |O               |
# |-                |O            |O               |
# |sensitive        |O            |O               |
# |k                |S-Chemical   |S-Chemical      |
# |(                |O            |O               |
# |+                |O            |O               |
# |)                |O            |O               |
# |-                |O            |O               |
# |channels         |O            |O               |
# |.                |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |/                |O            |O               |
# |and              |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |on               |O            |O               |
# |learning         |O            |O               |
# |and              |O            |O               |
# |memory           |O            |O               |
# |impairment       |O            |O               |
# |induced          |O            |O               |
# |by               |O            |O               |
# |scopolamine      |S-Chemical   |S-Chemical      |
# |in               |O            |O               |
# |mice             |O            |O               |
# |.                |O            |O               |
# |1                |O            |O               |
# |.                |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |,                |O            |O               |
# |also             |O            |O               |
# |known            |O            |O               |
# |as               |O            |O               |
# |,                |O            |O               |
# |is               |O            |O               |
# |an               |O            |O               |
# |endogenous       |O            |O               |
# |ligand           |O            |O               |
# |for              |O            |O               |
# |the              |O            |O               |
# |orphan           |O            |O               |
# |opioid           |O            |O               |
# |receptor         |O            |O               |
# |-                |O            |O               |
# |like             |O            |O               |
# |receptor         |O            |O               |
# |1                |O            |O               |
# |(                |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |)                |O            |O               |
# |and              |O            |O               |
# |involves         |O            |O               |
# |in               |O            |O               |
# |various          |O            |O               |
# |functions        |O            |O               |
# |in               |O            |O               |
# |the              |O            |O               |
# |central          |O            |O               |
# |nervous          |O            |O               |
# |system           |O            |O               |
# |(                |O            |O               |
# |cns              |O            |O               |
# |)                |O            |O               |
# |.                |O            |O               |
# |on               |O            |O               |
# |the              |O            |O               |
# |other            |O            |O               |
# |hand             |O            |O               |
# |,                |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |is               |O            |O               |
# |recently         |O            |O               |
# |isolated         |O            |O               |
# |from             |O            |O               |
# |the              |O            |O               |
# |same             |O            |O               |
# |precursor        |O            |O               |
# |as               |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |and              |O            |O               |
# |blocks           |O            |O               |
# |UNKNOWN_TOKEN    |S-Chemical   |S-Chemical      |
# |-                |O            |O               |
# |induced          |O            |O               |
# |allodynia        |O            |O               |
# |and              |O            |O               |
# |hyperalgesia     |O            |O               |
# |.                |O            |O               |
# |2                |O            |O               |
# |.                |O            |O               |
# |although         |O            |O               |
# |UNKNOWN_TOKEN    |O            |O               |
# |receptors        |O            |O               |
# |which            |O            |O               |
# |display          |O            |O               |
# |a                |O            |O               |
# |high             |O            |O               |
# |degree           |O            |O               |
# |of               |O            |O               |
# |sequence         |O            |O               |
# |homology         |O            |O               |
# |with             |O            |O               |
# |classical        |O            |O               |
# |opioid           |O            |O               |
# |receptors        |O            |O               |
# |are              |O            |O               |
# |abundant         |O            |O               |
# |in               |O            |O               |
# |the              |O            |O               |
# |hippocampus      |O            |O               |
# |,                |O            |O               |
# |little           |O            |O               |
# |is               |O            |O               |
# |known            |O            |O               |
# |regarding        |O            |O               |
# |their            |O            |O               |
# |role             |O            |O               |
# |in               |O            |O               |
# |learning         |O            |O               |
# |and              |O            |O               |
# |memory           |O            |O               |

# %%
col1_width = max([len(x[0]) for x in bad_example])
col2_width = max([len(x[1]) for x in bad_example])
col3_width = max([len(x[2]) for x in bad_example])  

print("\n\n-------- Bad Examples --------")
print ("|{0:<{col1}}  |{1:<{col2}}  |{2:<{col3}}  |".format("Word","Actual","Predicted",col1=col1_width,col2=col2_width,col3=col3_width))

for word, p_tag, a_tag in bad_example:
    print ("|{0:<{col1}}  |{1:<{col2}}   |{2:<{col3}}      |".format(word,a_tag,p_tag,col1=col1_width,col2=col2_width,col3=col3_width))
# Out:
# -------- Bad Examples --------
# |Word           |Actual      |Predicted   |
# |UNKNOWN_TOKEN  |O            |S-Chemical      |
# |UNKNOWN_TOKEN  |O            |S-Chemical      |
# |UNKNOWN_TOKEN  |O            |S-Chemical      |
# |contrast       |B-Chemical   |O               |
# |media          |E-Chemical   |O               |
# |contrast       |B-Chemical   |O               |
# |materials      |E-Chemical   |O               |
# |prc            |S-Chemical   |O               |
# |prc            |S-Chemical   |O               |
# |prc            |S-Chemical   |O               |
# |5              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |5              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |5              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |ammonium       |S-Chemical   |E-Chemical      |
# |UNKNOWN_TOKEN  |O            |S-Chemical      |
# |ammonium       |S-Chemical   |E-Chemical      |
# |5              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |ammonium       |S-Chemical   |E-Chemical      |
# |5              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |O            |S-Chemical      |
# |5              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |4              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |E-Chemical   |S-Chemical      |
# |4              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |E-Chemical   |S-Chemical      |
# |4              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |E-Chemical   |S-Chemical      |
# |4              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |E-Chemical   |S-Chemical      |
# |4              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |E-Chemical   |S-Chemical      |
# |4              |B-Chemical   |O               |
# |-              |I-Chemical   |O               |
# |UNKNOWN_TOKEN  |E-Chemical   |S-Chemical      |
# |UNKNOWN_TOKEN  |B-Chemical   |S-Chemical      |
# |fq             |E-Chemical   |O               |
# |UNKNOWN_TOKEN  |B-Chemical   |S-Chemical      |
# |fq             |E-Chemical   |O               |
